# %% [markdown]
# ## Possible sources of data
#
# - Scrape TED Talks

# %% [markdown]
# ### Scraping TED Talks

# %% [markdown]
# We begin with the standard imports:

# %%
import requests, urllib
import time, os, glob
import re
import pandas as pd, numpy as np
from bs4 import BeautifulSoup
from itertools import chain

# %% [markdown]
# Function to look at a *single* TED talk page and grab all TED talk links:

# %%
def get_names(path, alltalks):
    r = urllib.request.urlopen(path).read()
    soup = BeautifulSoup(r, "lxml")
    talks = soup.find_all("a", class_ = "")
    for i in talks:
        if i.attrs['href'].find('/talks/') == 0 and alltalks.get(i.attrs['href']) != 1:
            alltalks[i.attrs['href']] = 1
    
    return alltalks

# %% [markdown]
# Function to scrape all TED talk links:

# %%
alltalks = {}
link = "https://www.ted.com/talks?language=zh-tw&page={}&sort=newest"

# %%
def get_talks(alltalks):
    try:
        for i in range(int(len(alltalks) / 36), 66):
            path = link.format(i)
            alltalks = get_names(path, alltalks)
            print(path, len(alltalks))
            time.sleep(4)
    except urllib.request.HTTPError:
        print("TED got mad at you, waiting 30 seconds")
        time.sleep(30)
        get_talks(alltalks)

get_talks(alltalks)
# Out:
# https://www.ted.com/talks?language=zh-tw&page=0&sort=newest 36
# https://www.ted.com/talks?language=zh-tw&page=1&sort=newest 36
# https://www.ted.com/talks?language=zh-tw&page=2&sort=newest 72
# https://www.ted.com/talks?language=zh-tw&page=3&sort=newest 108
# https://www.ted.com/talks?language=zh-tw&page=4&sort=newest 144
# https://www.ted.com/talks?language=zh-tw&page=5&sort=newest 180
# https://www.ted.com/talks?language=zh-tw&page=6&sort=newest 216
# https://www.ted.com/talks?language=zh-tw&page=7&sort=newest 252
# https://www.ted.com/talks?language=zh-tw&page=8&sort=newest 288
# https://www.ted.com/talks?language=zh-tw&page=9&sort=newest 324
# https://www.ted.com/talks?language=zh-tw&page=10&sort=newest 360
# https://www.ted.com/talks?language=zh-tw&page=11&sort=newest 396
# https://www.ted.com/talks?language=zh-tw&page=12&sort=newest 432
# https://www.ted.com/talks?language=zh-tw&page=13&sort=newest 468
# https://www.ted.com/talks?language=zh-tw&page=14&sort=newest 504
# https://www.ted.com/talks?language=zh-tw&page=15&sort=newest 540
# https://www.ted.com/talks?language=zh-tw&page=16&sort=newest 576
# https://www.ted.com/talks?language=zh-tw&page=17&sort=newest 612
# https://www.ted.com/talks?language=zh-tw&page=18&sort=newest 648
# https://www.ted.com/talks?language=zh-tw&page=19&sort=newest 684
# https://www.ted.com/talks?language=zh-tw&page=20&sort=newest 720
# https://www.ted.com/talks?language=zh-tw&page=21&sort=newest 756
# https://www.ted.com/talks?language=zh-tw&page=22&sort=newest 792
# https://www.ted.com/talks?language=zh-tw&page=23&sort=newest 828
# https://www.ted.com/talks?language=zh-tw&page=24&sort=newest 864
# https://www.ted.com/talks?language=zh-tw&page=25&sort=newest 900
# https://www.ted.com/talks?language=zh-tw&page=26&sort=newest 936
# https://www.ted.com/talks?language=zh-tw&page=27&sort=newest 972
# https://www.ted.com/talks?language=zh-tw&page=28&sort=newest 1008
# https://www.ted.com/talks?language=zh-tw&page=29&sort=newest 1044
# https://www.ted.com/talks?language=zh-tw&page=30&sort=newest 1080
# https://www.ted.com/talks?language=zh-tw&page=31&sort=newest 1116
# https://www.ted.com/talks?language=zh-tw&page=32&sort=newest 1152
# https://www.ted.com/talks?language=zh-tw&page=33&sort=newest 1188
# https://www.ted.com/talks?language=zh-tw&page=34&sort=newest 1224
# https://www.ted.com/talks?language=zh-tw&page=35&sort=newest 1260
# https://www.ted.com/talks?language=zh-tw&page=36&sort=newest 1296
# https://www.ted.com/talks?language=zh-tw&page=37&sort=newest 1332
# https://www.ted.com/talks?language=zh-tw&page=38&sort=newest 1368
# https://www.ted.com/talks?language=zh-tw&page=39&sort=newest 1404
# https://www.ted.com/talks?language=zh-tw&page=40&sort=newest 1440
# https://www.ted.com/talks?language=zh-tw&page=41&sort=newest 1476
# https://www.ted.com/talks?language=zh-tw&page=42&sort=newest 1512
# https://www.ted.com/talks?language=zh-tw&page=43&sort=newest 1548
# https://www.ted.com/talks?language=zh-tw&page=44&sort=newest 1584
# https://www.ted.com/talks?language=zh-tw&page=45&sort=newest 1620
# https://www.ted.com/talks?language=zh-tw&page=46&sort=newest 1656
# https://www.ted.com/talks?language=zh-tw&page=47&sort=newest 1692
# https://www.ted.com/talks?language=zh-tw&page=48&sort=newest 1728
# https://www.ted.com/talks?language=zh-tw&page=49&sort=newest 1764
# https://www.ted.com/talks?language=zh-tw&page=50&sort=newest 1800
# https://www.ted.com/talks?language=zh-tw&page=51&sort=newest 1836
# https://www.ted.com/talks?language=zh-tw&page=52&sort=newest 1872
# https://www.ted.com/talks?language=zh-tw&page=53&sort=newest 1908
# https://www.ted.com/talks?language=zh-tw&page=54&sort=newest 1944
# https://www.ted.com/talks?language=zh-tw&page=55&sort=newest 1980
# https://www.ted.com/talks?language=zh-tw&page=56&sort=newest 2016
# https://www.ted.com/talks?language=zh-tw&page=57&sort=newest 2052
# https://www.ted.com/talks?language=zh-tw&page=58&sort=newest 2088
# https://www.ted.com/talks?language=zh-tw&page=59&sort=newest 2124
# https://www.ted.com/talks?language=zh-tw&page=60&sort=newest 2160
# https://www.ted.com/talks?language=zh-tw&page=61&sort=newest 2196
# https://www.ted.com/talks?language=zh-tw&page=62&sort=newest 2232
# https://www.ted.com/talks?language=zh-tw&page=63&sort=newest 2268
# https://www.ted.com/talks?language=zh-tw&page=64&sort=newest 2303
# https://www.ted.com/talks?language=zh-tw&page=65&sort=newest 2312

# %% [markdown]
# Function to scrape Traditional Chinese and English for a single talk:

# %%
def extract_talk(path, talk_name):
        
    langs = ["en", "zh-tw"]        
    titles = "(?<![A-Z][a-z])(?<![A-Z][a-z][a-z])\."
    r = urllib.request.urlopen(path).read()
    soup = BeautifulSoup(r, "lxml")
    df = pd.DataFrame()
    
    for i in soup.findAll("link"):
        
        #only look at talks with traditional chinese
        try:
            if i.get("href") != None:
                for lang in langs:
                    if i.attrs["href"].find("?language={}".format(lang)) != -1: 
                        path = i.attrs["href"]
                        r1 = urllib.request.urlopen(path).read()
                        soup1 = BeautifulSoup(r1, "lxml")
                        text_talk = []
                        #print(soup1)
                        for i in soup1.findAll("p", class_= "m-b:0"):
                            #print(i.text.strip().replace("\t", "").replace("\n", ""))
                            if lang == "zh-tw":
                                #text_talk.append(i.text.replace("\t","").replace("\n", "")
                                                 #.strip().split(u"。"))
                                text_talk.append(i.text.strip().replace("\t", "").replace("\n", ""))
                            else:
                                #text_talk.append(re.split(titles, i.text.replace("\t","").replace("\n", " ")
                                             #.strip()))
                                text_talk.append(i.text.strip().replace("\t", "").replace("\n", " "))
                            #text_talk.append(i.text.strip().replace("\t","").split("\n")) #split line by line
                        #text_talk = [x for x in list(chain.from_iterable(text_talk)) if x != ""]
                        #text_talk = list(chain.from_iterable(text_talk))
                        #print(" ".join(text_talk))
                        text_talk = [" ".join(text_talk)]
                        #print(talk_name + " " + lang + " " + str(len(text_talk)))
                        df1 = pd.DataFrame()
                        df1[lang] = text_talk
                        df = pd.concat([df1, df], axis = 1)
        except KeyError:
            break
    df = pd.concat([pd.DataFrame({"Talk" : [talk_name]}), df], axis = 1)
    df.to_csv(talk_name + '.txt', index = False, sep='\t', encoding='utf-8')
    #return df

# %% [markdown]
# One possible edgecase (lacking perfectly aligned periods):

# %%
# ?urllib.request.urlopen

# %%
extract_talk("https://www.ted.com/talks/shubhendu_sharma_an_engineers_vision_for_tiny_forests_everywhere/transcript", "shubhendu_sharma_an_engineers_vision_for_tiny_forests_everywhere")

# %%
alltalks = [x.replace("?language=zh-tw", "") for x in list(alltalks)]
alltalks[832]
# Out:
# '/talks/steve_ramirez_and_xu_liu_a_mouse_a_laser_beam_a_manipulated_memory'

# %% [markdown]
# Function to scrape Traditional Chinese and English for *all* TED talks:
#
# I temporarily stopped at alltalks[833]

# %%
def to_csv(alltalks, talknum):
    try:
        for i in range(talknum, len(alltalks)):
            extract_talk('https://www.ted.com'+ alltalks[i] +'/transcript', alltalks[i][7:])
            time.sleep(3)
            print("On talk number {}".format(talknum + 1) + ", {}% done".format(round((talknum + 1) / len(alltalks), 4)))
            talknum += 1
    except urllib.request.HTTPError:
        print("TED got mad at you, waiting 30 seconds")
        time.sleep(30)
        to_csv(alltalks, talknum)

alltalks = [x.replace("?language=zh-tw", "") for x in list(alltalks)]
to_csv(alltalks, 830)
# Out:
# On talk number 831, 0.3594% done
# On talk number 832, 0.3599% done
# On talk number 833, 0.3603% done
# On talk number 834, 0.3607% done
# TED got mad at you, waiting 30 seconds
# On talk number 835, 0.3612% done
# TED got mad at you, waiting 30 seconds
# On talk number 836, 0.3616% done
# On talk number 837, 0.362% done
# On talk number 838, 0.3625% done
# TED got mad at you, waiting 30 seconds
# On talk number 839, 0.3629% done
# On talk number 840, 0.3633% done
# On talk number 841, 0.3638% done
# On talk number 842, 0.3642% done
# On talk number 843, 0.3646% done
# On talk number 844, 0.3651% done
# TED got mad at you, waiting 30 seconds
# On talk number 845, 0.3655% done
# On talk number 846, 0.3659% done
# On talk number 847, 0.3663% done
# On talk number 848, 0.3668% done
# On talk number 849, 0.3672% done
# On talk number 850, 0.3676% done
# TED got mad at you, waiting 30 seconds
# On talk number 851, 0.3681% done
# On talk number 852, 0.3685% done
# On talk number 853, 0.3689% done
# On talk number 854, 0.3694% done
# On talk number 855, 0.3698% done
# On talk number 856, 0.3702% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 857, 0.3707% done
# On talk number 858, 0.3711% done
# On talk number 859, 0.3715% done
# On talk number 860, 0.372% done
# On talk number 861, 0.3724% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 862, 0.3728% done
# On talk number 863, 0.3733% done
# On talk number 864, 0.3737% done
# On talk number 865, 0.3741% done
# On talk number 866, 0.3746% done
# On talk number 867, 0.375% done
# TED got mad at you, waiting 30 seconds
# On talk number 868, 0.3754% done
# On talk number 869, 0.3759% done
# On talk number 870, 0.3763% done
# On talk number 871, 0.3767% done
# On talk number 872, 0.3772% done
# TED got mad at you, waiting 30 seconds
# On talk number 873, 0.3776% done
# On talk number 874, 0.378% done
# On talk number 875, 0.3785% done
# On talk number 876, 0.3789% done
# On talk number 877, 0.3793% done
# TED got mad at you, waiting 30 seconds
# On talk number 878, 0.3798% done
# TED got mad at you, waiting 30 seconds
# On talk number 879, 0.3802% done
# On talk number 880, 0.3806% done
# On talk number 881, 0.3811% done
# TED got mad at you, waiting 30 seconds
# On talk number 882, 0.3815% done
# TED got mad at you, waiting 30 seconds
# On talk number 883, 0.3819% done
# On talk number 884, 0.3824% done
# On talk number 885, 0.3828% done
# On talk number 886, 0.3832% done
# On talk number 887, 0.3837% done
# TED got mad at you, waiting 30 seconds
# On talk number 888, 0.3841% done
# On talk number 889, 0.3845% done
# On talk number 890, 0.3849% done
# On talk number 891, 0.3854% done
# TED got mad at you, waiting 30 seconds
# On talk number 892, 0.3858% done
# TED got mad at you, waiting 30 seconds
# On talk number 893, 0.3862% done
# On talk number 894, 0.3867% done
# On talk number 895, 0.3871% done
# On talk number 896, 0.3875% done
# On talk number 897, 0.388% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 898, 0.3884% done
# On talk number 899, 0.3888% done
# On talk number 900, 0.3893% done
# On talk number 901, 0.3897% done
# On talk number 902, 0.3901% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 903, 0.3906% done
# On talk number 904, 0.391% done
# On talk number 905, 0.3914% done
# On talk number 906, 0.3919% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 907, 0.3923% done
# On talk number 908, 0.3927% done
# On talk number 909, 0.3932% done
# On talk number 910, 0.3936% done
# On talk number 911, 0.394% done
# On talk number 912, 0.3945% done
# TED got mad at you, waiting 30 seconds
# On talk number 913, 0.3949% done
# On talk number 914, 0.3953% done
# On talk number 915, 0.3958% done
# TED got mad at you, waiting 30 seconds
# On talk number 916, 0.3962% done
# On talk number 917, 0.3966% done
# On talk number 918, 0.3971% done
# TED got mad at you, waiting 30 seconds
# On talk number 919, 0.3975% done
# TED got mad at you, waiting 30 seconds
# On talk number 920, 0.3979% done
# On talk number 921, 0.3984% done
# On talk number 922, 0.3988% done
# TED got mad at you, waiting 30 seconds
# On talk number 923, 0.3992% done
# TED got mad at you, waiting 30 seconds
# On talk number 924, 0.3997% done
# On talk number 925, 0.4001% done
# TED got mad at you, waiting 30 seconds
# On talk number 926, 0.4005% done
# On talk number 927, 0.401% done
# On talk number 928, 0.4014% done
# On talk number 929, 0.4018% done
# On talk number 930, 0.4022% done
# On talk number 931, 0.4027% done
# TED got mad at you, waiting 30 seconds
# On talk number 932, 0.4031% done
# On talk number 933, 0.4035% done
# On talk number 934, 0.404% done
# On talk number 935, 0.4044% done
# TED got mad at you, waiting 30 seconds
# On talk number 936, 0.4048% done
# TED got mad at you, waiting 30 seconds
# On talk number 937, 0.4053% done
# On talk number 938, 0.4057% done
# On talk number 939, 0.4061% done
# TED got mad at you, waiting 30 seconds
# On talk number 940, 0.4066% done
# TED got mad at you, waiting 30 seconds
# On talk number 941, 0.407% done
# On talk number 942, 0.4074% done
# On talk number 943, 0.4079% done
# On talk number 944, 0.4083% done
# On talk number 945, 0.4087% done
# On talk number 946, 0.4092% done
# TED got mad at you, waiting 30 seconds
# On talk number 947, 0.4096% done
# TED got mad at you, waiting 30 seconds
# On talk number 948, 0.41% done
# On talk number 949, 0.4105% done
# On talk number 950, 0.4109% done
# On talk number 951, 0.4113% done
# On talk number 952, 0.4118% done
# On talk number 953, 0.4122% done
# TED got mad at you, waiting 30 seconds
# On talk number 954, 0.4126% done
# On talk number 955, 0.4131% done
# On talk number 956, 0.4135% done
# On talk number 957, 0.4139% done
# On talk number 958, 0.4144% done
# TED got mad at you, waiting 30 seconds
# On talk number 959, 0.4148% done
# On talk number 960, 0.4152% done
# On talk number 961, 0.4157% done
# On talk number 962, 0.4161% done
# On talk number 963, 0.4165% done
# TED got mad at you, waiting 30 seconds
# On talk number 964, 0.417% done
# On talk number 965, 0.4174% done
# On talk number 966, 0.4178% done
# On talk number 967, 0.4183% done
# TED got mad at you, waiting 30 seconds
# On talk number 968, 0.4187% done
# On talk number 969, 0.4191% done
# TED got mad at you, waiting 30 seconds
# On talk number 970, 0.4196% done
# On talk number 971, 0.42% done
# On talk number 972, 0.4204% done
# TED got mad at you, waiting 30 seconds
# On talk number 973, 0.4208% done
# On talk number 974, 0.4213% done
# On talk number 975, 0.4217% done
# TED got mad at you, waiting 30 seconds
# On talk number 976, 0.4221% done
# On talk number 977, 0.4226% done
# On talk number 978, 0.423% done
# On talk number 979, 0.4234% done
# TED got mad at you, waiting 30 seconds
# On talk number 980, 0.4239% done
# On talk number 981, 0.4243% done
# On talk number 982, 0.4247% done
# On talk number 983, 0.4252% done
# On talk number 984, 0.4256% done
# On talk number 985, 0.426% done
# TED got mad at you, waiting 30 seconds
# On talk number 986, 0.4265% done
# On talk number 987, 0.4269% done
# TED got mad at you, waiting 30 seconds
# On talk number 988, 0.4273% done
# On talk number 989, 0.4278% done
# On talk number 990, 0.4282% done
# On talk number 991, 0.4286% done
# On talk number 992, 0.4291% done
# On talk number 993, 0.4295% done
# TED got mad at you, waiting 30 seconds
# On talk number 994, 0.4299% done
# On talk number 995, 0.4304% done
# On talk number 996, 0.4308% done
# On talk number 997, 0.4312% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 998, 0.4317% done
# On talk number 999, 0.4321% done
# On talk number 1000, 0.4325% done
# On talk number 1001, 0.433% done
# TED got mad at you, waiting 30 seconds
# On talk number 1002, 0.4334% done
# TED got mad at you, waiting 30 seconds
# On talk number 1003, 0.4338% done
# On talk number 1004, 0.4343% done
# On talk number 1005, 0.4347% done
# TED got mad at you, waiting 30 seconds
# On talk number 1006, 0.4351% done
# On talk number 1007, 0.4356% done
# On talk number 1008, 0.436% done
# On talk number 1009, 0.4364% done
# On talk number 1010, 0.4369% done
# On talk number 1011, 0.4373% done
# TED got mad at you, waiting 30 seconds
# On talk number 1012, 0.4377% done
# TED got mad at you, waiting 30 seconds
# On talk number 1013, 0.4381% done
# On talk number 1014, 0.4386% done
# On talk number 1015, 0.439% done
# On talk number 1016, 0.4394% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 1017, 0.4399% done
# On talk number 1018, 0.4403% done
# On talk number 1019, 0.4407% done
# On talk number 1020, 0.4412% done
# On talk number 1021, 0.4416% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 1022, 0.442% done
# On talk number 1023, 0.4425% done
# On talk number 1024, 0.4429% done
# On talk number 1025, 0.4433% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 1026, 0.4438% done
# On talk number 1027, 0.4442% done
# On talk number 1028, 0.4446% done
# On talk number 1029, 0.4451% done
# On talk number 1030, 0.4455% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 1031, 0.4459% done
# On talk number 1032, 0.4464% done
# On talk number 1033, 0.4468% done
# On talk number 1034, 0.4472% done
# On talk number 1035, 0.4477% done
# On talk number 1036, 0.4481% done
# TED got mad at you, waiting 30 seconds
# On talk number 1037, 0.4485% done
# On talk number 1038, 0.449% done
# On talk number 1039, 0.4494% done
# TED got mad at you, waiting 30 seconds
# On talk number 1040, 0.4498% done
# On talk number 1041, 0.4503% done
# On talk number 1042, 0.4507% done
# On talk number 1043, 0.4511% done
# On talk number 1044, 0.4516% done
# TED got mad at you, waiting 30 seconds
# On talk number 1045, 0.452% done
# On talk number 1046, 0.4524% done
# TED got mad at you, waiting 30 seconds
# On talk number 1047, 0.4529% done
# On talk number 1048, 0.4533% done
# On talk number 1049, 0.4537% done
# On talk number 1050, 0.4542% done
# On talk number 1051, 0.4546% done
# TED got mad at you, waiting 30 seconds
# On talk number 1052, 0.455% done
# On talk number 1053, 0.4554% done
# On talk number 1054, 0.4559% done
# On talk number 1055, 0.4563% done
# On talk number 1056, 0.4567% done
# On talk number 1057, 0.4572% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 1058, 0.4576% done
# On talk number 1059, 0.458% done
# On talk number 1060, 0.4585% done
# On talk number 1061, 0.4589% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 1062, 0.4593% done
# On talk number 1063, 0.4598% done
# On talk number 1064, 0.4602% done
# On talk number 1065, 0.4606% done
# On talk number 1066, 0.4611% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 1067, 0.4615% done
# On talk number 1068, 0.4619% done
# On talk number 1069, 0.4624% done
# On talk number 1070, 0.4628% done
# On talk number 1071, 0.4632% done
# On talk number 1072, 0.4637% done
# TED got mad at you, waiting 30 seconds
# On talk number 1073, 0.4641% done
# On talk number 1074, 0.4645% done
# TED got mad at you, waiting 30 seconds
# On talk number 1075, 0.465% done
# On talk number 1076, 0.4654% done
# TED got mad at you, waiting 30 seconds
# On talk number 1077, 0.4658% done
# On talk number 1078, 0.4663% done
# On talk number 1079, 0.4667% done
# On talk number 1080, 0.4671% done
# On talk number 1081, 0.4676% done
# On talk number 1082, 0.468% done
# TED got mad at you, waiting 30 seconds
# On talk number 1083, 0.4684% done
# On talk number 1084, 0.4689% done
# On talk number 1085, 0.4693% done
# On talk number 1086, 0.4697% done
# On talk number 1087, 0.4702% done
# On talk number 1088, 0.4706% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 1089, 0.471% done
# On talk number 1090, 0.4715% done
# On talk number 1091, 0.4719% done
# On talk number 1092, 0.4723% done
# On talk number 1093, 0.4728% done
# On talk number 1094, 0.4732% done
# TED got mad at you, waiting 30 seconds
# On talk number 1095, 0.4736% done
# On talk number 1096, 0.474% done
# TED got mad at you, waiting 30 seconds
# On talk number 1097, 0.4745% done
# On talk number 1098, 0.4749% done
# On talk number 1099, 0.4753% done
# TED got mad at you, waiting 30 seconds
# On talk number 1100, 0.4758% done
# On talk number 1101, 0.4762% done
# TED got mad at you, waiting 30 seconds
# On talk number 1102, 0.4766% done
# On talk number 1103, 0.4771% done
# On talk number 1104, 0.4775% done
# On talk number 1105, 0.4779% done
# On talk number 1106, 0.4784% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 1107, 0.4788% done
# On talk number 1108, 0.4792% done
# On talk number 1109, 0.4797% done
# On talk number 1110, 0.4801% done
# On talk number 1111, 0.4805% done
# TED got mad at you, waiting 30 seconds
# On talk number 1112, 0.481% done
# On talk number 1113, 0.4814% done
# On talk number 1114, 0.4818% done
# TED got mad at you, waiting 30 seconds
# On talk number 1115, 0.4823% done
# TED got mad at you, waiting 30 seconds
# On talk number 1116, 0.4827% done
# On talk number 1117, 0.4831% done
# On talk number 1118, 0.4836% done
# On talk number 1119, 0.484% done
# On talk number 1120, 0.4844% done
# On talk number 1121, 0.4849% done
# TED got mad at you, waiting 30 seconds
# On talk number 1122, 0.4853% done
# TED got mad at you, waiting 30 seconds
# On talk number 1123, 0.4857% done
# On talk number 1124, 0.4862% done
# On talk number 1125, 0.4866% done
# On talk number 1126, 0.487% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 1127, 0.4875% done
# On talk number 1128, 0.4879% done
# On talk number 1129, 0.4883% done
# On talk number 1130, 0.4888% done
# On talk number 1131, 0.4892% done
# On talk number 1132, 0.4896% done
# TED got mad at you, waiting 30 seconds
# On talk number 1133, 0.4901% done
# On talk number 1134, 0.4905% done
# On talk number 1135, 0.4909% done
# On talk number 1136, 0.4913% done
# On talk number 1137, 0.4918% done
# On talk number 1138, 0.4922% done
# TED got mad at you, waiting 30 seconds
# On talk number 1139, 0.4926% done
# On talk number 1140, 0.4931% done
# On talk number 1141, 0.4935% done
# On talk number 1142, 0.4939% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 1143, 0.4944% done
# On talk number 1144, 0.4948% done
# On talk number 1145, 0.4952% done
# On talk number 1146, 0.4957% done
# On talk number 1147, 0.4961% done
# TED got mad at you, waiting 30 seconds
# On talk number 1148, 0.4965% done
# TED got mad at you, waiting 30 seconds
# On talk number 1149, 0.497% done
# On talk number 1150, 0.4974% done
# On talk number 1151, 0.4978% done
# On talk number 1152, 0.4983% done
# On talk number 1153, 0.4987% done
# On talk number 1154, 0.4991% done
# TED got mad at you, waiting 30 seconds
# On talk number 1155, 0.4996% done
# On talk number 1156, 0.5% done
# On talk number 1157, 0.5004% done
# On talk number 1158, 0.5009% done
# On talk number 1159, 0.5013% done
# On talk number 1160, 0.5017% done
# TED got mad at you, waiting 30 seconds
# On talk number 1161, 0.5022% done
# On talk number 1162, 0.5026% done
# On talk number 1163, 0.503% done
# On talk number 1164, 0.5035% done
# On talk number 1165, 0.5039% done
# On talk number 1166, 0.5043% done
# TED got mad at you, waiting 30 seconds
# On talk number 1167, 0.5048% done
# On talk number 1168, 0.5052% done
# On talk number 1169, 0.5056% done
# TED got mad at you, waiting 30 seconds
# On talk number 1170, 0.5061% done
# On talk number 1171, 0.5065% done
# On talk number 1172, 0.5069% done
# On talk number 1173, 0.5074% done
# On talk number 1174, 0.5078% done
# On talk number 1175, 0.5082% done
# TED got mad at you, waiting 30 seconds
# On talk number 1176, 0.5087% done
# TED got mad at you, waiting 30 seconds
# On talk number 1177, 0.5091% done
# On talk number 1178, 0.5095% done
# On talk number 1179, 0.5099% done
# On talk number 1180, 0.5104% done
# TED got mad at you, waiting 30 seconds
# On talk number 1181, 0.5108% done
# TED got mad at you, waiting 30 seconds
# On talk number 1182, 0.5112% done
# On talk number 1183, 0.5117% done
# On talk number 1184, 0.5121% done
# On talk number 1185, 0.5125% done
# On talk number 1186, 0.513% done
# On talk number 1187, 0.5134% done
# TED got mad at you, waiting 30 seconds
# On talk number 1188, 0.5138% done
# On talk number 1189, 0.5143% done
# On talk number 1190, 0.5147% done
# On talk number 1191, 0.5151% done
# On talk number 1192, 0.5156% done
# On talk number 1193, 0.516% done
# TED got mad at you, waiting 30 seconds
# On talk number 1194, 0.5164% done
# On talk number 1195, 0.5169% done
# TED got mad at you, waiting 30 seconds
# On talk number 1196, 0.5173% done
# On talk number 1197, 0.5177% done
# TED got mad at you, waiting 30 seconds
# On talk number 1198, 0.5182% done
# On talk number 1199, 0.5186% done
# TED got mad at you, waiting 30 seconds
# On talk number 1200, 0.519% done
# TED got mad at you, waiting 30 seconds
# On talk number 1201, 0.5195% done
# On talk number 1202, 0.5199% done
# On talk number 1203, 0.5203% done
# On talk number 1204, 0.5208% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 1205, 0.5212% done
# On talk number 1206, 0.5216% done
# On talk number 1207, 0.5221% done
# On talk number 1208, 0.5225% done
# On talk number 1209, 0.5229% done
# TED got mad at you, waiting 30 seconds
# On talk number 1210, 0.5234% done
# On talk number 1211, 0.5238% done
# On talk number 1212, 0.5242% done
# On talk number 1213, 0.5247% done
# On talk number 1214, 0.5251% done
# On talk number 1215, 0.5255% done
# TED got mad at you, waiting 30 seconds
# On talk number 1216, 0.526% done
# TED got mad at you, waiting 30 seconds
# On talk number 1217, 0.5264% done
# On talk number 1218, 0.5268% done
# On talk number 1219, 0.5272% done
# On talk number 1220, 0.5277% done
# On talk number 1221, 0.5281% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 1222, 0.5285% done
# On talk number 1223, 0.529% done
# On talk number 1224, 0.5294% done
# On talk number 1225, 0.5298% done
# On talk number 1226, 0.5303% done
# On talk number 1227, 0.5307% done
# TED got mad at you, waiting 30 seconds
# On talk number 1228, 0.5311% done
# On talk number 1229, 0.5316% done
# On talk number 1230, 0.532% done
# On talk number 1231, 0.5324% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 1232, 0.5329% done
# On talk number 1233, 0.5333% done
# On talk number 1234, 0.5337% done
# On talk number 1235, 0.5342% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 1236, 0.5346% done
# On talk number 1237, 0.535% done
# On talk number 1238, 0.5355% done
# On talk number 1239, 0.5359% done
# TED got mad at you, waiting 30 seconds
# On talk number 1240, 0.5363% done
# On talk number 1241, 0.5368% done
# TED got mad at you, waiting 30 seconds
# On talk number 1242, 0.5372% done
# On talk number 1243, 0.5376% done
# On talk number 1244, 0.5381% done
# On talk number 1245, 0.5385% done
# On talk number 1246, 0.5389% done
# On talk number 1247, 0.5394% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 1248, 0.5398% done
# On talk number 1249, 0.5402% done
# On talk number 1250, 0.5407% done
# On talk number 1251, 0.5411% done
# On talk number 1252, 0.5415% done
# On talk number 1253, 0.542% done
# TED got mad at you, waiting 30 seconds
# On talk number 1254, 0.5424% done
# On talk number 1255, 0.5428% done
# On talk number 1256, 0.5433% done
# On talk number 1257, 0.5437% done
# On talk number 1258, 0.5441% done
# TED got mad at you, waiting 30 seconds
# TED got mad at you, waiting 30 seconds
# On talk number 1259, 0.5446% done
# On talk number 1260, 0.545% done
# On talk number 1261, 0.5454% done
# On talk number 1262, 0.5458% done
# TED got mad at you, waiting 30 seconds
# On talk number 1263, 0.5463% done
# TED got mad at you, waiting 30 seconds

# %% [markdown]
# ## Reading in all txt files

# %%
glob.glob("*.csv")[2]
# Out:
# 'mehdi_ordikhani_seyedlar_what_happens_in_your_brain_when_you_pay_attention.csv'

# %%
#library computer
path = "C:\\Users\\liblabs-user\\Desktop\\Cal Poly Summer Research 2017"
os.chdir(path)

#sierra's computer
#spath = "/Users/sierra/Desktop/Cal Poly Summer Research 2017"
#os.chdir(spath)

pd.read_csv(glob.glob("*.txt")[0], sep = "\t", encoding = "utf-8")
# Out:
#                                                 Talk  \
# 0  abigail_marsh_why_some_people_are_more_altruis...
#
#                                                   en  \
# 0  There's a man out there, somewhere, who looks ...
#
#                                                zh-tw
# 0  一位男子站在那，長的有點神似演員伊卓瑞斯·艾巴，或者是艾巴20年前的樣子。除了他鋌而走險救了...
