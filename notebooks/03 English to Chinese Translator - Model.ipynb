# %% [markdown]
# # Model
# #### Charlie Liou

# %%
#import numpy as np, pandas as pd
import string, re
import os, glob, requests
from bs4 import BeautifulSoup
from itertools import chain

# %% [markdown]
# Much of this is adapted from Kevin Knight's [A Statistical MT Tutorial Workbook.](http://www.isi.edu/natural-language/mt/wkbk.rtf)
#
# To write a statistical English to Chinese translator, we will consider English sentences $e$ and Chinese sentences $c$. This may seem like solving the opposite problem, but given $c$, we seek the English sentence that will maximize $P( e \mid  c)$ (that is, the most likely English sentence when given the Chinese sentence.) This reversal will be explained later. More formally, we are trying to find the english sentence $\vec{e}$ that satisfies
#
# $$\vec{e} = arg\hspace{0.05cm} max\hspace{0.05cm}P(e \mid c)$$
#
# How do we approach maximizing the probability $P(e \mid  c)?$ Given that we know Bayes' Theorem:
#
# $$P( e \mid  c) = \dfrac{P(e)\hspace{0.05cm}P(c\mid e)}{P(c)}$$
#
# the above equation becomes
#
# $$\vec{e} = arg\hspace{0.05cm} max\hspace{0.05cm}P(e \mid c) = arg\hspace{0.05cm} max\hspace{0.05cm}P(e)\hspace{0.05cm}P(c \mid e)$$
#
# This is pure Bayesian reasoning; think of the given Chinese sentence $c$ as a crime scene. Knight gives a good analogy for this: $e$ is the person who did the crime, $P(e)$ is the description of the person, and $P(c \mid e)$ is how they did it. There are possibly many people who fit the description of $P(e)$ but those people may not have the means of committing the crime. Likewise, there are possibly many people who have the means $P(c \mid e)$ of committing the crime but they don't fit the personality. We're trying to solve for the person who is most likely to commit the crime and has the means to commit it.
#
# Now if we think about translating language itself, accurate syntax and translations are necessary. We can't have one without the other. In our last equation, $P(e)$ is equivalent to correct syntax and $P(c\mid e)$ is equivalent to correct translations. This is why we must maximize the probability $P(e \mid c)$. Maximizing this probability is equivalent to finding sentences that have correct syntax and accurate translations.

# %% [markdown]
# ### Language Model
#
# To account for syntax, meaning finding values of $P(e)$, we use a *n*-gram model.

# %% [markdown]
# Data directory:

# %%
#my personal computer
path = "C:\\Users\\chuck189\\Desktop\\Cal Poly Summer Research 2017\\data"

#math lounge computer
#path = "/Users/csmuser/Desktop/Cal Poly Summer Research 2017/data"

# %% [markdown]
# Trigram code:

# %%
def trigram(final, freqs):
    '''
    Takes a list of strings (which are sentences) and a dictionary with phrase frequencies
    Returns a trigram and updated phrase frequencies.
    '''
    temp = {}
    
    
    for sent in final:
        
        for i in range(0, len(sent) - 2):
            ot = final[i] + " " + final[i + 1]
            tt = final[i + 1] + " " + final[i + 2]
            if ot in temp:
                if tt in temp[ot]:
                    temp[ot][tt] += 1
                else:
                    temp[ot].update({tt : 1})
            else:
                temp.update({ot : {tt : 1}})
    '''
    for i in list(temp):
        num = 0
        for j in list(temp[i]):
            num += temp[i][j]
        for j in list(temp[i]):
            temp[i][j] /= num
    '''
    
    return temp

# %% [markdown]
# Function for merging a list of dictionaries:

# %%
def merge_dicts(dict_args):
    result = {}
    for dictionary in dict_args:
        result.update(dictionary)
    return result

# %% [markdown]
# The next block prepares to check contractions and a list of punctuations to remove (except sentence stops, -, $).

# %%
#pulling contractions from two different sites
c = requests.get("http://www.softschools.com/language_arts/grammar/contractions/contractions_list/").content
soup = BeautifulSoup(c, "lxml")
cont = [x for x in str(soup.find_all("span", class_ = "myFont14")[0])
                .replace("<br/>", " ").split(" ") if "\'" in x]

c1 = requests.get("http://grammar.wikia.com/wiki/List_of_contractions").content
soup1 = BeautifulSoup(c1, "lxml")
cont1 = [str(x).replace("</td>", "").replace("\n", "").replace("<td>", "") 
         for x in soup1.find_all("td") if "\'" in str(x)]

e = ["He'll ", " he'll ", "We'd ", " we'd ", "She'll ", " she'll ", "We're ", 
        " we're ", "It's ", " it's ", "So's ", " so's ", "Who're ", " who're ", "'s", "s'", " we'll ", "We'll "]
conts = list(chain.from_iterable([[x.ljust(len(x) + 1).capitalize(), x.center(len(x) + 2)]
                                  for x in list(set(cont).union(cont1))]))
[conts.append(x) for x in ["That'll", " that'll "]]
for i in e:
    if i in conts:
        conts.remove(i)

nopunct = merge_dicts(list(chain.from_iterable([[{conts[x].replace("\'", "") : x, conts[x].replace("\'", " ") : x}] 
                                        for x in range(len(conts))])))

#punctuations to remove
sub = {".": "", "!": "", "?": "", "-": "", "$": "", "%": ""}
rep = dict((re.escape(k), v) for k, v in sub.items())
pattern = re.compile("|".join(rep.keys()))
exclude = set(pattern.sub(lambda m: rep[re.escape(m.group(0))], string.punctuation))

# %%
nopunct
# Out:
# {' I d ': 3,
#  ' I ll ': 17,
#  ' I m ': 45,
#  ' I ve ': 71,
#  ' Id ': 3,
#  ' Ill ': 17,
#  ' Im ': 45,
#  ' Ive ': 71,
#  ' aren t ': 91,
#  ' arent ': 91,
#  ' can t ': 97,
#  ' cant ': 97,
#  ' couldn t ': 75,
#  ' couldnt ': 75,
#  ' didn t ': 57,
#  ' didnt ': 57,
#  ' doesn t ': 77,
#  ' doesnt ': 77,
#  ' don t ': 25,
#  ' dont ': 25,
#  ' hadn t ': 1,
#  ' hadnt ': 1,
#  ' hasn t ': 23,
#  ' hasnt ': 23,
#  ' haven t ': 61,
#  ' havent ': 61,
#  ' he d ': 93,
#  ' he s ': 11,
#  ' hed ': 93,
#  ' hes ': 11,
#  ' how d ': 13,
#  ' how s ': 55,
#  ' howd ': 13,
#  ' hows ': 55,
#  ' isn t ': 101,
#  ' isnt ': 101,
#  ' let s ': 5,
#  ' lets ': 5,
#  ' might ve ': 79,
#  ' mightn t ': 65,
#  ' mightnt ': 65,
#  ' mightve ': 79,
#  ' mustn t ': 27,
#  ' mustnt ': 27,
#  ' needn t ': 89,
#  ' neednt ': 89,
#  ' shan t ': 7,
#  ' shant ': 7,
#  ' she d ': 113,
#  ' she s ': 49,
#  ' shed ': 113,
#  ' shes ': 49,
#  ' should ve ': 95,
#  ' shouldn t ': 99,
#  ' shouldnt ': 99,
#  ' shouldve ': 95,
#  ' that ll ': 115,
#  ' that s ': 19,
#  ' thatll ': 115,
#  ' thats ': 19,
#  ' there s ': 81,
#  ' theres ': 81,
#  ' they d ': 103,
#  ' they ll ': 85,
#  ' they re ': 43,
#  ' they ve ': 69,
#  ' theyd ': 103,
#  ' theyll ': 85,
#  ' theyre ': 43,
#  ' theyve ': 69,
#  ' wasn t ': 37,
#  ' wasnt ': 37,
#  ' we ll ': 67,
#  ' we ve ': 41,
#  ' well ': 67,
#  ' weren t ': 53,
#  ' werent ': 53,
#  ' weve ': 41,
#  ' what ll ': 21,
#  ' what re ': 63,
#  ' what s ': 35,
#  ' what ve ': 73,
#  ' whatll ': 21,
#  ' whatre ': 63,
#  ' whats ': 35,
#  ' whatve ': 73,
#  ' when s ': 51,
#  ' whens ': 51,
#  ' where s ': 15,
#  ' wheres ': 15,
#  ' who ll ': 31,
#  ' who s ': 107,
#  ' who ve ': 111,
#  ' wholl ': 31,
#  ' whos ': 107,
#  ' whove ': 111,
#  ' why s ': 39,
#  ' whys ': 39,
#  ' won t ': 109,
#  ' won t ve ': 29,
#  ' wont ': 109,
#  ' wontve ': 29,
#  ' would ve ': 59,
#  ' wouldn t ': 47,
#  ' wouldn t ve ': 9,
#  ' wouldnt ': 47,
#  ' wouldntve ': 9,
#  ' wouldve ': 59,
#  ' you d ': 33,
#  ' you ll ': 87,
#  ' you re ': 83,
#  ' you ve ': 105,
#  ' youd ': 33,
#  ' youll ': 87,
#  ' youre ': 83,
#  ' youve ': 105,
#  'Aren t ': 90,
#  'Arent ': 90,
#  'Can t ': 96,
#  'Cant ': 96,
#  'Couldn t ': 74,
#  'Couldnt ': 74,
#  'Didn t ': 56,
#  'Didnt ': 56,
#  'Doesn t ': 76,
#  'Doesnt ': 76,
#  'Don t ': 24,
#  'Dont ': 24,
#  'Hadn t ': 0,
#  'Hadnt ': 0,
#  'Hasn t ': 22,
#  'Hasnt ': 22,
#  'Haven t ': 60,
#  'Havent ': 60,
#  'He d ': 92,
#  'He s ': 10,
#  'Hed ': 92,
#  'Hes ': 10,
#  'How d ': 12,
#  'How s ': 54,
#  'Howd ': 12,
#  'Hows ': 54,
#  'I d ': 2,
#  'I ll ': 16,
#  'I m ': 44,
#  'I ve ': 70,
#  'Id ': 2,
#  'Ill ': 16,
#  'Im ': 44,
#  'Isn t ': 100,
#  'Isnt ': 100,
#  'Ive ': 70,
#  'Let s ': 4,
#  'Lets ': 4,
#  'Might ve ': 78,
#  'Mightn t ': 64,
#  'Mightnt ': 64,
#  'Mightve ': 78,
#  'Mustn t ': 26,
#  'Mustnt ': 26,
#  'Needn t ': 88,
#  'Neednt ': 88,
#  'Shan t ': 6,
#  'Shant ': 6,
#  'She d ': 112,
#  'She s ': 48,
#  'Shed ': 112,
#  'Shes ': 48,
#  'Should ve ': 94,
#  'Shouldn t ': 98,
#  'Shouldnt ': 98,
#  'Shouldve ': 94,
#  'That ll': 114,
#  'That s ': 18,
#  'Thatll': 114,
#  'Thats ': 18,
#  'There s ': 80,
#  'Theres ': 80,
#  'They d ': 102,
#  'They ll ': 84,
#  'They re ': 42,
#  'They ve ': 68,
#  'Theyd ': 102,
#  'Theyll ': 84,
#  'Theyre ': 42,
#  'Theyve ': 68,
#  'Wasn t ': 36,
#  'Wasnt ': 36,
#  'We ll ': 66,
#  'We ve ': 40,
#  'Well ': 66,
#  'Weren t ': 52,
#  'Werent ': 52,
#  'Weve ': 40,
#  'What ll ': 20,
#  'What re ': 62,
#  'What s ': 34,
#  'What ve ': 72,
#  'Whatll ': 20,
#  'Whatre ': 62,
#  'Whats ': 34,
#  'Whatve ': 72,
#  'When s ': 50,
#  'Whens ': 50,
#  'Where s ': 14,
#  'Wheres ': 14,
#  'Who ll ': 30,
#  'Who s ': 106,
#  'Who ve ': 110,
#  'Wholl ': 30,
#  'Whos ': 106,
#  'Whove ': 110,
#  'Why s ': 38,
#  'Whys ': 38,
#  'Won t ': 108,
#  'Won t ve ': 28,
#  'Wont ': 108,
#  'Wontve ': 28,
#  'Would ve ': 58,
#  'Wouldn t ': 46,
#  'Wouldn t ve ': 8,
#  'Wouldnt ': 46,
#  'Wouldntve ': 8,
#  'Wouldve ': 58,
#  'You d ': 32,
#  'You ll ': 86,
#  'You re ': 82,
#  'You ve ': 104,
#  'Youd ': 32,
#  'Youll ': 86,
#  'Youre ': 82,
#  'Youve ': 104}

# %% [markdown]
# This function prepares the `casia2015_en` dataset for *n*-gram processing.

# %%
def process_c2015en(l, conts, nopunct, exclude, e):

    money = "<$>"
    percent = "<%>"
    
    for i in range(len(l)):
        
        #####remove punctuations except - ! . ?
        #####accounts for many apostrophe edge cases including possession
        
        if (e[0] in l[i]) or (e[1] in l[i]) or (e[2] in l[i]) or (e[3] in l[i]) or (e[4] in l[i]) or (e[5] in l[i]) \
            or (e[6] in l[i]) or (e[7] in l[i]) or (e[8] in l[i]) or (e[9] in l[i]) or (e[10] in l[i]) or (e[11] in l[i]) \
            or (e[12] in l[i]) or (e[13] in l[i]) or (e[14] in l[i]) or (e[15] in l[i]) or (e[16] in l[i]) or (e[17] in l[i]): 
            for item in exclude:
                if item is "\'":
                    indexes = [m.start() for m in re.finditer("\'", l[i])]
                    num = 0
                    for index in indexes:
                        if (e[14] in l[i]) or (e[15] in l[i]):
                            continue
                        t = l[i][index - 2 - num: index - num]
                        if (t != "he") and (t != "He") and (t != "We") and (t != "we") and (t != "It") and \
                        (t != "it") and (t != "So") and (t != "so") and (t != "ho") and \
                        (index - num != 0) and (index - num != len(l[i])):
                            l[i] = l[i][:index - num] + l[i][index + 1 - num:]
                            num += 1
                else:
                    l[i] = l[i].replace(item, "")
        else:
            l[i] = "".join(ch for ch in l[i] if ch not in exclude)
           
        #####replace contractions w/ correct form, add sentence markers
        
        j = l[i].strip()
        #l[i] = start + " " + j[:len(j)-1] + " " + stop
        for x in nopunct:
            if x in l[i]:
                l[i] = l[i].replace(x, conts[nopunct[x]])
        
        #####deal with - and --
        
        if " - " in l[i]:
            indexes = [m.start() for m in re.finditer(" - ", l[i])]
            num = 0
            for index in indexes:
                l[i] = l[i][:index - num] + l[i][index + 2 - num:]
                num += 2
                    
        elif "--" in l[i]:
            indexes = [m.start() for m in re.finditer("--", l[i])]
            num = 0
            for index in indexes:
                l[i] = l[i][:index - num] + l[i][index + 2 - num:]
                num += 2
                
        #####replace $__ with <$>, 
        
        if "$" in l[i]:
            indexes = [m.start() for m in re.finditer("\$", l[i])]
            nums = [m.end() for m in re.finditer("\$[-+]?([0-9]*?\.?[\s][0-9]+|[0-9]+)", l[i])]
            if len(indexes) == len(nums):
                num = 0
                for j in range(len(indexes)):
                    l[i] = l[i][:indexes[j] - num] + money + l[i][nums[j] - num:]
                    num += nums[j] - indexes[j] - 3
            else:
                l[i] = "" #bad sentence
            
        #####replace __% with <%>
        #####accounts for cases such as "29. 2%"
        
        if "%" in l[i]:
            indexes = [m.start() for m in re.finditer("([0-9]*?\.[\s]?[0-9]+|[0-9]+)%", l[i])]            
            percents = [m.end() for m in re.finditer("%", l[i])]
            if len(indexes) == len(percents):
                num = 0
                for j in range(len(indexes)):
                    l[i] = l[i][:indexes[j] - num] + percent + l[i][percents[j] - num:]
                    num += percents[j] - indexes[j] - 3
            else:
                l[i] = ""

                
        l[i] = l[i].replace(". .", "").replace("..", "").replace("  ", " ")
 
    return l

# %%
re.split("!|\?", "hello pupper?! how are you doing! i'm doing great")
# Out:
# ['hello pupper', '', ' how are you doing', " i'm doing great"]

# %%
def sentence_split_c2015en(l):
    
    start = "<s>"
    stop = "</s>"
    titles = "(?<![A-Z])(?<![A-Z][a-z])(?<![A-Z][a-z][a-z])\."
    k = []
    
    for i in range(200):
        temp = [x.strip() for x in re.split(titles, l[i]) if x.strip() != ""] 
        print(temp)
        if len(temp) == 1: #just 1 sentence, no .
            ex = [x.strip() for x in re.split("!|\?", temp[0]) if x.strip() != ""]
            if len(ex) == 1: #just 1 sentence, no . ? !
                j = ex[0].strip()
                k.append(start + " " + start + " " + j[:len(j)] + " " + stop + " " + stop)
                print(j, i)
            else:
                print(ex, i)
        else:
            for sent in temp: #>= 2 sentences, no .
                ex = [x.strip() for x in re.split("!|\?", temp[0]) if x.strip() != ""]
                
    
    return k

# %%
c2015en = sentence_split_c2015en(c2015entemp)
# Out:
# ['The show stars the X Girls a troupe of talented topless dancers some of whom are classically trained']
# The show stars the X Girls a troupe of talented topless dancers some of whom are classically trained 0
# ['The centerpiece of the show is a farcical rendition of Swan Lake in which male and female performers dance in pink tutus and imitate swans']
# The centerpiece of the show is a farcical rendition of Swan Lake in which male and female performers dance in pink tutus and imitate swans 1
# ['The removal of the barrier between performance and post-production was just as helpful for the actors']
# The removal of the barrier between performance and post-production was just as helpful for the actors 2
# ['assist somebody acting or reciting by suggesting the next words of something forgotten or imperfectly learned']
# assist somebody acting or reciting by suggesting the next words of something forgotten or imperfectly learned 3
# ['Basically it was a fine performance I have only minor quibbles to make about her technique']
# Basically it was a fine performance I have only minor quibbles to make about her technique 4
# ["After it's over we watch the pairs of headlights glide in a neat line back up Main Street dispersing as drivers turn off toward home"]
# After it's over we watch the pairs of headlights glide in a neat line back up Main Street dispersing as drivers turn off toward home 5
# ['After the performance they removed the back wall of the theatre and the cast summoned the audience onstage for an impromptu line dance']
# After the performance they removed the back wall of the theatre and the cast summoned the audience onstage for an impromptu line dance 6
# ['After the end of each performance with paper can be spread the water light on the surface were saved', 'Kids draw']
# ['After the performances a garden party featuring delicious vegetarian food which had been long awaited by many finally began']
# After the performances a garden party featuring delicious vegetarian food which had been long awaited by many finally began 8
# ['The event featured a variety of spectacular performances and was highlighted by the joyful exchange of special gifts']
# The event featured a variety of spectacular performances and was highlighted by the joyful exchange of special gifts 9
# ['The performance simply effected a near imperceptible linear geological displacement']
# The performance simply effected a near imperceptible linear geological displacement 10
# ['Fifteen minutes into the show a bunch of rowdy football players started catcalling several actresses on stage']
# Fifteen minutes into the show a bunch of rowdy football players started catcalling several actresses on stage 11
# ['The show takes off with a bed a mirror a chair and one lingerie-clad beauty and before you know it one sexy lady becomes three']
# The show takes off with a bed a mirror a chair and one lingerie-clad beauty and before you know it one sexy lady becomes three 12
# ['In the beginning the performer sits on the carpet beats the wine cups lightly and begins dancing slowly']
# In the beginning the performer sits on the carpet beats the wine cups lightly and begins dancing slowly 13
# ['Playing catwoman in leopard print lingerie with a long tail and cat ears while sitting in a cage']
# Playing catwoman in leopard print lingerie with a long tail and cat ears while sitting in a cage 14
# ['She was so nervous before the performance that she was shaking like a jelly']
# She was so nervous before the performance that she was shaking like a jelly 15
# ['Acting runs in their blood they have been actors for more than 150 years']
# Acting runs in their blood they have been actors for more than 150 years 16
# ['Acting can be a brutal occupation and it gets harder the further away you veer from the standard ideal of beauty']
# Acting can be a brutal occupation and it gets harder the further away you veer from the standard ideal of beauty 17
# ["Show me a cork that breathes and I'll show you a bottle of vinegar"]
# Show me a cork that breathes and I'll show you a bottle of vinegar 18
# ['Performers Mr. Ding Yi Chief tenor of Sydney Opera House Chief soprano of Sydney Opera House']
# Performers Mr. Ding Yi Chief tenor of Sydney Opera House Chief soprano of Sydney Opera House 19
# ['Show contents and times are subject to change or cancellation without notice due to inclement weather etc']
# Show contents and times are subject to change or cancellation without notice due to inclement weather etc 20
# ['Performing an open-ended analysis internally is often impaired by the expectations brought on by individuals working within the company']
# Performing an open-ended analysis internally is often impaired by the expectations brought on by individuals working within the company 21
# ['When it was all over the blogger handed the robber some money and gave him a hug']
# When it was all over the blogger handed the robber some money and gave him a hug 22
# ['Performance artist Marni Kotak holding doll gave birth to her child at the Microscope Gallery in Brooklyn as part of an art project']
# Performance artist Marni Kotak holding doll gave birth to her child at the Microscope Gallery in Brooklyn as part of an art project 23
# ['Performing arts from life than life life is a source of artistic creation the source of inexhaustible']
# Performing arts from life than life life is a source of artistic creation the source of inexhaustible 24
# ['Drama is important too', 'Placebo injections are more effective than placebo pills and neither is as potent as sham surgery']
# ['Acting gives them an excuse in essence to learn how to express themselves Aronson said']
# Acting gives them an excuse in essence to learn how to express themselves Aronson said 26
# ['This is where the entertainer holds an envelope to his head gives the answer and then opens the envelope and reads the question']
# This is where the entertainer holds an envelope to his head gives the answer and then opens the envelope and reads the question 27
# ['The performers who include singers Barry Manilow and Aretha Franklin are treating spectators Friday to a full concert dress rehearsal']
# The performers who include singers Barry Manilow and Aretha Franklin are treating spectators Friday to a full concert dress rehearsal 28
# ['The performer will bring his own appeal his own sensibility his own writers']
# The performer will bring his own appeal his own sensibility his own writers 29
# ["The performer doesn't have any gunpowder for her cannon", 'So Clifford puffs and helps her out']
# ['The performer put some rise on the cloth and stir-fry it with a small dustpan']
# The performer put some rise on the cloth and stir-fry it with a small dustpan 31
# ['A jockey enthusiastically presented a Stetson horseman hat to the distinguished Chinese guest']
# A jockey enthusiastically presented a Stetson horseman hat to the distinguished Chinese guest 32
# ["The performer's carefree style on the ice won her many friends and a gold MEDAL."]
# The performer's carefree style on the ice won her many friends and a gold MEDAL. 33
# ['Performers splash water during the opening ceremony celebrations of the inaugural Youth Olympic Games Saturday Aug. 14 2010 in Singapore']
# Performers splash water during the opening ceremony celebrations of the inaugural Youth Olympic Games Saturday Aug. 14 2010 in Singapore 34
# ['Performer refers to persons who perform literary and artistic works professionally or not professionally']
# Performer refers to persons who perform literary and artistic works professionally or not professionally 35
# ["The performance is accompanied by the percussion music that only sets off the atmosphere by contrast not limits the lion's movements"]
# The performance is accompanied by the percussion music that only sets off the atmosphere by contrast not limits the lion's movements 36
# ['Table I Timing of effect of GIPET I on human intestinal permeability using urinary excretion of polar sugars as a surrogate marker']
# Table I Timing of effect of GIPET I on human intestinal permeability using urinary excretion of polar sugars as a surrogate marker 37
# ["As an indicator of one's status or taste or lack thereof watches have become the new shorthand"]
# As an indicator of one's status or taste or lack thereof watches have become the new shorthand 38
# ['The ideographic subjectivity and abstractness results in the emphasis in metaphysical reality in novels']
# The ideographic subjectivity and abstractness results in the emphasis in metaphysical reality in novels 39
# ['table-footer-group Table footer is always displayed after all other rows and row groups and before any bottom captions']
# table-footer-group Table footer is always displayed after all other rows and row groups and before any bottom captions 40
# ['Table to have 8 mm thick clear tempered glass with polished edges and sand blasted logo on the top panel']
# Table to have 8 mm thick clear tempered glass with polished edges and sand blasted logo on the top panel 41
# ['Table has a simple structure large-caliber light weight easy to operate and other advantages']
# Table has a simple structure large-caliber light weight easy to operate and other advantages 42
# ['For sustained contributions to circuits systems and signal processing especially his seminal work on wave digital filters']
# For sustained contributions to circuits systems and signal processing especially his seminal work on wave digital filters 43
# ['The characterization results of the catalyst show that the PAS molecular sieve has more pore-size distributions for VGO isomeric']
# The characterization results of the catalyst show that the PAS molecular sieve has more pore-size distributions for VGO isomeric 44
# ['Characterization The ways in which a which a writer reveals the personality of a character id like']
# Characterization The ways in which a which a writer reveals the personality of a character id like 45
# ['To characterize the imaging appearances of epithelioid hemangioma we reviewed the available literature on the subject']
# To characterize the imaging appearances of epithelioid hemangioma we reviewed the available literature on the subject 46
# ['A table-valued object can be a table a view a function a synonym or a local table']
# A table-valued object can be a table a view a function a synonym or a local table 47
# ['Most of the terms in this list are explained in the glossary at the end of this book']
# Most of the terms in this list are explained in the glossary at the end of this book 48
# ['The first column contains the task and the next two columns designate whether or not the task works based on its origin']
# The first column contains the task and the next two columns designate whether or not the task works based on its origin 49
# ['The data of solar radiation in the table were the average of forenoon and afternoon']
# The data of solar radiation in the table were the average of forenoon and afternoon 50
# ['The list of genes was shifted with respect to the expression data so that the one did not correspond with the other']
# The list of genes was shifted with respect to the expression data so that the one did not correspond with the other 51
# ['The series continues to produce total eclipses for two more centuries as the duration of totality gradually dwindles']
# The series continues to produce total eclipses for two more centuries as the duration of totality gradually dwindles 52
# ['Electrical data shown in tables is only a reference standard', 'Actual data may be changed by different using conditions']
# ["The subtotal for each edition is shown as is the customer's total balance"]
# The subtotal for each edition is shown as is the customer's total balance 54
# ['Paste board Board made from several laminations of thinner sheets', 'Contrast to Homogenous board']
# ["You've held out for months waiting and watching the market for some sign of a tablet that you think you'd like"]
# You've held out for months waiting and watching the market for some sign of a tablet that you think you'd like 56
# ["Suffocate me! You don't say I do not say we have to have a talk! We'll I don't go to hell who go to hell", 'I said I love you !']
# ['Gravure is done by engraving or etching version made of chrome-plated will increase the hardness to increase resistance to India']
# Gravure is done by engraving or etching version made of chrome-plated will increase the hardness to increase resistance to India 58
# ['Concaue printing plate cylinder is divided into a shaft of a non-Edition version of the rollers and drum']
# Concaue printing plate cylinder is divided into a shaft of a non-Edition version of the rollers and drum 59
# ['Gravure press in traction roll and is adjacent to the first edition of roll usually have weekly rate synchronization mechanism']
# Gravure press in traction roll and is adjacent to the first edition of roll usually have weekly rate synchronization mechanism 60
# ['Gravure printing in business card printing and membership card when making metallic ink is well-suited for flexo printing in glazing', 'there']
# ['Concaue business card printing and membership card making and engraving gravure and photographic plates']
# Concaue business card printing and membership card making and engraving gravure and photographic plates 62
# ['Nay he cried laughing but we will sell the foul thing for a slave and his price shall be the price of a bowl of sweet wine']
# Nay he cried laughing but we will sell the foul thing for a slave and his price shall be the price of a bowl of sweet wine 63
# ["Don't rely on your opinion of what you think they need do user research to actually find out"]
# Don't rely on your opinion of what you think they need do user research to actually find out 64
# ["Don't let anyone back you into a corner or you may end up in a vulnerable position"]
# Don't let anyone back you into a corner or you may end up in a vulnerable position 65
# ['DONT behave as though disrupting the Olympic torch relay is an unforgivable sin on the part of an entire city or nation']
# DONT behave as though disrupting the Olympic torch relay is an unforgivable sin on the part of an entire city or nation 66
# ["But take care! Don't spill any", 'Because as you know the first bear to fill his bucket wins!']
# ["Eg Don't park your car outside my house you know how people talk!"]
# Eg Don't park your car outside my house you know how people talk 68
# ['Do not imagine that mathematics is hard and crabbed and repulsive to common sense it is merely the etherealization of common sense']
# Do not imagine that mathematics is hard and crabbed and repulsive to common sense it is merely the etherealization of common sense 69
# ["Don't all your savings on fixing up your place", 'Save enough to get out of town']
# ["Don't count him in", 'You know him', 'His determination is always a flash in the pan']
# ['Do not think of it as something utopian something that electorates have to approve in a referendum']
# Do not think of it as something utopian something that electorates have to approve in a referendum 72
# ["Don't lose it in your popcorn", "ICM's boss believes that the internet will lower barriers to entry for new film-makers"]
# ["Don't flurry me my dear Paul said his sister for that destroys me"]
# ["May Don't worry! If you start choking I'll perform the Heimlich Manoeuvre on you!"]
# ["May Don't worry", "If you start choking I'll perform the Heimlich Manoeuvre on you"] 123
# ["Yuna Dont's worry", "Being called Koala doesn't make him any less of a computer expert"]
# ["Don't worry the police won't arrest you because you said something unusual", 'Truth is on your side', "you'll come out scot-free"]
# ["Don't worry Boss with my cataracts you only sort of look like the bad guys"]
# Don't worry Boss with my cataracts you only sort of look like the bad guys 126
# ["Don't worry", "I'll go with you and help you pick something light this year", "I've always wanted to see the New Year Market"]
# ["Don't worry about not making the varsity team you'll always have next year"]
# Don't worry about not making the varsity team you'll always have next year 128
# ['Stop worrying about your piano recital', "You'll cross that bridge when you come to it"]
# ["If your dream strikes you as too improbable don't worry", "If it's possible in your head it qualifies as a good dream"]
# ["Don't worry about the lack of sense of what you write for you can chose to keep or toss out these ideas when the activity is over"]
# Don't worry about the lack of sense of what you write for you can chose to keep or toss out these ideas when the activity is over 131
# ["Don't worry about it", 'With your kerchief and your clothes you look very feminine']
# ["Don't worry about opposition from those groups", 'You are doing the right thing', 'A kite rises against the wind']
# ["Let's apply gray eye pencil to the outside half of your upper eyelash line first", 'Then use your finger to smudge the line']
# ["Don't worry no one would blame you if you mistook it for the scent of freshly mown grass when smelling a Haitai coffee for example"]
# Don't worry no one would blame you if you mistook it for the scent of freshly mown grass when smelling a Haitai coffee for example 135
# ["Don't worry she laughed looking down at his feet Your brilliance saved the day"]
# Don't worry she laughed looking down at his feet Your brilliance saved the day 136
# ["Don't worry Senora the commando told her", "We aren't fighting a war on children"]
# ['don t worry ! the weatherman says we ll have a cold spell before the end of this week']
# ['don t worry', 'the weatherman says we ll have a cold spell before the end of this week'] 138
# ["Don't worry", 'In deference to you I kept them all at a high school graduate reading level', 'Thanks pal']
# ["Don't worry", "I'll take out the map from the glove compartment and take a look", 'Uh where are we?']
# ["gnome don't worry my wooden friends! you are well-protected against any lightning attacks!"]
# ["gnome don't worry my wooden friends", 'you are well-protected against any lightning attacks'] 141
# ["Don't worry I'll help you! said the bear", 'He put the mouse into his pocket and continued to run']
# ["Never mind I'll find someone like you", 'I wish nothing but the best for you too']
# ["Don't worry I'll have someone look at it this afternoon and in the meantime I'll have your documents re-faxed to other fax machine"]
# Don't worry I'll have someone look at it this afternoon and in the meantime I'll have your documents re-faxed to other fax machine 144
# ["To help you designers out there we've researched different design sectors to see which one has the most fulfilling unicorn-friendly jobs"]
# To help you designers out there we've researched different design sectors to see which one has the most fulfilling unicorn-friendly jobs 145
# ["Don't worry we were told even a golf club has one of those it's just a name"]
# Don't worry we were told even a golf club has one of those it's just a name 146
# ['t worry about it', 'A little wear and tear is to be expected']
# ['Do not worry about Iran', 'Iran will teach lesson to any aggressor', 'You will see China and Iran will lead the world']
# ["BC Don't worry I'll take the heat for you son", 'But what these folks have to say is important for my daughter to hear']
# ["Don't worry", 'In a couple of days therell be too much to do', "Then you'll want to be back in these lazy days"]
# ['It will not be the end of the world at least not far quite a while yet but the world will slowly become a different place']
# Other acne products I do not know but I feel like a spring of acne products indene fine ah do not you know 172
# ["Another person still just such as month princess but is to can't wait for person's message of reply shout 1 to intrude into building"]
# Another person still just such as month princess but is to can't wait for person's message of reply shout 1 to intrude into building 173
# ['Moreover the standards of stylistic acceptability for various types of discourse differ radically from language to language']
# Moreover the standards of stylistic acceptability for various types of discourse differ radically from language to language 174
# ['Other humans had deserted him and mistreated him but now he had a friend and his appreciation was more than obvious']
# Other humans had deserted him and mistreated him but now he had a friend and his appreciation was more than obvious 175
# ['The otheR deities were vexed beyond words but dared attempt no rescue for all heR piteous cries']
# The otheR deities were vexed beyond words but dared attempt no rescue for all heR piteous cries 176
# ['Anything else can be shelved also and then a smile of self-mockery sleep bar']
# Anything else can be shelved also and then a smile of self-mockery sleep bar 177
# ['Other Web sites let users exchange goods and services or barter', 'In this ancient form of trade no money changes hands']
# ['Many another fellow in his place would have been a constant drag on his parents']
# Many another fellow in his place would have been a constant drag on his parents 179
# ['Other researchers have systematically mutated each of the 6600 genes in yeast and observed how the mutant yeast fare under different conditions']
# Other researchers have systematically mutated each of the 6600 genes in yeast and observed how the mutant yeast fare under different conditions 180
# ['Another man may be sickle too and sick to death and this affliction may lie in his bowels as gold in a Mine and be of no use to him']
# Another man may be sickle too and sick to death and this affliction may lie in his bowels as gold in a Mine and be of no use to him 181
# ['Some other people uploaded this if it? is okay with you just letting you know', 'Also awesome', '-w']
# ['Another popular evergreen plant is mistletoe', 'It has small white berries and leaves that feel like leather']
# ['The other fisherman get more fish than he does make more in profits and will ultimately deplete the fish population anyway']
# The other fisherman get more fish than he does make more in profits and will ultimately deplete the fish population anyway 184
# ['Other patterns include super cardioid very directional which may be useful if you want to tighten up the sonic picture']
# Other patterns include super cardioid very directional which may be useful if you want to tighten up the sonic picture 185
# ['Do not Deng! West Lu not lower the head use claw son Nao Nao eyes Wei Wei Anne of the head continuously screams along with his action']
# ['Do not Deng', 'West Lu not lower the head use claw son Nao Nao eyes Wei Wei Anne of the head continuously screams along with his action'] 186
# ['There will be a time when we have only memories to cling to']
# There will be a time when we have only memories to cling to 187
# ['No wait I want to now', 'Let me freshen up a bit']
# ['Tell me not in mournful numbers Life is but an empty dream! For the soul is dead that slumbers And things are not what they seem']
# ['Tell me not in mournful numbers Life is but an empty dream', 'For the soul is dead that slumbers And things are not what they seem'] 189
# ["Don't look at me Daisy retorted I've been trying to get you to New York all afternoon"]
# Don't look at me Daisy retorted I've been trying to get you to New York all afternoon 190
# ['â€œDonâ€™t leave me â€ she cried hysterically as he rushed off to reconnoitre the vicinity']
# â€œDonâ€™t leave me â€ she cried hysterically as he rushed off to reconnoitre the vicinity 191
# ["Please don't tamper with my computer I don't want to lose any of the files that I saved"]
# Please don't tamper with my computer I don't want to lose any of the files that I saved 192
# ["Don't move it", "Eve said I'll get a bucket of water", "She hurried off to the butler's pantry her heart pounding with a fearful joy"]
# ["Don't tease he said unsteadily", 'You know how dangerous it is']
# ["Don't try to be too clever with Fred If he thinks you're fucking him around he'll clobber you"]
# Don't try to be too clever with Fred If he thinks you're fucking him around he'll clobber you 195
# ['Do not take life too seriously', 'You will never get out of it alive']
# ['Do not be fussy about what he did', 'After all he is only a child']
# ['t be fussy about what he did', 'After all he is only a child']
# ["Don't be so strict with him", 'After all he is just a child']

# %% [markdown]
# `CASIA 2015` dataset:

# %%
os.chdir(path + "/casia2015")
files = glob.glob("*.txt")

c2015entemp = process_c2015en(open(files[1], "r", errors = "ignore").read().split("\n"), conts, nopunct, exclude, e)

# %%
lol = open(files[0], "r", encoding = "utf-8").read().split("\n")
#for i in range(len(lol)):
    #lol[i] = lol[i].encode("unicode-escape").decode("utf8")
    #for j in i:
        #print(j.encode("unicode-escape"))
        #j = j.encode("unicode-escape")

# %%
for i in range(len(lol)):
    print(lol[i], i)
# Out:
# 表演的明星是X女孩团队——由一对具有天才技艺的艳舞女孩们组成，其中有些人受过专业的训练。 0
# 表演的压轴戏是闹剧版《天鹅湖》，男女小人们身着粉红色的芭蕾舞裙扮演小天鹅。 1
# 表演和后期制作之间的屏障被清除了，这对演员来说一样大有裨益。 2
# （表演或背诵时）通过暗示下面忘记或记地不准的东西来帮助某人。 3
# 表演基本上很精彩--我只对她的技巧稍有意见。 4
# 表演结束后，我们看到一对对车灯沿主路一路排回镇上，然后散开来各回各家。 5
# 表演结束后，移走了背景墙，随后全体演员即兴邀请观众上台齐跳并排舞。 6
# 表演结束后用宣纸轻铺水面，可将水面上的画进行拓印保存。 7
# 表演结束后，众人期待已久的园游会终于正式开锣，美味可口的素食佳肴让大家一饱口福。 8
# 表演节目丰富精采，交换礼物的欢乐时刻一到，则形成另一波高潮。 9
# 表演仅仅是造就一个近乎觉察不出来的「直线的地质的移位」。 10
# 表演开始十五分钟后，一帮足球运动员开始集体向着舞台上的女演员发出嘘声。 11
# 表演开始时，舞台上会有一张床，一面镜子，一张椅子以及一位穿着内衣的美女。在你觉察到前，一位性感的女孩会突然变成三位。 12
# 表演开始时，艺人坐在地毯上轻击盅子，徐缓起舞； 13
# 表演“猫女”——在一个笼子里穿着带有一根长尾巴和猫耳的豹纹女内衣。 14
# 表演前，她紧张得浑身颤抖不已。 15
# 表演是他们的嫡传技艺，150多年来他们家族一直都是演员。 16
# 表演算得上是一门残忍的职业，你偏离正统美越远，就越艰难。 17
# 表演我软木塞哪一呼吸和我将表演你一瓶醋。 18
# 表演：悉尼歌剧院首席男高音丁毅先生悉尼歌剧院首席女高音 19
# 表演秀以及开园时间有可能因故不经预告而取消或中止，敬请留意。 20
# 表演一个不限分析国内受损的期望往往带来了个人工作的公司。 21
# “表演”一结束，他马上给那名黑人“歹徒”发工钱，然后两个人还握手拥抱。 22
# 表演艺术家MarniKotak（持玩偶者）在布鲁克林的“显微镜”画廊生下一婴作为她艺术作品的一部分。 23
# 表演艺术来源于生活而高于生活，生活是艺术创作的来源，取之不尽用之不竭的源泉。 24
# 表演在安慰疗法中也很重要。安慰性注射虽然比安慰药丸有效果，但是却没有虚假手术来得见效。 25
# “表演在本质上给了他们一个正当的理由去学习如何表达自己。”阿伦森说。 26
# 表演者把信封靠近他的脑袋，然后先给出答案，再打开信封，读问题。 27
# 表演者包括歌手马尼洛和富兰克林；歌手们星期五将向观众献上一场彩排。 28
# 表演者会带来他自己的吸引力，他自己的感性，他自己的作者。 29
# 表演者没有大炮火药了，于是Clifford吹气把她发射出去了。 30
# 表演者拿一个小簸箕在上面炒，过一会，爆米花就出来了。 31
# 表演者热情地向中国贵宾赠送斯特森骑士帽。 32
# 表演者在冰上的那种潇洒的风格为她赢得了许多朋友和一块金牌。 33
# 表演者在开幕典礼庆祝活动溅水的首届青年奥运会星期六2010年8月14日在新加坡举行。 34
# 表演者，指演员或者其他表演文学、艺术作品的人。 35
# 表演中用打击乐伴奏，但狮舞的动作不受音乐节奏的限制，音乐只起烘托气氛的作用。 36
# 表一：对人体肠道的通透性，作为替代标记使用极地糖尿execretionGIPET我的时间。 37
# 表已经成为有身份或有品味——抑或是身份或品味低下——的新标志。 38
# 表意的主观性和抽象性导致小说偏向表现“形而上的现实”。 39
# 表英尺组表页脚始终显示在其他所有行和行组，和之前的底部字幕。 40
# 表有8毫米厚的明确钢化玻璃与抛光边缘和沙丘抨击标志的顶端小组。 41
# 表有结构简单、口径大、重量轻、操作方便等优点。 42
# 表彰他在电路，系统和信号处理，尤其是数字滤波方面的贡献。 43
# 表征的结果显示PAS分子筛具有更多的适合蜡分子异构化反应的孔径分布。 44
# 表征的途径，其中一项是作家揭示了这样一个人物身份证的个性。 45
# 表征影像学表现上皮样血管瘤，我们审查了现有文献关于这一主题的。 46
# 表值对象可以是表、视图、函数、同义词或本地表。 47
# 表中的大多数术语在本书最后所附的“名词汇编”中均有说明。 48
# 表中的第一列包含任务，后面两列指明任务是否在其原始平台上进行操作。 49
# 表中光照度数据为上午和下午两次观测值的平均值。 50
# 表中基因的一列相对于表达数据发生了调换，导致两项不相对应。 51
# 表中继续述说着两个甚至更多世纪的全食，然而持续时间逐渐减少。 52
# 表中所列电参数为参考值，实际电参数会因使用条件的不同而变化。 53
# 表中也显示了每个版本的小计以及顾客的总费用。 54
# 裱糊纸板：用多张较薄纸板裱贴而成的纸板。有别于均质纸板。 55
# 憋了几个月，等啊等，等待市场推出一款你钟爱的平板电脑。 56
# 憋死我了！你也不说，我也不说，咱俩总得有一个来挑明吧！算了，我不下地狱谁下地狱。我说了“我爱你”！ 57
# 瘪版是堵住雕镂或蚀刻制成的，制成的版镀铬后会补充硬度，以提矮耐印度。 58
# 瘪印版滚筒不合为有轴版滚筒和无轴版滚筒。 59
# 瘪印机洋牵引辊与初版辊相邻凡是撤有周速同步机构。 60
# 瘪印在制卡和会员卡制作金属油墨时不入格得当。柔印在上光方面也有其独到之处。 61
# 瘪制卡和会员卡制作又不合为雕镂不不凸版与拍照印版两栽。 62
# “别啊，”他喊道，冷笑着，“我们可以把这脏东西当奴隶卖了呀，正好可以换一碗酒钱呢。” 63
# 别按你自己的想象认为他们需要什么；做些用户研究去确切地发现他们所需。 64
# 别哭了，赫德森太太.子弹真要出膛眼泪也挡不住.不然世界可真是个温柔乡啊 321
# “别哭了，”她说，“你知道水对你伤害很大。” 322
# 别哭了。我会慢慢收获你的悲伤。我有时间去发现让你悲泣的原由。 323
# 别哭，你是我们的英雄，我知道金牌对于你来说很重要，其实胜利与否真的无所谓。 324
# 别哭泣，别叹息，别呻吟；悲伤唤不回流逝的时光。 325
# 别哭泣，别叹息，别呻吟；悲伤唤不回流逝的时光。（爱尔兰剧作家弗莱沏。J。） 326
# 别哭泣，别叹息，别呻吟；悲伤唤不回流逝的时光。---约翰.弗莱彻，英国剧作家。 327
# 别哭泣，别叹息，别呻吟。悲伤唤不回消逝的时光。 328
# 别哭泣，别叹息，别呻吟；悲伤也唤不回流逝的时光。 329
# 别哭泣，也别叹息，别失意，悲伤换不回失去的时光。 330
# 别拉斯汽车液压系统常见故障及处理 331
# “别来这一手啦，布洛德，”卢克开始这么说，他准备要着手好好进行一番真刀真枪的科学辩论。 332
# 别赖在沙发上了，做事变得高效一点吧，那才是应该过的生活。 333
# 别浪费水，否则多年以后地球上就没有水可供我们使用了。 334
# 别浪费我的时间来告诉我堕胎是错误的，不如告诉我有甚么更好的方法，及你们如何推广这些方法。 335
# 别老穿这件条纹T恤，你看上去像大黄蜂。 336
# 别老惦念着孩子们，他们已经长大，自己会照顾自己了。 337
# 别老盯着我工作。挺烦人的，而且我也无法集中注意力。 338
# 别了，母校，我们航行再远，总与您遥遥相望！ 339
# 《别了，武器》一书虽然在细节描写方面刻意求实，而且有一个悲剧性的结局，但它仍然是一部理想主义的著作。 340
# 别离的泪水，为记忆的长河增添新的浪花；别离的祝福，为再—次相聚拉开了序幕。 341
# 别离我太远，也别和我太近，这个距离便好。淡淡的感觉在我视线之内驻扎，在我心的一角静泊。 342
# 别理解错了，我可受不了周围堆满混乱一团的杂物。 343
# 别林斯基：《别林斯基选集》第1卷，满涛译。上海：上海译文出版社，1979年。 344
# 《别林斯基选集》第2卷，满涛译。上海：上海译文出版社，1979年。 345
# 别留下黑色羽毛作为你的灵魂谎言的象征！ 346
# 别留下我一个人！尼维尔马上爬起来，我不想一个人呆在这里。刚才吸血鬼巴伦已经来过两次了。 347
# 别骂自己的孩子是小兔崽子，因为从遗传学的角度来讲，这对家长是不利的。 348
# 别忙着在明天早晨8点打电话给一家华尔街银行去咨询业务。 349
# 别冒傻气了，你爸爸刚14岁就辍了学，这使他后悔了一辈子。 350
# 别名或用户定义的类型所属的架构名。 351
# 别名「机会大地」（LandofOpportunity）的阿肯色于1836年添加联邦，成为美国第25州。 352
# 别名可以是以句点分隔并且中间没有空格字符的组合。 353
# 别名是一种简单的机制，允许您为给定的序列提供展开形式。 354
# 别名数据类型或用户定义类型所属架构的名称。 355
# 别名「鹈鹕之州」（PelicanState）的路易斯安那坐落在南方腹地，它拥有多采多姿的历史，是为纪念路易十四（KingLouisXIV）而得名。 356
# 别名往往是一个缩短了的表名，用于在联接中引用表的特定列。 357
# 别名「阳光之州」（SunshineState）的佛罗里达以其宜人、和煦的天气及美丽的海滩闻名于世。 358
# 别名，以便更易于将标识符限定到命名空间或类型。 359
# 别名允许访问可能被代码中的实体隐藏的根命名空间。 360
# 别拿话儿搪塞我们，我们只是想知道你到底是同意还是不同意。 361
# 别拿我们开心了，问问你们自己的兄弟姐妹或是子女，不是更直接吗？。 362
# “别那么草率嘛”！他说到。“你至少看一下我给你示范一遍。” 363
# 别那么嫉妒好不好，在我面前他可从没说过你的坏话。 364
# “别那么叫我！我不是你妈。你只是一个脏老头。” 365
# 别那么紧张。你说的都是对的，不会招致任何批评。 366
# 别那么敏感，只是随口问问，我发现你在看伴郎。 367
# 别那么软弱。知道吗？你应该看看史密斯医生。她很棒的。 368
# 别那么生你母亲的气了，毕竟，她只是想帮助你而已。 369
# “别，”那女仆说，“丁太太，对这个漂亮的小姑娘别这么凶吧。 370
# 别那样看着我，”——海德薇大大的琥珀色眼睛里充满了责备——“又不是我的错。 371
# 别那样看着我，你知道我从不吹嘘 372
# 别那样说啦！这全是命运带来的偶然！ 373
# 别那样，这是抽签抽到的，可不是我主动争取的。 374
# “别难过，”Finklestein弥留之际说，“我已经过了八十年好日子。” 375
# 别难过皮特：《钢铁侠》主角小罗伯特唐尼也没拿到那个角色。 376
# 别难过，作者只不过比你早几年、多几次惊慌而已。 377
# “别闹了，”凌霄回身看她，“李小涵，在你眼里最贵的衣服是什么牌子的？” 378
# 别闹笑话…详细的你可以百度网页搜下蔓妮韵瘦身贴官网看看。 379
# 别怕丢人，那是一种成功的尝试，不要笑话那些上台丢人的人。 380
# 别怕，接下来的几分钟，我会帮你解除魔咒，助你摆脱这种不体面的境地。 381
# 别怕。您只会觉得一点小小的刺痛。我现在给你消毒手指。好了，做完了，疼吗？ 382
# 别怕伤害我的感情，直说吧，医生，我也许则得了癌症了？ 383
# 别怕缩短文章。你应该把这段删去，把那段缩短一些。 384
# “别碰帽子，”她的客人说。她转过身去，看见他已抬起头，正看着自己。 385
# “别碰我！”嘉莉说着挪开身子，但是仍用手帕捂着眼睛。 386
# “别骗我。”桃金娘喘着气说，眼泪滔滔不绝地滚下面颊，皮皮鬼在她身后快活地咯咯直笑。 387
# 别嘌呤醇、抑制尿酸的合成--它可以用于治疗代谢综合征及相关的疾病吗？ 388
# 别期望你迟到而其他人顶上，因为有一些工作要等着你来处理完，别人才能进行。 389
# 别杞人忧天了，你要学会看开一点。 390
# 别气馁，毕竟，你在这个领域是个新手。 391
# 别气馁，你得到的通常是马上就可以打开未知出路的钥匙。 392
# 别请乔伊来参加这次聚会。他这人对人太冷淡，太不友好。他来了会使其他所有人都扫兴的。 393
# 别去拆房子，要检视每块砖，并且换掉那些看来残破而不再能支撑那结构物的。 394
# 别去打听别人想要保守秘密的事。 395
# 别去惊动它，孩时的那份记忆太完美，无论今后的任何一种可能的相见都不能给它续添上貂尾。 396
# 别去问值还是不值，生命的价值从来不是用交换体现。 397
# 别去用勺子盛托盘上的饭，盛碗里的饭。 398
# 别太得意，老头子。要吹牛就尽量吹个够，我可不想碰你那满是皱纹的皮。 553
# “别太放松了，”第二个野游者回答，“我已经迷路三周了”。 554
# 别太客套了。我真是受宠若惊了！我看着很年轻，实际年龄真的比较大。 555
# 别太引以为自豪了。那个女孩子说不定就是你的祸水呢。 556
# 别太在意别人看法，事实可能已被好奇心之浮云遮住。 557
# 别太责备他。他毕竟还是个孩子。 558
# 别太自信了！我需要准备好，所以给我拿来四位神的小雕像。 559
# “别，”桃金娘的声音从另一间小卧室中低吟着。“不要这样……告诉我出了什么事……我可以帮助你……” 560
# 别提集邮的事，否则约翰准会把他全部的收藏都拿出来向大家炫耀。 561
# 别提了！随后。在经过了我人生中最长的一天后。我们预订的旅馆又是低廉而肮脏的！ 562
# 别提了。我表弟今天结婚，以为老板能准假，没想到却碰了一鼻子灰。 563
# “别提了！我犁了十天的地，”刁颤栗着说。 564
# 别提了。我是咱们班女生中唯一还没结婚的。我是白领没错，过得却是黑生活。 565
# 别提了。昨天我家旁边的工厂不断发出噪音一整天，如果没有耳塞我可能就聋了。 566
# “别提那该死的狮子了”他吼道“你们哪个白痴他妈的放了那只公牛？” 567
# 别提起战争的话头，一提起他会滔滔不绝地说起他在第二次世界大战中的经历。 568
# 别天真了，波斯人，在斯巴达你一样都供不起。 569
# 别天真了，波斯人。在斯巴达，你一样也给不了。 570
# 别挑剔了！你未必可以找到另外一个待遇这么好的工作！ 571
# “别听那傻姑娘唠叨了，维尔福，”侯爵夫人说，“她不久就会听惯这些事情的。” 572
# 别听他说的，人们是因为想嘲笑他所以才出钱让他这样的。 573
# 别听她的。凯莉，这才过了一个月。要想忘记一个人，你得花上跟他交往的时间的一半。 574
# 别停下来弯起你的小手指边吃边傻笑，艾美，”乔嚷道，她因为急不可耐地要听信，被茶噎了一口，涂了奶油的面包也掉落到地毯上。 575
# 别同我讲家庭教师了，听见这个名词就让我火冒三丈了。 576
# “别推我，”其中的一个罢工工人坚决地说，“我可没干什么。” 577
# “别推我，杂种，”他说。“我要告诉爸妈！” 578
# 别拖延，不久就得履行另外一项义务而干扰你的学习，在此之前尽所能了解。 579
# 别忘记，谦逊是盾牌，抵御肮脏者的眼。 580
# 别忘记我的成长会很迅速。跟上我的成长步子也许有些困难，但请你努力跟上。 581
# 别忘记我的茁壮成长离不开很多的理解和爱护，刚好这些你从来不缺，我不用再告诉你了，不是吗？ 582
# 别忘记下周五的“义卖”，所以我们会为这项有趣的活动准备一些课程。 583
# 别忘了：OSXLion将只发布数字版（事实上，这也是整个故事中，唯一确认了的一点）。 584
# 别忘了带上你派对礼服，去参加夜间回程路上的鸡尾酒会。 585
# 别忘了给Web部件“打扮”一下，因为如果不这样的话，你的Web部件看起来会很乏味的。 586
# “别忘了给汤姆带根烟。”一战期间英国的一支爱国小调这样唱。 587
# 别忘了给我寄张明信片来，多拍一些照片。 588
# 别忘了，孩子会模仿你做事，而不是做那些你告诉他应该做的事。 589
# 别忘了，没有机器是完美的，不会，因此，转换所有能源成有用的能量提交给它供您使用。 590
# 别忘了明天晚上的约会。明天下班等我叫你一起走。 591
# 别忘了日本不会放弃任何对美国进行核报复的机会。 592
# 别忘了如今即使是2%-4%的债券收益率也并不像看起来那么微不足道，因为通货膨胀依然接近于零。 593
# 别忘了，上帝的慈爱每早晨都是新的，他的怜悯也在你的生命中动工，给你祝福并荣耀他的名。 594
# 别忘了是谁给你神位的。你休想背叛我。 595
# 别忘了，他上周末不是刚刚在伐夫郡举行的G20会议中提议征收托宾税吗？ 596
# 别忘了，微软在企业界的地位根深蒂固，将Windows改为其他操作系统成本不菲。 597
# 别忘了，我的宝贝，你还不到十七岁，对幸福丧失信心还为时过早。 598
# 别忘了我们还有两个超级明星处于伤病之中，他们的名字是迈克尔-巴拉克和安大略-舍甫琴柯。 599
# 别忘了香港现在属于中国，那些想在香港拥有西方民主不要再做梦了。 600
# 别忘了雪是一个反射性的表面，它将反弹非常多的光线。 601
# 别忘了要把这些拿出来分享，因为它们也许就激发了学校方面的足够兴趣，为你争取到位于迪伦楼的面试机会。 602
# 别忘了要记得提醒公司帮你申请劳保喔。 603
# 别忘了，一二十年前，AOL和Microsoft和今日的Google们一样风光无限：那时的她们看起来如此有活力，似乎永不会停滞。 604
# 别忘了远方的故友，你想不出他有多么想你。 605
# 别忘了，这些哥特大教堂属于那个时代最高的建筑之列，因而其宏伟的建筑正面和硕大的内部空间在当时或许更加令人敬畏。 606
# 别为摆阔炫耀而追求财富，只挣你取之有道、用之有度、施之有乐且遗之有慰的钱财。 607
# 别为此太过于纠结了，因为大多数这类的问题发生仅仅是因为女人们也常像男人们一样不回电话…… 608
# 别为了满足于他们的要求而以牺牲自己为代价。 609
# 别为难了，还是打开电视或者翻翻杂志来找点灵感吧！ 610
# 别为你儿子担心，他已到了可以独立谋生的年龄。 611
# 别为他的离开难过了，我很清楚，他走了你很高兴。 612
# 别为这点小事大惊小怪的，这可是我最不希望看到的事。 613
# 别问警察怎样去伦敦西区最快，也别问他如何使用牡蛎交通卡。他也很想帮你，不过他是从西米德兰兹郡来的。 614
# 别问我，为了爱情承受了几度煎熬， 615
# 别问我细节了。我将设个陷阱将其抓获。 616
# 别恶心，你在夸我还是贬我？小虾米配龙虾酱是谁的？。 617
# 别误会你是名很优秀的插图画家，但这并非我所谓的艺术 618
# “别误会，”他说，“没有什么能阻止我对你的爱。剪掉头发不会改变我对你的感情。” 619
# 别误解了我的意思：我对任何能够经得起时间考验的情感都很赞赏。 620
# 别瞎说，盖文神父对不起，不过那是事实 621
# 别瞎说了。你知道，你这么一说我就开始害怕了。 622
# 别瞎说了！他是最不可信赖的人。 623
# “别瞎说了，”推销员不在意地说，“从打我们住到这里起，他总共只来过五六次。” 624
# 别吓我，好不好？你别吓我，好不好？你在的，是吗？你告诉过我你会在的！会在的！ 625
# 别响！你没有危险——可要是你妨碍我——林惇，我爱爸爸胜过爱你！ 626
# 别想当然地以为人类发明的技术就一定会服从于人类。三思吧。 627
# 别想和他比赛，因为他靠弄虚作假得分。 628
# 宾汉在被押往船上的途中，遇见了拿撒勒人耶稣，耶稣的怜悯使宾汉心中燃起了希望之火。 815
# 宾克穿过一片海燕麦田，他听到燕麦发出欢快的窸窣声和汩汩的海潮声。 816
# 宾克的脑海里立刻浮现出了往事——一些赞斯鲜活的民间传说。 817
# 宾客纷至、车来轿往、兴师动众，已成为禹州地方士绅的沉重负担。 818
# 宾客服务中心员工记下房号和名字，稍后让前台回电， 819
# 宾客关系主任向前厅部交上各种表格以便记帐。 820
# 宾客将依次序由大门开始，行经大厅和房间，最后以庭院为终点。 821
# 宾客可以品尝到价格仅为人民币118元另加15%服务费的两道式午餐，含茶或咖啡。 822
# 宾客们不仅有机会获赠书法大师的定制作品，而且还能品尝到茶艺师傅优雅地沏好的中国茶。 823
# 宾客们顿时觉得似乎有一朵乌云从黑纱后面滚滚而来，遮住了花烛的光亮。 824
# 宾客们要不围坐在有藤顶遮盖的长折叠桌旁，要不就在一块土质夯实的空地上跳舞。 825
# 宾客名单仍在草拟当中，会有更改，但目前的情况是这样（说奥巴马先生将不被邀请）。 826
# 宾客是在用完正餐之后参加酒会，餐后酒会通常可以不供应食品。 827
# 宾客同样可尽享自在的生活空间，舒适的座椅、墙挂式40寸液晶电视及DVD播放器配备环绕立体声播放系统； 828
# 宾客允许新人进入洞房之后，马上闯入（洞房）并抢走新娘的一只长袜。 829
# 宾客这么少，希望小姐们见谅，并且向她们保证：以后决不会再发生类似情况。 830
# “宾客至上、服务第一”是我们的宗旨，我们将为阁下提供优质的服务，使您住得舒服、放心。 831
# “宾客至上，服务第一”是我们一贯的宗旨，我们热诚欢迎您的光临！ 832
# 宾客中有一个沉静和蔼的人戴着无边眼镜，看起来象大学教授。 833
# 宾客住店，要主动出示有效证件，办理登记手续。 834
# 宾拉登的声明说，漫画是讨伐伊斯兰的新十字军征战的一部分，罗马教廷在其中扮演著重要和长期的角色。 835
# 宾利先生仪表堂堂，大有绅士风度，而且和颜悦色，没有拘泥做作的气派。 836
# 宾利现在使用全球品牌指引，以保持其品牌表达了相同的高标准，因为它适用于其产品。 837
# 宾尼先生说，嘿你们这些小孩不知道在那里晃悠很危险吗？ 838
# 宾斯是板球好手，青年的时候曾代表郡比赛。 839
# 宾特利汽车有限公司成立于1919年，当时资本很少，公司在接下来的10年都将处于一个困境。 840
# 宾：我们可以，但我们不就得冒著水货市场和我们削价竞争的风险吗？ 841
# 宾夕法尼亚车站昨天挤满了上下班的旅客，等待消息。行车时刻已因楼宇倒塌完全混乱。 842
# 宾夕法尼亚大街两边的决策者们将从重新评估台海局势受益。 843
# 宾夕法尼亚大学的研究人员发现，有一些基因变异出现在与细胞排废系统有关的基因中。 排废系统的作用可能是使‘粘附’蛋白质能够正常工作。 844
# 宾夕法尼亚大学法学院的二年级学生程（AnnieCheng）说，兼职教授不谈没用的东西。 845
# 宾夕法尼亚大学帕克分校的地球科学家凯文·弗朗称，这是个“有趣的”结论。 846
# 宾夕法尼亚大学研究的目的不是为了指责新闻媒体，而是评估平常媒体对癌症治疗报道的基础。 847
# 宾夕法尼亚的判决条例要求对于这类罪行的处罚最低为两年，24个月。 848
# 宾夕法尼亚和佛罗里达的案件受到一些美国人的谴责：这个法案原意是要保护孩子的，可是现在却让孩子们成为受害者。 849
# 宾夕法尼亚殖民地的铁匠们不仅既铸造了铁器，同时也铸就了一次具有工业与政治影响的革命。 850
# 宾夕法尼亚州60岁的商业经理说，我们现在采用一种观望的态度。 851
# 宾夕法尼亚州大学的一位语言学教授希望将出行边界应用于自己的地域方言界线研究。 852
# 宾夕法尼亚州，费城自然科学学院，一只大壁虎把自己悬挂在培养箱顶面上。 853
# 宾夕法尼亚州葛底斯堡的士兵国家博物馆，曾是一家孤儿院，据说其雇员在地下室用链条锁住儿童。 854
# 宾夕法尼亚州给赌博经理支付的薪酬是在各个州中最高的（平均一年91,850美元），但是只有50个州有这个职业。 855
# 宾夕法尼亚州哈弗福德学院的斯蒂芬·鲍恩和普林斯顿大学的托尼·罗思曼，向arXiv预印本文献库提交了一篇论文，对这一问题进行了调查。 856
# 宾夕法尼亚州立大学（PennsylvaniaStateUniversity）教授丹尼斯?西蒙（DenisSimon）表示：“他们发了一点点牢骚，但并没有大举撤出中国。” 857
# 宾夕法尼亚州立大学的艾伦?沃克说：“这些骨骼都属于很古怪奇特的生物。 858
# 宾夕法尼亚州免费覆盖到那些收入在官方贫困标准两倍以下的家庭。 859
# 宾夕法尼亚州西南部一自治村镇，位于莫农加希拉河沿岸，匹兹堡的近郊。人口21,923。 860
# 宾夕法尼亚州选民原来以为自己州的初选可能是竞选活动的尾声。 861
# 宾夕法尼亚州一名学校枪击事件的十几岁的嫌疑犯的母亲正面临着提供武器的指控。 862
# 宾夕法尼亚州中部的一城市，位于哈里斯堡以北。19世纪作为伐木业中心发展起来。人口31,933。 863
# 宾夕法尼亚州州长请求总统在典礼上说点什么，林肯同意了。 864
# 宾也记得和当地的印第安人和平交互，为美国未来画下草图，他可算是美国宪法的先驱。 865
# 宾语领先句在现代哲学中，你会发现这种晦涩朦胧太多了 866
# 宾致葡萄酒俱乐部（原9+1葡萄酒俱乐部）立足北京，致力于葡萄酒文化的推广。 867
# 宾州Ligonier所举办的高地竞赛，让许多沉重运动员有机会在各个项目中一较究竟。如：掷树比赛。 868
# 宾州大道是美国最「重要的街道」，也是联邦最早兴建的道路之一。 869
# 宾州大学的罗伯·巴里斯说：“人们会认为有伤疤的人更勇敢、无畏，或者更男性化。” 870
# 宾州大学华顿学院的学生喜欢在校园里辩论伦理问题。 871
# 宾州大学拥有全世界最负盛名的商学院、良好的住宿制度，以及多样化的学生群。 872
# 宾州的选民知道，他们的选择最终具有历史意义，美国主要政党将第一次提名一位妇女或者非洲裔美国人作为总统候选人。 873
# 宾州费城城市命名，这是希腊的兄弟爱（哲学，“爱”或“友谊”，并adelphos，“兄弟”）。 874
# 宾州滑岩大学将为从墨西哥返回的学子单独举行毕业典礼。 875
# 宾州警察局称，有个闷墩用小口径手枪打耗子，耗子没打到，子弹却伤了女朋友。 876
# 殡仪员麦克安排我们坐在一张胡桃木色桌子旁，叹了口气说：“医院联系过我了。” 939
# 殡仪员啪地关上灵车车门，准备上车就座，出租马车的人喊道：“绕道上山，汤普森，马车才不会太颠簸。” 940
# 殡仪执事们来了，抬起那棺材，里面却没有东西。 941
# 殡葬员说染料对他的眼球起了种奇怪的作用，把它们彻底变白了，彻底到连虹膜的褐色和瞳孔的黑色都被漂白了。 942
# 殡葬中心一名工作人员在冷库里发现了一个空袋子，里面原本应存放有这名士兵的踝骨碎片。 943
# 髌股关节疼痛，压轧感以及交锁是全膝置换术后不常见的症状。 944
# 髌股关节相对面可见小的骨赘，右侧膝关节更明显。 945
# 髌骨股骨关节成形术失败后行TKA可能会一种打捞作业，所以，仔细选择病人很重要。 946
# 髌腱旁小切口治疗胫骨髁间棘骨折 947
# 鬓角长度要留得适中，蓄至耳部中间的位置即可。鬓角越长，脸就越显瘦长，而反之亦然。 948
# 兵丁们把一个人的双手钉在它上面。第三棵树明了自己被用来施行一个残酷 949
# 兵丁拿苦胆调和的酒，给耶稣喝。他尝了，就不肯喝。 950
# 兵丁受了银钱，就照所嘱咐他们的去行。这话就传说在犹太人中间，直到今日。 951
# 兵丁也戏弄他、上前拿醋送给他喝、说、你若是犹太人的王、可以救自己罢。 952
# 兵丁用荆棘编作冠冕，戴在他头上，给他穿上紫袍， 953
# 兵工厂：用来研究升级步兵、坦克等的建筑。 954
# 兵马俑不仅规模宏大，而且类型众多，个性鲜明。 955
# 兵马俑既美也累，他们不会很快死亡。 956
# 兵马俑是这个国家崇武精神的体现。 957
# 兵马俑现在仍然为大多数中国人以“武士俑和战马俑”而了解。 958
# 兵马俑游客满意指标得分最高，法门寺得分最低； 959
# 兵器工业自身固有的特殊性和高危险性，决定了其开展安全评价的必要性。 960
# 兵士说。他把手举到帽子边上行了个礼，因为他以前从来没有看见过这样的一只狗儿。 961
# 兵团被划分为若干别动队，经常增援其他克隆人部队。 962
# 兵团高校公共体育教学改革乒乓球项目实施情况的调查研究与分析 963
# 兵团也是他的家，也像双亲的家一样始终是可爱的、可贵的。 964
# 兵团作为国家实施罪犯易地改造的重要基地，它的存在是十分必要的。 965
# 兵要的是真挚的言语或真挚的沉默。兵说他不懂得爱情。 966
# 兵蚁的卵子发生与工蚁相比，仅有卵母细胞的分化期，没有生长期； 967
# 兵役制度：实行义务兵和志愿兵相结合的兵役制，兵役期两年。 968
# 兵役制度：实行志愿兵役制，服役期至少3年。 969
# 兵役制度：征兵和义务兵役制，服役期两年。 970
# 兵役制：义务兵役制；服役期为9个月。 971
# 兵营是双枪老大爷的前提建筑之一。 972
# 兵营现在是唯一能安置守卫队长的建筑。 973
# 兵源素质低下，士兵待遇较差；以及皇帝对军队的过分依赖和纵容等。 974
# 兵种包括所有等级的中士和下士。海军中则等价为包括所有等级的海军士官。 975
# 冰雹开始减弱，寂静像失去的朋友再度归来。 976
# 冰雹可能是人口集中的东南沿海一带最重要的风险，但还没有规定对屋顶材料加以控制。 977
# 冰雹是一种中小尺度的天气现象，多发生在地形复杂的山区和丘陵地带。 978
# 冰雹直径不超过1寸时，国家气象局会发布重要天气警报。 979
# 冰被模制得非常细致并且是半透明的，背景中的地平线[显得]抽象而平静。 980
# 冰层较薄的地方通常会较早解冻，而这些黑色的砂丘浸泡在阳光会加速冰层的融化。 981
# 冰茶、矿泉水和果汁也都一应俱全，唯独酒是严厉禁止的。 982
# 冰出于谁的胎。天上的霜是谁生的呢。 983
# 冰川报告中存在严重的错误，这个事实已经在科学圈传播数月。 984
# 冰川变化存在差异，这并不奇怪，即便是在喜马拉雅山脉内部本身也是如此。 985
# 冰川带着低处嵌着的岩石活动时，形成了这些一条条平行的沟槽或擦痕。 986
# 冰川的融化可能在未来数十年导致部分河流夏季流量增加，然后随着冰川的消失而减少。 987
# 冰川的融水流进格陵兰岛南部的特隆赫姆沥海峡（拍摄于9月下旬的一个下午）。 988
# 冰川的主干道，涌动的方向是从右边过来在主干道上变化得非常快。 989
# 冰川底部埋藏着各种尺寸和形状的岩石。 990
# 冰川堆积物的工程特性、降雨、河流冲蚀及工程开挖是影响冰川堆积物边坡地质灾害发育的主要因素。 991
# 冰川锅穴冰川中近于直立的井穴或洞，系由冰面和岩石碎屑从冰缝中坍落而成 992
# 冰川湖的能量运动是与海洋非常不同的，是对身体感官而言，非常抚慰舒适的。 993
# 冰川内部河道将冰川表面的融水带入床岩下。 994
# 冰川漂流物在基岩表面留下的一系列短痕之一。 995
# 冰川融化，空气和海洋温度明显上升。 996
# 冰川时代末期，人类开始从事农业生产，那些神是否也在同一时刻开始了呢？ 997
# 冰川是巨大的长期存在的冰体，除了气候和湿度变化以外，海拔对冰川的寿命也起了关键性的作用。 998
# 《冰川》也是上次《流动性的漂泊》展的作品，这幅景观以严密的验证而显示了该作品是自然和人类引导的混合体。 999
# 冰川在融化，风暴在凶猛增加，山体滑坡和洪水，随之而来的是干旱和森林砍伐。 1000
# 冰川中以耐冷的生物为主，形成一个以微生物为主要生命形式的相对简单的生态系统。 1001
# 冰川作用也可能是有益的对于超大铜矿石岩层的沉积物的形成。 1002
# 冰窗花，我心境里最纯美的花，这些自然的杰作哟，总是在冬天里给我无限的遐想。 1003
# 冰醋酸是个脱水代理及刺激物和腐蚀。 1004
# 冰脆的罗马生菜配以传统凯撒沙拉酱，帕玛桑芝士与蒜香面包粒。经典之作！ 1005
# 冰刀企鹅正为营救女朋友的事而心烦意乱呢，因为一群愤怒的雪人抓走了它的全部朋友！ 1006
# 冰岛被比作“煤矿里的金丝雀”，对全球经济起到警示作用。 1007
# 冰岛崩溃的原因在于这场金融危机出人意料的严重程度和该国政府骇人听闻的政策失误。 1008
# 冰岛长须鲸加工工业公司计划向日本出口大量鲸鱼肉。 1009
# 冰岛矗立在两块地壳板块的聚合点上，是世界上火山活动最活跃的地区之一。 1010
# 冰岛的复苏为爱尔兰和其他欧元区处境艰难的国家提供了两个教训。 1011
# 冰岛的故事示范了为何世界各国央行会为支撑商业银行的业务而提供泛滥的流动性。 1012
# 冰岛的国家形象已经与西欧捆绑在一起了：我们喜欢把自己看成是联系欧洲和美国的一个大西洋上的小国。 1013
# 冰岛的火山仍在持续地喷发中，所以我们一直都在密切地监控着局面。 1014
# 冰岛的能量被困在冰岛内部，如果存在一些关于被困能量的诗意想法，那么也存在一些冰岛人的乏味的妥协措施。 1015
# 冰岛的排名反映出该国内部政治局面稳定、与邻国关系良好。 1016
# 冰岛的银行对外借贷相当于其银行存款的金额数多次，在最近几个星期，这个国家不得不扣押三大银行。 1017
# 冰岛对创业家有最积极的看法——但经合组织的数据是从2007年开始到它的经济破裂之前。 1018
# 冰岛对荷兰的比赛，冰岛人扳回了刚刚丢失的IMP，就是因为他们也展示了有效的纪律。 1019
# 冰岛发现，在它出现危机的时候，想要获取那些主要货币并不如它希望的那么容易。 1020
# 冰岛各式的熏鱼享誉世界，三文鱼和熏鳟鱼是味道最好的美味。 1021
# 冰岛火山爆发而引起大量火山灰在欧洲机场关闭5天后也慢慢从天空消散。 1022
# 冰岛火山将继续喷发它的结束不是短暂的时间内能够完成的。 1023
# 冰岛或许是那场竞赛的赢家，但其民众却成了输家。 1024
# 冰岛将在这周末以更温和的形式进行投票寻求解决之道。（看文章）。 1025
# 冰岛金融危机正濒临爆发边缘动荡不安，货币崩盘，通货膨胀率飙升。 1026
# 冰岛近代史上最强劲的一次火山爆发，是1783年的拉基火山爆发，给人类历史带来了严重的灾难。 1027
# 冰岛经济的扩张建立在高借贷利率之上，如今在偿还债务时则面临困难。 1028
# 冰岛经济基本上是资本主义经济,但仍然伴随着广泛的福利系统 (包括有大量的住屋补助金) 、较低的失业和甚至明显的收入分配。 1029
# 冰岛居民具有一个有限的基因库和非常详细的人口档案，这使得冰岛成为一个基因宝藏。 1030
# 冰岛拉基火山爆发所产生的间接影响还持续了好几年。 1031
# 冰岛旅游局主席斯万赫德 康拉德斯图蒂尔女士说：“我们有泡泡温泉、水疗、桑拿和温水泳池。” 1032
# 冰岛南部的埃德菲亚德拉火山喷发就属于此类。 1033
# 冰岛内部事务部表示，黄的投资集团不符合收购土地的法律规定。 1034
# 冰岛破产，但至少没人会被冻死，因为他们有地热可供取暖。 1035
# 冰岛气象局声称，今天早些时候，地震震动预示着岩浆已经开始从火山口中喷涌而出。 1036
# 冰岛人请求可以用老式文体撰写一篇叙事诗，内容是他受到的残忍待遇和冰岛是多么伟大。 1037
# 冰岛人认为只有傻瓜才不考虑别人的利益。 1038
# 冰岛人甚至还在纽芬兰岛上（加拿大的一个省）上建立了村庄，尽管仅仅维持了十年左右。 1039
# 冰岛人也是很好的对象，Barzilai说他们都是五个维京男人与四个爱尔兰女人的后裔。 1040
# 冰岛是由于“热区”里的物质从地底深处涌起，把部分海底山脊推到空中而形成的国家。 1041
# 冰岛首相上周向国民发表讲话，说他们可能必须回头向土地和大海要资源。 1042
# 冰岛同样属于北欧国家，但非严格意义上的斯堪的纳维亚地区，同样诞生了一位获奖作家。 1043
# 冰岛央行依照惩罚条款对Glitnir强制施行国有化，而不是对其进行接管。 1044
# 冰岛也不愿意用非常规手段为银行体系提供更多支持。 1045
# 冰岛一直置身于欧盟之外，这不仅仅是为了保证其捕捉鳕鱼的配额。 1046
# 冰岛一座火山爆发，其火山灰可能影响到英国航空业乘客的正常出行。 1047
# 冰岛已经发现以其自身货币来拯救巨大的银行业有着局限性。 1048
# 冰岛有一支海洋巡逻队，备有巡逻艇和一些小型飞机，负责渔区保护和海上救护工作。 1049
# 冰岛在文化和娱乐花销上远甚于其他发达国家，私人和公共开支加起来已高达GDP的10%。 1050
# 冰岛早餐---一顿可以驱赶黑暗和寒冷的丰盛且热腾腾的早餐就是这个了。 1051
# 冰岛政府被迫将其最大的两家银行国有化，并发狂似的向俄罗斯寻求续命贷款。 1052
# 冰岛政府已出台紧急措施，企图限制外汇流出，以保护摇摇欲坠的冰岛克朗。 1053
# 冰岛政府在运动、艺术和娱乐设施上为其民众的慷慨投入是其他国家的两倍多。 1054
# 冰岛之所以破产，是因为一群渔民竟然相信自己的国家已经成为一家巨型投资银行。 1055
# 冰岛总统奥拉维尔?拉格纳?格里姆松为了减少二氧化氮排放到大气中正试图把它们注入地下。 1056
# 冰岛总统拒绝签署议会二月份通过的偿还英国和荷兰政府的决议，从而导致了星期六的公投。 1057
# 冰的底层变的有弹性，因此冰河可以移动。 1058
# 冰登山使他1月14日成立的中央附近的德国菲尔特市采石场墙上的方式，到2010年。 1059
# 冰雕的造型诸如此类，直到这个冬天，米奇老鼠，唐老鸭和维尼熊走进了冰灯节。 1060
# 冰冻的过程带有不确定的身分。没有两件曲谱是完全一样的。这一点巨匠可想而知。 1061
# 冰冻的黄瓜片，如果没有什么别的东西，也可以当作冷敷法来消除眼袋。 1062
# 冰冻和常规保存机采血小板在血液病患者中的应用评价 1063
# 冰毒和摇头丸在药理作用上属中枢兴奋药，毁坏人的神经中枢。 1064
# 冰封的旭日在春雨的迷蒙中黯然退场，阴霾的记忆，随着三番两次的欺骗被滚滚泪水埋葬。 1065
# 冰封装甲的重要升级技能，这个护盾对攻击者给与冰冷伤害。 1066
# “冰夫人……”弄墨嘀咕了一声。见松又要解释。连忙摆手。 1067
# 冰敷瘀青的部位来减轻肿胀。 1068
# 冰浮筒的测定数据表明，最近几年海冰底部的融解确实大幅增长。 1069
# 冰冠城城堡将家中的困难，更新的实例，可设置在每个老板的老板改变了基础。 1070
# 冰冠要塞分为10人和25人版本，每个版本各有12次遭遇战。 1071
# 冰河时期可能已经阻碍了法国北部的人类文明进化，但它可能有助于其它地方的文明发展。 1072
# 冰河世纪末期全球变暖对亚洲温带地区，欧洲和北美都有巨大影响。第三句 1073
# 《冰河世纪》由一群可爱的史前动物主演，其中有树懒、剑齿虎和性情乖戾的猛犸象曼尼（Manny）。 1074
# 冰河与之相间时小儿女情态颇动人心，只愿两人相依相伴，再无孤寂。 1075
# 冰河正在向海的前缘加速移动，后方的冰原则在变薄。 1076
# 冰后期海平面上升，下切河谷被淹，并转化为河口湾，海水随之扩展到两侧的古河间地。 1077
# 冰壶比赛进行地如此悠闲使得他可以轻松进行多任务工作;一眼关注大屏幕上实时滚动的金融数据，一眼关注比赛。 1078
# 冰火两重天.大多数房屋比较破败，公共卫生条件几乎缺失，公共健身器材更是不着边际。 1079
# “冰激凌乐园”的创办人马特·欧康纳说，他不理解为什么有人会厌恶这个产品。 1080
# 冰激凌是夏日里给人酷爽感觉且令人心满意足的款待，但是一天一勺的量就足以让比基尼退避三舍。 1081
# 冰激凌在手，漫步于街道间，你可能会碰上些年轻的艺人。 1082
# 冰激凌，正如其名，有极大的吸引力。 1083
# 冰激振动可以引起较大的平台甲板加速度响应，从而危及导管架平台上部管线安全。 1084
# 冰架上存在静水表明冰架即将崩裂，因为静水会浸宽现有冰缝。 1085
# 冰间湖内生长有大面积纯热力学生长的海冰并向外输送。 1086
# 冰解面是可以看到冰块脱离的墙面，但事实上，它向海平面以下还延伸了两千英尺。 1087
# 冰晶般地清爽，含有数倍水份，深层导入，肌肤不再干渴，回复水盈嫩滑。 1088
# 冰晶必须面向水平，而观察者的视线也必须接近水平来观察幻日。 1089
# 冰晶需呈片状，它们悬浮近在地面的空中，将光线向下反射。 1090
# 冰块厚度可调，储冰室冰量可调，底脚高度可调且易安装。 1091
# 冰类绵绵冰麦角冰地瓜冰紅豆牛奶冰八宝冰豆花 1092
# 冰冷刺骨的北风在吹是个寒冷的清晨所有的山峰被雪覆盖冬天真的来了。 1093
# 冰冷的空气和阵阵大风使美国东海岸度过了寒冷的一天。 1094
# 冰冷的倾盆大雨正洗劫这小镇酒吧前的一条黑乎乎的沥青街。 1095
# 冰冷风暴：冷色调的蓝色和绿色调和在一起，就像是高山上的一缕清风。 1096
# 冰凉的威士忌在他体内流动，形成了一股暖流，直通到他的内脏，使他感到体内火辣辣的。 1097
# 冰凌针-板间隙直流正极性下起始电晕特性的研究 1098
# 冰流下面的水有润滑剂的作用，使冰能够顺畅的流向海洋。 1099
# 冰帽融化、海平面提升、洪水、龙卷风和暴风雨都将是不可避免的结果。 1100
# 冰面不断融化，会出现更多的水域服务于航行和军事用途。 1101
# 冰面的形成在二三年前已经推迟到十二月，而到来年三月却又融化的无影无踪。 1102
# 冰面很光滑，你推动雪橇，然后放手，接下来会怎样呢，雪橇仍然会继续前进，为什么会这样呢？ 1103
# 冰面没有尽头，我们也不想停下，这样一直滑进了树林。 1104
# 冰面上到处有融化的冰水形成的湖泊，这是自然环境过于迅速变化的悲剧性证据。 1105
# 冰面上摩擦力通常较低，这使得滑冰选手一俟启动，就能不受摩擦力牵绊，顺畅滑翔冰面。 1106
# 冰期时，气温很低，冰层从两极向其他地方无限扩展； 1107
# 冰淇淋简已经空了，蚂蚁正在享受着一团香精和巧克力。 1108
# 冰淇淋可以选用人造甜料或糖来制造。 1109
# 冰淇淋没有达到美国直到十八世纪中叶。 1110
# 冰淇淋是乔治·华盛顿总统最喜欢的甜点，根据记载，总统为了要制作冰淇淋，还亲自买了一部机器。 1111
# 冰碛层中架空块碎石成因及处理分析 1112
# 冰桥科学家正在调查松岛冰川来研究冰川在如何变化以及变化的原因。 1113
# 冰桥小组带着雷达和激光雷达飞到冰上面去测量冰的厚度。 1114
# 冰球棒不允许用来钩划或者砍对手，这些犯规将被强制进行处罚。 1115
# 冰球队员将冰球射入守门员的球门，得分最多的队为胜者。 1116
# （冰球曲棍球）开始的一种方式；裁判在对手之间做出判定。 1117
# 冰球是加拿大的国家级体育运动。现代冰球运动就是在加拿大发展起来的。加拿大的另外一项热门运动是曲棍球。 1118
# 冰球是平的，可在冰上滑动，冰球选手可用曲棍使其滑动。 1119
# 冰球是一项主要是男子参加的激烈运动，冰球场分进攻、中立和防守三个区。 1120
# 冰球运动是世界上最快的体育项目，参赛者在冰上每小时滑行30英里，很容易就累了。 1121
# 冰球运动员与轮滑球运动员技战术可有机转换的内在分析 1122
# 冰区航行拖船”涅瓦河前哨“是在圣彼得堡设计和建造的。 1123
# 冰山#6：使用睫毛膏拉出眼睛睫毛卷的外观更大，更明亮。 1124
# 冰山尺寸大小不一，小至一块方冰，大至相当于一个国家的面积。 1125
# 冰山：从冰川上断裂下来的冰块，它们在海中四处漂流。 1126
# 冰山搁浅后融化，在海床上留下了这些岩石，随后海床的上升使它们得以露出海面。 1127
# 冰山仅存在短短的一段时间就慢慢地悄无声息地融化掉。 1128
# “冰山理论”是一个用来形容美国作家欧内斯特·海明威的写作风格的术语。 1129
# 冰山上有些碎冰块，可能是在它从汉博尔德冰川脱落漂走时，其它冰山崩裂落下来的。 1130
# 冰山是大自然最壮观的创造之一，但大多数人却从未看到过冰山，一种朦胧神秘的气氛笼罩着它们。 1131
# 冰山是美丽的，一些冰山超出了水面几百英尺，它们看上去好像漂浮在海上的白色群山。 1132
# 冰山形成于久远的、寒冷的水体中，而且伴随着雷声轰鸣般的嘈杂和水花汹涌的风暴，但却无人耳闻目睹。 1133
# 冰山运动之雄伟壮观，是因为他只有八分之一在水面上。 1134
# “冰山”在标识（标志）的名称变成了冰冠。 1135
# 冰山在海里移动很是雄伟壮观，这是因为它只有八分之一露在水面上。 1136
# 冰山在罗瑟拉基地不远处与浅海不断磨蚀，英国南极考察组在南极半岛，2009年元月25日。 1137
# 冰伤害属性技能制造小伤害，不过同时能够削弱目标的移动速度。 1138
# 冰上溜石游戏是一种在冰上玩的运动。从17世纪早期以来，苏格兰成了它真正的故乡。 1139
# 冰上曲棍球比赛，主要是在库约地区（特别是在圣胡安省）。 1140
# 冰上舞蹈同样由一男一女两名选手组队参赛。 1141
# 冰上舞蹈与双人滑最主要的区别在于，冰上舞蹈更强调类似于舞蹈的复杂的步法，同时要与音乐配合。 1142
# 冰舌每年在变长，直到一定时候断裂开，崩解而成一个新的冰山。 1143
# 冰霜打击：瞬发攻击，造成武器伤害的50%及3点冰霜伤害。对冻结目标造成双倍伤害。 1144
# 冰霜的手指缓慢的滑过鱼梁木，缓慢延伸，空荡的村庄不再空旷。 1145
# 冰霜符文掌握（第6层）被霜寒代替，该天赋增加你的寒冰之链和尖啸冲击的伤害15%。 1146
# 冰霜和熔岩覆盖在这颗多火山的卫星上，同时在发出蓝色散射光芒的羽状烟柱下还可以看到发出红光的熔岩。 1147
# 冰霜新星：正确的覆盖碎裂屏障和霜寒刺骨的效果。 1148
# 冰霜之径-开启冰霜之径后，从一定高度跌落可免受伤害。 1149
# 冰水不一定能解渴，而一杯温茶可能可以。 1150
# 冰水混合物作冷却剂，准备方便而且长时间温度恒定。 1151
# 冰水流淌的四月初，榆树便冒出褐色的芽，逐渐变深，变绿。 1152
# 冰水系统每隔三个月更换新水一次，若无法更换请加除锈剂。 1153
# 冰水在碗柜里敲的山响甜品唉声叹气躺在床上茶杯噼啪爆裂开一条通往死亡国度的小巷。 1154
# 冰糖葫芦老少皆宜，它具有开胃、养颜、增智、消除疲劳、清热等作用。 1155
# 冰天崩溃后，射线最终使人类身体变小，并逐渐缩短他们的生命长度。更详细。 1156
# 冰天雪地的加拿大，这只猫头鹰貌似是在利用这样的天气条件练习自己的溜冰技巧。 1157
# 冰蛙称这边的为近卫，称那边的为天灾；有敌人，有盟友，这是第一日。 1158
# 冰蛙说，野区要多多建造各种小路；要有阴蛋穿梭在河道以上，树林之中。 1159
# 冰吻——这需要一小块儿冰的帮助。轻轻地用冰块摩擦她的后背，让它慢慢融化。 1160
# 冰箱大小的头部和香蕉一般的牙齿使它成为超级强大的肉食动物。 1161
# 冰箱大小的有机玻璃原型股东北的油气电力实验室是一个比较复杂一点。 1162
# 冰箱的制冷机制发出卡嗒卡嗒声，然后静了下来，她觉察到她没注意它发出来的那些响声。 1163
# 冰箱放的食物看起来、闻起来都没问题，如果只是超过保质期一天，甚至是保质期当天，你会直接把它丢进垃圾桶吗？ 1164
# 冰箱里除了塞满了足够我们五人吃三天的食物以外，还有一格专门用来存放我们带来的啤酒、香槟、葡萄酒和伏特加。 1165
# 冰箱里存放着MMS，你就不是一个无助的受害者，面临着看不见的病毒敌人的军队。 1166
# 冰箱里的动物脂最上层正在聚集成一层稠密又洁净的东西。 1167
# 冰箱里放着一盒陈旧的香肠（我看了一下日期，便把它给扔了），一袋豌豆，半打塑料盒里装满了冰。 1168
# 冰箱里面的东西很少，有几根芥菜、几片芝士切片，还有十四罐健怡七喜。 1169
# 冰箱里有冰茶，另外我刚买了一些柳橙汁，不过还不冰 1170
# 冰箱里有一条大猪腿，那是她打算在星期天做着吃的。 1171
# 冰箱门堵盖零件工艺分析和注射模设计 1172
# 冰箱门上的架子是最不适合放鸡蛋的地方，因为经常震动会使蛋白变稀，而且其他食物的气味可以穿透蛋壳而进入鸡蛋里面。 1173
# 冰箱内部可以用硼酸或消毒纸巾擦拭，搁架要拿出来用水清洗。 1174
# 冰箱、洗衣干衣机、男式服饰、自行车、烧烤工具、餐桌椅、化妆台、扇子、微波炉、贵妃椅、DVD机。 1175
# 冰箱、洗衣机、彩电、空调、手机、相机、电话机、音响、微波炉、电饭锅、台灯、剔须刀、计算器、计算机？ 1176
# 冰箱用全封闭压缩机噪声分析与降噪措施的探讨 1177
# 冰箱，这两个冻结的水部分，并把冻结的鞭子混合空气。 1178
# 冰香膏及中药熏洗治疗扭伤的临床观察 1179
# 冰蓄冷空调蓄冰罐单独融冰供冷的设备选择计算 1180
# 冰靴上的刀片划出许多雪白的冰屑，高高地飞溅到空中，然后像雪花一样飘落在整个溜冰场上。 1181
# 冰雪的斗篷。兽人大笑了起来，在他脸上漂浮着的骷髅也发出了自己狂躁而响亮的笑声。 1182
# 冰雪的芬兰，不仅造就了他冰凝的面容，也造就了他冰一样刚毅的性格。 1183
# 冰雪封住了卡车的车门，于是他不得不将提箱和塑料袋扔出窗外。 1184
# 冰雪覆盖的一个邮箱被看作是皮科船员在附近工作而不会在科茨维尔，宾夕法尼亚州，星期三，2011年2月2日电。 1185
# 冰雪溜滑，人们很难站稳。 1186
# 冰雪旅馆里有59个卧室，还有电影院、桑拿室、美术馆、小教堂和一个超酷的伏特加酒吧。 1187
# 冰雪消融北极人发现词汇贫乏北极的土著人用什么词语表达大黄蜂、知更鸟、麋鹿或者鲑鱼？如果你不知道，你不是唯一的。 1188
# 冰雪消融的季节沉睡的梦境也开始脱落，我常在美丽的梦境中自恋着,执着等待着,只是你不知道而已。 1189
# 冰雪运动员髌骨软骨病的诊疗与预防 1190
# 冰堰后面，冰雪消融形成了深深的湖泊，灌满了爱达荷州与蒙大拿州西部的若于个山谷。 1191
# 冰，液态水和水蒸汽可以看成是同一物质。 1192
# 冰预计可作为混凝土一样坚硬，一钻就舀有助筹足冷冻标本。 1193
# 冰原消耗了大量的水分，海平面迅速下降，横跨白令海峡的大陆桥浮出水面。 1194
# 冰只有二分之一，卡路里每克每度。 1195
# 冰中俘获的空气泡可以揭示过去的大气条件，所以冰川可以向人们提供环境记录。 1196
# 冰洲石-玻璃组合平行分束偏光镜的设计研究 1197
# 冰洲石是方解石的一种存在形式，它可以把光线分成两束。 1198
# 冰洲石是一种昂贵的光学晶体材料，由于其完善的解理性和脆性而难于加工。 1199
# 丙泊酚是一种常用全身麻醉药，对多种器官组织具有保护作用。 1200
# 丙泊酚与硫喷妥钠对电抽搐治疗时抽搐发作的影响比较 1201
# 丙二醇单甲醚的合成方法，它涉及一种丙二醇单甲醚的合成方法。 1202
# 丙二醇甲醚是一种低毒性、用途广泛的精细化学品。 1203
# 丙二醇也被认为是隐藏在随身物品中的杀手的代理，习惯于用来捕捉地面上的甲虫[10]。 1204
# 丙二酸、二氧化氯、碘离子及硫酸的初始浓度对振荡现象的发生有很大的影响。 1205
# 丙肝病毒在血友病患者身上表现更温和？ 1206
# 丙肝的感染率同样没有下降，这说明那里使用肮脏的针头注射毒品的人数也没有减少。 1207
# 丙肝通常是通过输入没有筛查的血或者通过注射或者吸入药物被感染。 1208
# 丙纶的纤维不易脱落，易清洗，与优质锦纶和羊毛相比，价格更能接受。 1209
# 丙纶纤维制成的织物既有柔软的手感，又具有良好的悬垂性，挺括抗皱。 1210
# 丙纶熔点低，磨料磨损、绒毛表层的摩擦都可能造成不可补救的绒毛衰败现象。 1211
# “禀赋效应”是一种非理性偏好，即珍惜你拥有的东西，而不是去改变它。选择你熟悉的东西。 1247
# 禀皇上，此次演武，循惯例皆持木剑，请殿下验过。 1248
# 秉承“对光负责”而精于研发创新的新星照明品牌。 1249
# 秉承时代带给人类的希望，我想敦促在座的每一位毕业生，问题的挑战。 1250
# 秉承坦诚、公道求新、务实、和气生财之经营理念，以“精诚服务”为公司之宗旨。 1251
# 秉承这个时代带给人类的希望,我想敦促在座的每一位毕业生,接受一个问题的挑战 1252
# 秉承这种思想，艾默生环境优化技术公司最近升级了其商务制冷应用关于制冷剂的白皮书。 1253
# 秉承着两千年前的吴越锻造技术，他开拓出了自己的新天地！ 1254
# 秉承质量第一，客户优先的原则，竭诚为广大客户服务。 1255
# 秉持“以人为本”的理念，为员工提供广阔的职业发展空间，实现员工与公司的共同成长。 1256
# 秉司猪淋巴结肿大或萎缩，呈灰紫色，粉红健康猪淋巴结； 1257
# 秉性刚强烈女形象又彰显她对抗男权文化桎梏的倔强姿态。 1258
# 秉性温和的斑马通常在小打小闹中只是喷喷气而已，却不想这回他们裂开了嘴露出了牙，甚至还跳到了对方的背上。 1259
# 饼干公司不得不付出比他们预计多得多的钱，因为为买下那学生烘制的饼干他们支付了24,000美元。 1260
# 饼干觉得现在的成绩证明了俱乐部老板找回国王的决定有多么正确。 1261
# 饼干类食品主要成分就是面粉和糖分，没有什么营养，香精和色素损害肝脏。 1262
# 饼干，麦片，枫叶糖浆，巧克力，饮料，果酱，果仁，咖啡，冰酒等。 1263
# 饼干也在恢复中出了点小问题但这次是新伤。他应该能在这周结束前回归训练。 1264
# 饼确实是硬的，是我从酒店里带回来的一块大饼。 1265
# 饼是人们喜闻乐见的一种传统食物，在中国北方比较流行，是一种很普遍的家常主食。 1266
# 并按相同条件及规约产生效力，一如其为批约无异。 1267
# 并按相应的技术指标给出了相应的程序流程图和试验结果。 1268
# 并按着正唱着歌的妈妈的小的保持平衡的脚上。 1269
# 并把测地线距离应用于径向基函数，实现了一种曲面变形算法。 1270
# 并把冲突升级为转折，比如一个笨手笨脚的杂务工做的小型维修把整栋别墅给弄塌了。 1271
# 并把矛头指向了男人们占有掠夺这一天性，他们“只想着一件事”。 1272
# 并把一块大石头滚到墓口，就走了。 1273
# 并帮助他在自己的职位上如鱼得水，勇渡难关，坐稳了自己总裁的位子。 1274
# 并保持5评级。所有意见应来自不同的IP的访客。未设定目标需要的，但北欧意见首选。 1275
# 并保证材料强度足够大，缝制完全，就如我们看到的顶部面板一定要有后续处理。 1276
# 并被关在一个感官被剥夺的室内，接着又受到情报人员的依次粗暴的拷问。 1277
# 并被要求进行高水平的表演，但马匹，当然，英国马，准备的非常非常好… 1278
# 并被指控调戏一位仅三岁的小女孩，调戏过程被记录在录像带上。 1279
# 并本着武医之德，开设口腔门诊行医多年，在当地赢得了群众的一致好评。 1280
# 并比较不同年龄段和不同性别在变应原阳性率分布上的差异。 1281
# 并必须签署一书面协议以取得公司赞同。 1282
# 并表示，不排除投资国内股指期货的可能性。中国的股指期货交易计划在4月16日正式启动。 1283
# 并表示，任何击落火箭的企图都将变成是一场真正的战争。 1284
# 并表示如何处理铂金包的预订是她们客户服务工作的一部分。 铂金包都是在巴黎手工制作的。 1285
# 并表示如何处理铂金包的预订是她们客户服务工作的一部分。铂金包都是在巴黎手工制作的。 1286
# 并不包括使用不当或维修疏忽造成的损坏。 1287
# 并不比微软弱小的谷歌最近主要对加强它已存的特权感兴趣。 1288
# 并不表明我对这种全世界人都有的想法已有了充足的证据，但直觉告诉我，事实上，这种想法是普遍存在的。 1289
# 并不表示恐惧不存在，而是敢面对恐阴风耳惧、克服恐惧。 1290
# 并不出人意料，不是每个人都会因为这个家庭再访奥斯维辛而开心。 1291
# 并不存在必然致使法国人保守或者抵制革新的东西。 1292
# 并不存在单一的过程，很多小的过程编织在一起形成了似乎是同一层次的统一过程。 1293
# 并不多，但坚持并容易，因为她，感觉快乐。 1294
# 并不多，可是如果世界上的每个人都行动起来，这个世界很快就会变成天堂。 1295
# 并不罕见，骨盆骨折的特征表现出可能不止一种损伤类型，但适用同样的稳定性原则。 1296
# 并不好看的宾州选举解决肯定将使他更加希望甚至是热切的盼望党内的大佬们快点结束这样的争斗。 1297
# 并不仅仅是通过学取授，而是通过体验的方式让人引人注目，并且可以亲身实在地感想到。 1298
# 并不仅仅是重塑了脸蛋、漂亮的腹部以及一件鲍勃麦基服装，雪儿也已成为了一个产业。 1299
# ...
# 并没有所谓文明的冲突，而只有那些赞成文明的人和那些反对文明的人之间的冲突。 1991
# 并没有他人在现场受伤。目前仍不清楚Lopez有否被控以任何罪名。 1992
# 并没有太多像你想像中的那些美好和舒坦。生活就是这样，平平淡淡的没有滋味！ 1993
# 并没有我所盼望的那么多，先生，他每年大概可以在这儿待上半年；达西小姐总是在这儿歇夏。 1994
# 并没有影射该分级适用于特定平台上特定版本的LotusDomino。 1995
# 并没有证据显示房地产价格长期升幅高于经济增速或通货膨胀率。 1996
# 并没有做任何预动，你的右手已经蓄势待发，并加速了整个组合。 1997
# 并描述了J耦合分解谱和同核相关谱（COSY）的基本解析方法和用途。 1998
# 并明确表示他可以动用一切所需资源来调查这起凶残的案件 1999
# 并拿起个袋子，捡起个袜子，插下插头，这样，我能将豆放入捡起的袜子里，用捡起的袋子压舱… 2000
# 并那坏了心术，失丧真理之人的争竞。他们以敬虔为得利的门路。 2001
# 并能从控制论发展图式中寻找到“改变学习毅力”的突破点 2002
# 并能分身扮演所有能扮演的不同角色，你知道，因为那就是我喜欢表演的原因。 2003
# 并能更充分地恢复关节面的解剖关系，减少创伤性关节炎的发生。 2004
# 并能很有效的促进的社会交往，改善人际关系，还有助于净化社会风气。 2005
# 并能实现慢速运动，无需配备慢速电机。 2006
# 并能为客户改装和修理进口增压器或轴流式机车、船舶发电用增压器。 2007
# 并拟合出回归方程估算品种耐弱光性。 2008
# 并努力把公司打造成一个温馨的家，一个给有梦想的人们展示才华、获得发展的美丽舞台。 2009
# 并排坐在两张椅子上，我点开华盛顿彩票图标，然后中奖号码就出来了。 2010
# 并配备烟雾传感器和燃气泄漏传感器，实现防火、防燃气泄漏的作用。 2011
# 并配合饮食调理，使患者延长生命，可提高存活时的生活品质。 2012
# 并配合珍贵的藻类活性成分，持续提升整体肤质，使其回复紧致与清澈。 2013
# 并评述了这些生物技术在葱属植物遗传育种和品质改良中的应用前景。 2014
# 并祈祷当那浑沌黑暗的一天再度降临时，慈悲的救主会再次拯救我等脱离风暴。 2015
# 并启用它们之间的通信，同时为该容器提供了一种管理其组件的方法。 2016
# 并切换该阀，使得所述膜吸附器筒互相连接而在逆流流动模式下工作。 2017
# 并且，15%的男性晚期癌症患者仍进行前列腺癌筛查，相比而言，在无癌人群中这个比例是27%。 2018
# 并且ArcadeFire可以从对这些瞬间的认识中做出这么有力量的艺术，这也使我们的存在感到了值得记录的意义。 2019
# 并且A（下标H）的衰变模式可提供典型的信号和清晰的背景，较有利于探测。 2020
# 并且Bharti的规模和影响可以使它比Zain支付更少费用为非洲的网络塔和类似的设备。 2021
# 并且CDC拥有一个医务人员的网络，这些医务人员常规性的对病人抽样并测试，以检验他们携带哪些可能在社会中流行的致病体。 2022
# 并且，Hertz-Picciotto说那些因素“并不会使我们接近”诊断病例中600%-700%的增长。 2023
# 并且，XX公司是一个国际化的大企业，有远大的发展前景，我还有机会到XX领略一下风土人情。 2024
# 并且爱尔兰正在抵御金边债券信用的下滑。 2025
# 并且，按其要求准许珠海市（中国）、岐阜县和各务原市（日本）的退出。 2026
# 并且，澳大利亚的章鱼种类虽然不独特，但是它们无疑是伪装高手。 2027
# 并且把本接收机用于分子测风激光雷达系统中进行了标准具透过率的测量和风廓线的初步测量。 2028
# 并且百岁以上老人的子女更加有可能存在这种基因变异；他们也更有可能在身高这方面有所缺陷。 2029
# 并且保险行业对这些资产的披露趋于远胜银行。 2030
# 并且保证他仍作大司祭，仍享有从前所有的各种特殊荣誉，还将他列入王的一等朋友之中。 2031
# 并且被造的没有一样在他面前不显然的；原来万物在那与我们有关系的主眼前，都是赤露敞开的。 2032
# 并且贝尔，好像是因为羞耻心作祟，很快就离开了冠上自己大名的电话垄断行业。 2033
# 并且本发明还提供了一种包括栅极结构的半导体器件，该栅极结构的栅极顶部宽度大于栅极底部宽度。 2034
# 并且，本发明还提供用上述的轮胎用橡胶组合物制造的轮胎。 2035
# 并且本机可专用于单体液压支柱活柱和油缸的一般变形校直。 2036
# 并且本?拉登认为，美国撤军将会导致中东地带所有以美国为靠山的独裁政权的垮台。 2037
# 并且本人授权金鹃国际广告有限公司调查上述资料之真实性。 2038
# 并且，本实用新型还具有装配调节结构简单，整机结构紧凑的特点。 2039
# 并且，本文对“重振策划方案”和“重振传播方案”进行了实证研究。 2040
# 并且，本系统正在逐步推广到亚洲、欧洲和美洲的海外分行上线。 2041
# 并且比起白色鸽子，它们的免疫系统对传染病反应更迅速。 2042
# 并且比起一辆汽车或者是一台自动洗碟机来说，我更能胜任这一课程，因为——好吧，因为我看起来是如此的简单。 2043
# 并且必须强调欧盟将不允许俄罗斯通过温和的双边协议来除掉单独的欧盟国家。 2044
# 并且避免了力道较大的水流持续直接地冲击过滤件内的沉淀而形成细小的杂质颗粒； 2045
# 并且避免眼睛暴露在强光，特别是蓝光，在睡觉前的数个小时。 2046
# 并且并且当我为某事做准备意味很多对我，我的头脑去少许事，象我的手不是足够干净的，故意。 2047
# 并且，不成遗漏数字打印的CMYK色域与胶印不不退有所差别。 2048
# 并且，不管你做什么，作为听众的你依然局限在以自己喜好为中心由你的朋友和你信任的评论家形成的范围中。 2049
# 并且不管怎么说，英国已经正式有了自己的第一位宇航员，部队直升机试飞员TimPeake。 2050
# 并且不论你用多么显贵的身份来使得这个经历看起来平常，中央法庭还是中央法庭，要吓呆你还是吓呆你。 2051
# 并且不审查一般，抽象问题，他的数据可以有有效性根本为一个特殊企业在一个特殊情况。 2052
# 并且不是仅仅你不同意他们，还要提出反对的理由。 2053
# 并且不是亚当受欺骗，乃是女人受诱骗，陷在过犯里。 2054
# 并且不是一个研究，因为没有人的研究能证明一切事情——请给我展示已经完成的大量研究成果。 2055
# 并且不像来自那些污秽场所的肉，它不会污染河流和小溪，不会大量消耗地下水，也不会引起滥伐森林。 2056
# 并且不懈怠。 总要效法那些凭信心和忍耐承受应许的人。 2057
# 并且不懈怠，总要效法那些凭信心和忍耐承受应许的人。 2058
# 并且不懈怠，總要效法那些憑信心和忍耐承受應許的人。 2059
# 并且，不需要任何凝胶来保证这些电极和头盔佩戴者的头皮充分接触。 2060
# 并且不准遵守安息日，不准举行祖传的庆节，连承认自己是犹太人也不许可。 2061
# 并且财政部还在各地建立了地区办事处来提高文书工作的效率，可下级政府却不能完成所承担的责任。 2062
# 并且采取你自己服用益生菌的想法——而不是给你的婴儿——也许对你同样有吸引力。 2063
# 并且，采用蒙特卡罗方法模拟了回归参数及相关统计量的分布特征。 2064
# 并且采用同Ceres相似的技术来加速这些树木的生长并提高它们的耐寒能力。 2065
# 并且采用移动最小二乘近似函数的权函数作为加权残值法的权函数。 2066
# 并且蚕豆粉赋予了高粱粉挤压产品浓郁的豆香味。 2067
# 并且，禅并不认为无限可能性、无限自由、无尽的责任是可怕的。 2068
# 并且，超重儿童也许会低报不健康食品的摄入量，高估自己的锻炼量。 2069
# 并且赤裸裸的提出了谁将在未来的谈判中获得先机。 2070
# 并且除本法规定可以不支付报酬的以外，应当按照规定支付报酬。 2071
# 并且穿上新人。这新人是照着神的形像造的，有真里的仁义，和圣洁。 2072
# 并且慈善机构可以选择是否接受一个广告主的支持。如果慈善机构不希望某个广告和他们的商标放在一起，我们就不会为这些慈善机构投放该广告。 2073
# 并且，此举也将对国际社会发出一个重要的信号，中国对其维护人权的义务是相当认真的。 2074
# 并且此款桌上游戏不仅支持对抗模式，还有独立的可供团队合作挑战的地下城战役模式。 2075
# 并且此类ALS在分子病理和基因分类中的位置仍然是不明确的。 2076
# 并且此中有个教训，增加或减少一两角钱，对于划定贫困线影响甚小。 2077
# 并且从北半球来看，太阳会看起来在向南移动，它变得更小，露面时间更少。 2078
# 并且从此以后，他又用“拿破仑同志永远正确”这句格言，作为对他个人的座右铭“我要更加努力工作”的补充。 2079
# 并且，从红山文化的墓葬特点来看，红山玉器已初具礼器的雏形。 2080
# “并且从逻辑上也解释得通，因为我们生活的社会中人们的确关注我们看上去的样子。” 2081
# 并且从你拍照到你将照片冲洗出来的等待过程是很奇妙的。 2082
# 并且从新鲜的水果蔬菜获取日常所需的的营养有利于身体健康，促进新陈代谢。 2083
# 并且粗骨料含量越多，改性灌浆料T500流动时间越短，坍落扩展度（SF）越大。 2084
# 并且存在一个角速度ω，随时间而改变，毫无疑问的。 2085
# 并且，大地将会彻底分裂离析，并且，在大地上的万物都将会灭毁。并且，在那时的所有朲将面临审判。 2086
# 并且大多数的弟兄们，因我的捆锁，在主里笃信不疑，越发放胆讲说神的话，无所惧怕。 2087
# 并且大多数的弟兄，因见我带锁链，就依靠主，更敢讲论天主的道理，一点也不害怕。 2088
# 并且，大卫.陈说，这种电梯修理更为容易，每次维修只需要拆开一级或者两级即可。 2089
# 并且当NEC的转移主要是日语时，爱立信的多向的过程与各民族有关。 2090
# 并且当互联网的关键失察身体的安全主席，他设法保卫从外部威胁的核心寻址系统。 2091
# 并且当局与哥伦比亚政府就自由贸易协议的谈判结果很快将由美国国会决定。 2092
# 并且，当美国对国外投资和商品设置障碍的时候，有可能也会刺激国外同样逆向的行为。 2093
# 并且当你放轻松时别人也会放轻松，这样会使你们更容易沟通。 2094
# 并且当你跟着你的激情走时，你必须找到一个办法在财政上支持你自己。 2095
# 并且，当你已经拿到了另外一个学位，你将会在市场里学到并掌握更多的技能和知识。 2096
# 并且，当然的，我的到场，我的存在，造成了父母之间极其可怕的分裂。 2097
# 并且，当然了，你也要告别用公费在星期五购买面包和咖啡的日子了。 2098
# 并且，当然，你的发展努力的商务来龙去脉的理解和评价本质。 2099
# 并且，当然，也存在季节性情绪紊乱，可能它的首字母缩写SAD更为出名点。 2100
# 并且，当升级到更新版本的Python时，不必担心可能要废弃已有的pickle。 2101
# 并且，当试图解决复杂且影响广泛的问题时，公用所有权会对此产生阻碍。 2102
# 并且当所有这被诊断和被对待我们实际上起头主要科学数据库合并。 2103
# 并且,当他们把事情弄糟,当他们没有做“本该”做的事时,不要那么烦恼……因为你早料想到他们会把事情弄糟。 2104
# 并且当他们抱怨时，他们没有获得溺爱或者承诺更好的东西：他们被直接指向了一扇门。 2105
# 并且，当他赢得了学院的文学奖后，诺曼.梅勒认识到他的真正使命是要做一名作家。 2106
# 并且，当它与其他工具，比如热情、目标制定、计划组队时，是非常强大的队友。 2107
# 并且当五角大楼利用诈骗的这些财富想从世界空运组织得知消息是不能使美国强大的，因为这是物价值的交易。 2108
# 并且，当心轮变得精力充沛并具通透性的时候，那个进入意识的向上螺旋的入口就会出现。 2109
# 并且当一个人也许感觉象，他有，盎司控制比妇女更多有。 2110
# 并且得知，鲍毕曾经拥有一家小型的环保公司，他十分热爱他的事业，但工作中的一次意外让他不得不进行手术。 2111
# 并且，第二，由在有用的劳方被雇用那些人的不是的数量和那的比例那些人之间，那么使用。 2112
# 并且，电流模技术为微弱荧光信号的低噪声测量、放大和滤波提供了一条可行的技术路线。 2113
# 并且，电容式感应也可用于接近感应，传感器和使用者身体不需要接触。 2114
# 并且，都是在以甘氨酸和黄豆粉作为氮源和以玉米面和淀粉作为碳源菌丝生长势最强。 2115
# 并且对WTO成员来说，这也是俄罗斯贸易体制保持稳定、有可预见性和透明度的一个保证。 2116
# 并且对城市环路建设的作用，分期实施的必要性，高架路在环路中的地位进行了探讨。 2117
# 并且对除渣器转臂的运动状况进行了分析，得到了其运动规律成余弦规律变化； 2118
# 并且对改善亚健康状态：头晕、头痛、语滞、健忘、嗜睡、乏力等有良好的效果。 2119
# 并且对拦截机动目标有很强的自适应性，是一种具有工程实用价值的高精度末制导律。 2120
# 并且对数控插补球轴承磨削的关键技术进行了理论分析以及实际应用。 2121
# 并且对以色列来说，从战争中一无所获是奇耻大辱。 2122
# 并且对于大多数人来说，geek或者不是geek，现代生活本身就是一个无法言喻的复杂问题。 2123
# 并且对于家庭价值作为真实性而信任，认为它和日出一样的可靠，这份信任是经济灾难性崩溃的主要贡献者。 2124
# 并且对于经营管理来说，越大的公司，越可以说云计算是IT的五大优势之一。 2125
# 并且对于危险或人员无法进入的矿山地下空间，CMS是目前唯一有效的测试手段。 2126
# 并且，对于一般业馀创作者来说，几乎都无力负担著作权所有者所要求的昂贵授权费用。 2127
# 并且，对政府计划向来都不过仅有进展跟踪而已。 2128
# 并且对指标权重、评价结果的最大隶属度原则进行了改进。 2129
# 并且多行淫乱，直到那贸易之地，就是迦勒底，你仍不满意。 2130
# 并且，发射地点和弹道容易识别，易招致目标国的以牙还牙。 2131
# 并且发现音乐应该是除神话、诗歌外，又一条通向集体无意识的通道。 2132
# 并且发现，在纳米扭带中的挠率的存在几乎不影响其热导率。 2133
# 并且法庭都明白实际的和公共关系的花费，如果公司必须一个一个地照顾他们的使用者。 2134
# 并且，范多佛还说：“喷口附近的生物似乎会逐渐适应较为频繁严重的自然灾害。 2135
# 并且房地产市场的破产能传导至其他市场，而在这些市场中，银行拥有大量的头寸。 2136
# 并且，非常关键的是DFC与日本的金融和工程应该共同执行该实验计划。 2137
# 并且，分多段级联进行色散补偿，可得到更宽的放大带宽和更平坦的参量增益。 2138
# 并且分给以色列人，无论男女，每人一个饼，一块肉，一个葡萄饼。 2139
# 并且，锋利的刀具切割起来更匀称，所以使用锋利的刀具不止是只有安全这个优势而已。 2140
# 并且负责备品备件的采购，保证有效的存货管理能够满足日常所需避免因备件的短缺造成的停机现象发生。 2141
# 并且，该反应的活性与亚硝酸乙酯的分解程度不存在正比关系。 2142
# 并且该协议不包括贝拉克·奥巴马总统一度所预期的津贴改革。 2143
# 并且，该研究发现RET基因突变与疾病的持续时间有相互关系（兼顾生化指标和转移病灶）。 2144
# 并且，改变所听内容的音调会加强这一效应，这就是“移频听觉反馈”。 2145
# 并且感谢上帝，对方队长总能一次让他铭记于心的握手——坚定而，伴以同样坚定的注视。 2146
# 并且，告诉他不要害怕要澄清事情，如果他遇到不明白的问题或特殊的单词。 2147
# 并且告诉他们，他们所为慈善事业所筹集的钱，公司将会翻倍。 2148
# 并且给出了图像拼接的MATLAB仿真结果。实验表明，该算法能够获得较为满意的拼接效果。 2149
# 并且根据土耳其刑法的严厉规定，任何胆敢将“亚美尼亚悲剧”描述成“种族灭绝”的人都会面临牢狱之灾，甚至死刑。 2150
# 并且公开了一种用于检测哺乳动物的生殖状况，特别是发情周期的方法。 2151
# 并且工作时间每周超过60小时的那些结了婚的女性和女性比那些没有结婚的工作过度的人们性爱频率高10%。 2152
# 并且勾画出一个以印度为支柱的经济更融合、政治更稳定的南亚和中亚地区的新愿景。 2153
# 并且，关键的是，到底有没有一种审问技巧可以被证明既有效又人道？ 2154
# 并且，光盘使用大量的信息用于微机上。 2155
# 并且跪伏在耶稣足前，感谢他；他是一个撒玛黎雅人。 2156
# 并且过着屎壳郎般的生活，吃自己的，喝自己的，用…… 2157
# 并且还采用了美国最新的悬浮技术，能够在水面上漂浮移动，这令他拥有了一种得天独厚的战略位置。 2158
# 并且还警告学校不能劝阻控诉方进行刑事申诉，不断是在学校应进行的调查进行时还是进行后。 2159
# 并且，还可以看出互惠、信任、开放的文化与企业主（或主要负责人）在当地的社会关系有关。 2160
# 并且还认为法治并不能同社会的必然繁荣划上等号，法律只是形式正义和道德的衍生物。 2161
# 并且还推翻了在2000年最高法院所作的，宣布内布拉斯加州禁止部分生产式堕胎是违宪的裁决。 2162
# 并且还邀请了所有地位显赫的朋友来参加庆祝晚宴。 2163
# 并且还要亲自尝一点点那美味的葡萄酒。 2164
# 并且，还有60%还误认为太阳总是对人的健康有好处的。 2165
# 并且，还有句类似”你应该用法定货币去完成我不能完成的事情“之类的话被一个污点覆盖。 2166
# 并且还有一个问题是到哪里找气态氢，在寒冷的北极地区或者海底最冷的地方或者在底下数百英里的地方。 2167
# 并且含有较高的人畜粪尿成分，氮、磷含量特别是磷含量。 2168
# 并且，毫无疑问，他将把比赛带到他喜欢的节奏，他甚至还能在中卫的位置上有所提高。 2169
# 并且毫无争议的是，那时候穿着红色球衣的球员很大部分都有着极佳的天赋。 2170
# 并且豪华舞厅在二楼。你都记下来了吗？ 2171
# 并且，和对照组（重量级）比较，轻量级的小鼠身体脂肪减少了大约50%，以腹部脂肪减少为著。 2172
# 并且，和往常一样，为了满足桌面用户群的需要，添加了一整套新的音频和多媒体驱动程序。 2173
# 并且，很多人猜想美国是否会出于《共同防御条约》而参加对这个无人小岛的争夺。 2174
# 并且后期破坏不以剪切破坏为主，而是沿着粘结破坏面形成的薄弱面发生拉压式破坏。 2175
# 并且惠普只有一件毫无争议的法宝：利润率约80%的打印机更换用墨盒的销售业务。 2176
# 并且活塞杆的拉力可以通过过滤器调整工作气压的大小来调整。 2177
# 并且基于该方法分析主手的局部灵巧度分布。 2178
# 并且，基于以上这些，我们需要知道哪些有用，哪些没用。这样的话我就可以让医疗保险和医疗补助计划对那些昂贵却没有多少实际用处的检查说不。 2179
# 并且机械式发讯装置，还具有成本低，不需另设防水装置。 2180
# 并且，即使其余的白人工人阶级目前站在共和党阵营，但可能不会坚持很久。 2181
# 并且即使他们没有完成他们的旅程，他们都认为他们已经达到了他们的目标了。 2182
# 并且，即使他输了，他的儿子Rory也可能成为Nevada州的下一任长官。 2183
# 并且极大的处罚一再意味着不光彩的、无缘无故的警察暴力。 2184
# 并且，藉着与祂和好，我们犯罪留下的斑斑血迹就变成雪那样洁白了。 2185
# 并且，几乎所有时候，虽然他们是活跃的病毒传播者，但自身无明显疱疹感染症状。 2186
# 并且几乎所有心脏不好的粉丝都会在大赛的激情中放纵自己（吃高脂肪食品，吸烟，酗酒），这一行为无疑加重了危险。 2187
# 并且继续说道：“听着，不要忘记你说过的话、该做的事；也不要忘记那个年轻人。现在，你可以回家了！” 2188
# 并且，记得原始问题的人更容易发现演讲者欺骗性的回答。 2189
# 并且记住避开一个高糖、高脂肪饮食来帮助保持你的大脑健康可能会随着年龄的。 2190
# 并且记住：如果一个女人从你那里感受到强烈的吸引力，那么其他都不重要。 2191
# 并且加工生产出的艺术花盆仿古效果佳、不褪色、耐用性好、立体效果强。 2192
# 并且假如美国继续有失控的开支行为，其自身也终将承受最大的苦果。 2193
# 并且嫁接筒（1）缝隙的两侧分别固连有开启架（2）。 2194
# 并且建议若要干洗 布套，请于其它可拆部位一同拿去干洗，避免造成由布艺褪色而引起色差。 2195
# 并且将产生一个问题，因为很多人正在搜索这个程序。只能找到便宜的仿制品。 2196
# 并且将它推广到任意具有可数无限分布列的离散型随机变量和随机向量。 2197
# 并且，焦急和焦虑能够触发“战斗还是逃跑”的反应。这个反应会让血液从身体（包括阴茎）流到四肢，以便逃跑或者自卫。 2198
# 并且角鲨会在被酒精浸泡的时间里游动时就会发出其中一种不同寻常的攻击。 2199
# 并且较低的税金并不能补偿在瑞士生活的开支以及其乏味无趣。 2200
# 并且结合模型缩聚技术，降低了模型测量维数的要求。 2201
# 并且结合上述策略，给出了改进的算法伪代码流程并对改进的A*算法的进行验证。 2202
# 并且，金星和火星还增加着你的磁场，本能的驱使，爱怜，交际手腕和你在方方面面的魅力。 2203
# 并且仅仅是中国收入比较好的那些人，才可以从垂死的发达国家手中购买些东西。 2204
# “并且尽管有关政治正确的口惠不少，但狗咬狗的残酷环境依然存在：如果你没有表现，你就被淘汰，”她说道。 2205
# 并且，尽管有一些来自一些名人的光辉账目，科学教会基本上只是一个控制思想的组织。 2206
# 并且进一步拓宽了经营管理权，完善了处置权并确保收益权。 2207
# 并且进一步提出用土壤酶活性来评价橡胶园土壤肥力的必要性。 2208
# 并且经醋酸处理后，细胞壁和螺旋形叶绿体带处亦未见绿色荧光。 2209
# 并且经分维修正后的变异系数、点蚀系数成为衡量腐蚀特性的更通用参数。 2210
# 并且经预测，西班牙将会有个晴好的天气，这位德国人说他这一天的卡丁车将会带给他一个不错的状态。 2211
# 并且，就此而言，对于地方无线电广播和报纸报道，与此相关的一个因素——固执一直驱动着整个“地方”模式。 2212
# 并且就像地球上的火山喷发，当黑洞向星团气体注入高能粒子时，我们可以看到冲击波。 2213
# 并且就像赌场给大玩家提供免费的食宿那样，提前存款投注公司提供可以赎回的奖金作为附加的奖励。 2214
# 并且就像所有厨师一开始就会发现的那样，汉堡或土豆的外皮在它的中心变温之前很容易会烤焦。 2215
# 并且，“旧有的结束”扰乱了我们生活的节奏，就像它们强迫我们看向其他方向，指出我们的短处并认识我们自己。 2216
# 并且具有本品种茶叶的正常香气，香气清爽、醇厚、浓郁、持久、新鲜纯正，没有其他异味。 2217
# 并且具有自由行走、旋转、平移，区域放大，视点平滑切换等多种交互方式。 2218
# 并且据此制作的两台胀接式渗铝管换热器已在某硫酸企业生产中得到长期应用。 2219
# 并且决定在休旅车里住一年就当作是一段长期野营旅行。 2220
# 并且，咖啡因可以使大脑产生高水平的多巴胺，一种大脑中的化学物，使我们充满愉悦感。 2221
# 并且，开放运河沿岸的公共空间的工作正在实施，以使当地人民可以使用并享受这条水道。 2222
# 并且，看起来他们接受了使用更加精确的系统性能测量方法，比如加载和路径分析工具的提示。 2223
# 并且靠着神，盼望死人，无论善恶，都要复活，就是他们自己也有这个盼望。 2224
# 并且靠著他，你们也一同被建筑，因著圣神，成为天主的住所。 2225
# 并且，科学家们也没有预测到日本海岸地区会出现如此强烈的地震。 2226
# 并且可能不会成为这样一个大的提高市场苜蓿。 2227
# 并且可以对色散和色散斜率进行同步独立的补偿。 2228
# 并且，可以肯定的是，你没有权利以他们的身体，健康甚至是生命为代价来遵循你的信仰。 2229
# 并且可以使用脱脂奶和人工甜味剂减少脂肪和糖。 2230
# 并且可以为那些准备陆续出现的事情清理道路，也依赖于我们的盟友完成他们的地面工作。 2231
# 并且可以用我们的树枝来遮挡最炎热的太阳和遮风蔽雨雪。 2232
# 并且拉深筋的各圆角半径的增大都使减薄量和累积等效应变减小。 2233
# 并且来传和平的福音给你们远处的人，也给那近处的人。 2234
# 并且来自池塘底部的泥巴也可以用来给作物施肥。 2235
# 并且利用图表法获得电子温度，基本上不随主电容放电能量的增加而发生变化。 2236
# 并且利用已完成的数值模拟软件，研究分析了主副药室装药量比、副药室点火延迟及活塞质量对串联多药室火炮内弹道性能的影响。 2237
# 并且，《量子危机》有一些部分感觉不完整，就好像有些胶片被遗忘在剪辑室的地板上了。 2238
# 并且两那天早晨在步未践踏黑色的叶子平等地放置。 2239
# 并且芦苇作为清洁且无限量的能源资源可以用来发电。 2240
# 并且，玛丽和劳拉可以睡在底下的床上，就在那里。 2241
# 并且，马克思，辛迪的爱和同情期待着你，但是她害怕你是否仍和你的前妻正在相爱。 2242
# 并且，马丘比丘应会在今年五月（秘鲁安地斯山脉旅游旺季开始）以前重新开放。 2243
# 并且没有许多游客出现在这个网站上只为了查询有趣的复活节彩蛋，或者垃圾问题。 2244
# 并且没有馀剩的人留给他们。因为在追讨之年，我必使灾祸临到亚拿突人。 2245
# 并且每步棋之间留出24小时的时间，以保证比赛的客观性，不会出现快棋赛中的愚蠢错误。 2246
# 并且每当你在发球区打第一杆时，壮观的山脉足够吸引任何人的眼光离开高尔夫球。 2247
# 并且美国法官还有律师们否认（不是总可信的）他们在摄像机前举止不端。 2248
# 并且，美国官员透漏他们是亲兄弟，其中一个邻居称阿沙德对外的名字是卡西姆，阿沙德汗和塔雷克汗是表兄弟。 2249
# 并且美国司法部也警告此类计划有可能触犯了联邦法律。 2250
# 并且美国心脏协会认为每天1500mg的推荐量适用于所有的美国人。 2251
# 并且美国在新兴经济体股票市场的风险投资可能是股票投资，不会产生需要偿还的债务。 2252
# 并且，名师建议考生每天都应该安排一定的时间复习农学，连续集中攻克，持之以恒。 2253
# 并且，默瑞指出，利皮奈的书不止是对金融创新的简单的谴责，而是“呼吁参与创新，考虑如何试图以不同的方式建设它。” 2254
# 并且木瓜属于低热量生果，所以吃的时分完全不必为身体担忧。 2255
# 并且那地的金子是好的；在那里又有珍珠和红玛瑙。 2256
# 并且那家炼油厂也由委内瑞拉国有石油公司PDVSA（委内瑞拉石油公司）以每年18万美元的价格签约租用到2019年。 2257
# 并且那是完全可接受的，不论其他人格类型想要告诉你什么。 2258
# 并且那收割之人的冤声，已经入了万军之主的耳了。 2259
# 并且那“所做的事”就是增加了水和沉淀物（污垢，颗粒物）。 2260
# 并且那些昂贵的机器被放置在一个房间里边，大小不到咱们这间会议室的一半… 2261
# 并且那些查询的人很有可能是“盎格鲁”人，人们经常这样称呼祖籍非拉丁美洲的白人。 2262
# 并且那些想尝试新鲜事物的人还能在夜晚去钓鱼。 2263
# 并且那些总喜欢把简单的是弄复杂的人，我把他们称之为阴谋论者。 2264
# 并且那样看似将为DARPA产生花费于更多未经选拔研究项目的数百万美元尚未能产生的效益。 2265
# 并且那在主里的弟兄多半因我受的捆锁就笃信不疑，越发放胆传神的道，无所惧怕。 2266
# 并且能很容易洗掉或擦掉表面的污垢，让你在任何时候都不失体面。 2267
# 并且能平衡过量的油脂分泌，有效熔解乳化赌塞毛孔的。 2268
# 并且能用英式松饼替换烤面包片吗？ 2269
# 并且你的见证人司提反，被害流血的时候，我也站在旁边欢喜。 又看守害死他之人的衣裳。 2270
# 并且你的见证人司提反被害流血的时候，我也站在旁边欢喜；又看守害死他之人的衣裳。 2271
# 并且，你还要学习一些关于希腊世界的知识，为什么我要在学期一开始,用一节课讲了希腊世界和罗马世界，还有第二圣殿犹太教。 2272
# 并且你将问候并且和这个刚认识的人在微笑、友好、轻松的状态下进行交谈。 2273
# 并且，你可能对于这些无关信息产生怒气，不明白“为什么我要关心某某人是否晒伤了？” 2274
# 并且你可以通过一直告诉她你有多佩服她的付出和分析能力来让她软化。 2275
# 并且你们的答复中，对于遗漏如此重要信息的验证方案，并没有涉及关于它们的编写和批准问题。 2276
# 并且你们的妇人孩子，就是你们所说，必被掳掠的，和今日不知善恶的儿女，必进入那地。 2277
# 并且你们将制订一个对秘书处和管理部门实行深远改革的框架，而现在必须采取后续行动，贯彻执行。 2278
# 并且你们若不是徒然相信，能以持守我所传给你们的，就必因这福音得救。 2279
# 并且，你们知道的，我已要求萨默斯给我看每日经济情报的通报让我们知道正在发生的事情。 2280
# 并且，你能够倾斜的越多，在某种程度上，就越舒服。 2281
# 并且，你瞧，真是笑话，我们竟会在有床铺的房间里吃饭，我还不如死了的好。 2282
# 并且你所种的不是那将来的形体，不过是子粒，即如麦子，或是别样的谷。 2283
# 并且你所种的，不是那将来的形体，乃是赤裸的子粒，也许是麦子，或其他的谷。 2284
# 并且你想问因果关系是否有道理，或者只是意外？ 2285
# 并且你需要提前一个月向这所历史悠久的英国会所预定。 2286
# 并且你应该在每天同一时刻沉思，形成一种习惯。 2287
# 并且你有责任替你自己和你子孙保留，你妹妹所传后代遗传基因的完整性。你说的对。 2288
# 并且，你知道的，我们可以穿越时空去触摸彼此并且对对方都深信不疑，然后团结在一起。 2289
# 并且您还有义务归还因信息错误而支付给您的失业补助金。 2290
# 并且，您永远也不会真正了解需要为您的发行版安排多少工作。 2291
# 并且宁静的睡眠有助于长久的记忆。 2292
# 并且浓密地种植着各种各样的树木，它们以其巨大的身躯和其他一些魅力，令观赏者赏心悦目…… 2293
# 并且，配有适当的设计，在任何一点触碰水墙的表面，能够沿着墙水平地传播图象到任何位置。 2294
# 并且碰巧有一颗行星形成，距离大概和地球距太阳的距离相同、有相同的倾斜角和大气。 2295
# 并且铺床是一个简单而快速的使房屋表面看起来整洁的方法（即使你的衣柜一团糟）。 2296
# 并且，普通的乳房摄片只能显示肿瘤的一部分，普通乳房摄片上的一个小的瑕疵通常是实际大的多的病灶的核心。 2297
# 并且其它的研究也表明，越早到达座标零点的急救员，会病得越重。 2298
# 并且，其中一些潜在的新药其作用方式与现存的抗生素完全不同。 2299
# 并且，企业“预案制定者”在考虑“黑天鹅”型事件时也比之前要好很多。 2300
# 并且牵着他的手，把他领到附近一个百货超市并买了一双新鞋子和一件夹克。 2301
# 并且，前者依股东多数决作出决议后通知失权股东即生效，后者则需提起失权诉讼作出判决后才能生效（即双轨制）。 2302
# 并且谴责着那些通过我们的灵魂和秘语而发动战争的死亡的力量 2303
# 并且巧妙的应用设计元素构成了视觉冲击，并给审美者带来来遐想的空间。 2304
# 并且，请填写下边的请愿，告诉我们你如何打算为和平而自我性爱。 2305
# 并且求祂藉著祂统管万有的护理，引导并安排万事，使祂自己得荣耀。 2306
# 并且，区别实现各用例的优先级，有助于你选择从哪儿来开始。 2307
# 并且躯干拮抗肌的起始潜伏期随着目标的距离增加而增加，重量的加重而减少。 2308
# 并且，取替爆炸，你可以能控制的热量终结，这些能量用来加热水。 2309
# 并且，确实是，马德里很久没有享受过完整的一场比赛了。 2310
# 并且确实，我见过他滥用这种无害的才能用来找麻烦惹事。 2311
# 并且，群岛还处在繁忙的航线上，这正是支撑急剧扩张的中国经济的石油及其他资源的运输命脉。 2312
# 并且燃烧室膜片是无间断地由底部段通过过渡段进入封闭段。 2313
# 并且，让你吃惊的是你可能就认识一个瘾君子。 2314
# 并且让自性等在不被干扰的情况下，取得充分发挥的空间。 2315
# 并且人们缺乏毅力，容易气馁，遇到困难就退缩，不能坚持下去，容易放弃。 2316
# 并且人们认为所有油藏模拟模型得出的结果都会在很大程度上受到下伏地质模型的影响。 2317
# 并且人要奉他的名传悔改赦罪的道，从耶路撒冷起直传到万邦。 2318
# 并且人要靠着他的名，传悔改以得赦罪之道，从耶路撒冷起，直到万邦。 2319
# 并且任何一方的放弃某一权利的行为并不及于对以后类似事情，没有默认效力。 2320
# 并且认为隐信道技术不是一个独立的技术，而是信息隐藏技术的一个分支。 2321
# 并且，溶液中的胺类化合物和酚的氧化产物聚合生成棕色沉淀而被除去。 2322
# 并且，如果不是时机成熟而结成的婚姻，政府会给建立家庭新人一笔现金或是礼物。 2323
# 并且如果不是由于衰退导致全球贸易量自2009年开始大幅下降，逆差可能会更大。 2324
# 并且如果发现货物与合同不符，我们可以向你们提出索赔，或拒绝接受货物。 2325
# 并且如果顾客不能访问你的系统或业务不能进行工作，那么由可靠性或性能问题引起的运作停工就会招致机会成本。 2326
# 并且，如果花太多的时间深入挖掘这些为数众多的末日前景，真的会导致一个人进入一种非常负面的精神状态。 2327
# 并且如果美国不行动，欧洲将毫无疑问地在某一时刻放弃其绿色主张。 2328
# 并且如果美国能够模仿新兴经济体的出口导向增长，它就没有必要参照它们的产业政策。 2329
# 并且如果你等到那时，在你买一个蒲团之前，一切可能都结束了。 2330
# 并且如果你工作时不能感受爱，而只有厌恶，那你应该远离此工作，坐在寺庙的入口，接受那些从工作中获得快乐的人的救济品。 2331
# 并且如果你将人类换成其他任何动物，这个仅有的解释将是不成立的。 2332
# 并且，如果你没有预备好付出代价的话就不要把“自由”一词放在你的词汇量里。 2333
# 并且，如果你倾斜的比较厉害，就需要用肌肉的力量来支撑头部这就是为什么在这儿需要个靠头之物了。 2334
# 并且，如果你是一个KDE桌面的用户，你将彻底爱上它QT下的界面，尽管它（如同大多数QT程序一样）在Gnome下也很美。 2335
# 并且如果您的类型不符合该类型，编译器会给出警告。 2336
# 并且，如果您提前完成了所有分析和设计工作，那么您的设计可能不会随着您对该特性的进一步了解而发生改变。 2337
# 并且如果我的孩子试图把钢琴塞进他们的嘴里，我会在他们尝试前带他们去测智商。 2338
# 并且，如果预先没行使此外将终止和不再是可执行的。 2339
# 并且如果最初的刺激在消费和商业支出中触发了爆发式增长，那么乘数效应就会超过一。 2340
# 并且如你问题中所说，有闪烁技能的蹑踪者和有灵能风暴的高阶圣堂武士都可以很好的反击女妖。 2341
# 并且如同培地女孩一般，梦露在百万人面前是一个梦幻偶像而不是色相。 2342
# 并且瑞吉斯承认在沿着这些线索展开（搜索）的时候她有一些惶恐。 2343
# 并且，萨马拉斯还表示，他不会代表所在党签署任何由欧盟提出的援助条件。 2344
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-292-98a9f3e6ed13> in <module>()
#       1 for i in range(len(lol)):
# ----> 2     print(lol[i], i)
#
# C:\Users\chuck189\Anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     369             is_child = (not self._is_master_process())
#     370             # only touch the buffer in the IO thread to avoid races
# --> 371             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     372             if is_child:
#     373                 # newlines imply flush in subprocesses
#
# C:\Users\chuck189\Anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     188                 event_id = os.urandom(16)
#     189             self._events[event_id] = f
# --> 190             self._event_pipe.send(event_id)
#     191         else:
#     192             f()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send (zmq\backend\cython\socket.c:7305)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send (zmq\backend\cython\socket.c:7048)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy (zmq\backend\cython\socket.c:2920)()
#
# C:\Users\chuck189\Anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc (zmq\backend\cython\socket.c:9621)()
#
# KeyboardInterrupt:

# %%
lol[0].encode("unicode-escape").decode("gb18030")#.decode("gb2312")
# Out:
# '\\xe8\\xa1\\xa8\\xe6\\xbc\\u201d\\xe7\\u0161\\u201e\\xe6\\u02dc\\u017d\\xe6\\u02dc\\u0178\\xe6\\u02dc\\xafX\\xe5\\xa5\\xb3\\xe5\\xad\\xa9\\xe5\\u203a\\xa2\\xe9\\u02dc\\u0178\\xe2\\u20ac\\u201d\\xe2\\u20ac\\u201d\\xe7\\u201d\\xb1\\xe4\\xb8\\u20ac\\xe5\\xaf\\xb9\\xe5\\u2026\\xb7\\xe6\\u0153\\u2030\\xe5\\xa4\\xa9\\xe6\\u2030\\xe6\\u0160\\u20ac\\xe8\\u2030\\xba\\xe7\\u0161\\u201e\\xe8\\u2030\\xb3\\xe8\\u02c6\\u017e\\xe5\\xa5\\xb3\\xe5\\xad\\xa9\\xe4\\xbb\\xac\\xe7\\xbb\\u201e\\xe6\\u02c6\\xef\\xbc\\u0152\\xe5\\u2026\\xb6\\xe4\\xb8\\xad\\xe6\\u0153\\u2030\\xe4\\xba\\u203a\\xe4\\xba\\xba\\xe5\\u2014\\xe8\\xbf\\u2021\\xe4\\xb8\\u201c\\xe4\\xb8\\u0161\\xe7\\u0161\\u201e\\xe8\\xae\\xad\\xe7\\xbb\\u0192\\xe3\\u20ac\\u201a'

# %%
print(lol[0])
# Out:
# è¡¨æ¼”çš„æ˜Žæ˜Ÿæ˜¯Xå¥³å­©å›¢é˜Ÿâ€”â€”ç”±ä¸€å¯¹å…·æœ‰å¤©æ‰æŠ€è‰ºçš„è‰³èˆžå¥³å­©ä»¬ç»„æˆï¼Œå…¶ä¸­æœ‰äº›äººå—è¿‡ä¸“ä¸šçš„è®­ç»ƒã€‚

# %%
re.split("(?<![A-Z][a-z])(?<![A-Z][a-z][a-z])\.", c2015en[0])
# Out:
# ['<s> <s> The show stars the X Girls a troupe of talented topless dancers some of whom are classically trained </s> </s>']

# %%
re.split("(?<![A-Z][a-z])(?<![A-Z][a-z][a-z])\.", c2015en[25])
# Out:
# ['<s> Drama is important too',
#  ' Placebo injections are more effective than placebo pills and neither is as potent as sham surgery </s>']

# %%
trigram(c2015en[0].split(" "))
# Out:
# {'<s> The': {'The show': 1.0},
#  'Girls a': {'a troupe': 1.0},
#  'The show': {'show stars': 1.0},
#  'X Girls': {'Girls a': 1.0},
#  'a troupe': {'troupe of': 1.0},
#  'are classically': {'classically trained': 1.0},
#  'classically trained': {'trained </s>': 1.0},
#  'dancers some': {'some of': 1.0},
#  'of talented': {'talented topless': 1.0},
#  'of whom': {'whom are': 1.0},
#  'show stars': {'stars the': 1.0},
#  'some of': {'of whom': 1.0},
#  'stars the': {'the X': 1.0},
#  'talented topless': {'topless dancers': 1.0},
#  'the X': {'X Girls': 1.0},
#  'topless dancers': {'dancers some': 1.0},
#  'troupe of': {'of talented': 1.0},
#  'whom are': {'are classically': 1.0}}
