# %% [markdown]
# # Model
# #### Charlie Liou

# %%
import numpy as np#, pandas as pd
import re, string
import os, glob, requests
from bs4 import BeautifulSoup
from itertools import chain

# %% [markdown]
# Much of this is adapted from Kevin Knight's [A Statistical MT Tutorial Workbook.](http://www.isi.edu/natural-language/mt/wkbk.rtf)
#
# To write a statistical Chinese to English translator, we will consider English sentences $e$ and Chinese sentences $c$. This may seem like solving the opposite problem, but given $c$, we seek the English sentence that will maximize $P( e \mid  c)$ (that is, the most likely English sentence when given the Chinese sentence.) This reversal will be explained later. More formally, we are trying to find the english sentence $\vec{e}$ that satisfies
#
# $$\vec{e} = \arg\hspace{0.05cm} max\hspace{0.05cm}P(e \mid c)$$
#
# How do we approach maximizing the probability $P(e \mid  c)?$ Bayes' Theorem tells us:
#
# $$P( e \mid  c) = \dfrac{P(e)\hspace{0.05cm}P(c\mid e)}{P(c)}$$
#
# which allows us to reformat our problem into
#
# $$\vec{e} = \arg max\hspace{0.05cm}P(e \mid c) = \arg max\hspace{0.05cm}P(e)\hspace{0.05cm}P(c \mid e)$$
#
# This is pure Bayesian reasoning; think of the given Chinese sentence $c$ as a crime scene. Knight gives a good analogy for this: $e$ is the person who did the crime, $P(e)$ is the description of the person, and $P(c \mid e)$ is how they did it. There are possibly many people who fit the description of $P(e)$ but those people may not have the means of committing the crime. Likewise, there are possibly many people who have the means $P(c \mid e)$ of committing the crime but they don't fit the personality. We're trying to solve for the person who is most likely to commit the crime and has the means to commit it.
#
# Now if we think about translating language itself, accurate syntax and translations are necessary. We can't have one without the other. In our last equation, $P(e)$ is equivalent to correct syntax and $P(c\mid e)$ is equivalent to correct translations. This is why we must maximize the probability $P(e \mid c)$. Maximizing this probability is equivalent to finding sentences that have correct syntax and accurate translations.

# %% [markdown]
# ## Language Model
#
# To account for syntax, meaning finding values of $P(e)$, we use a *n*-gram model. I will find a trigram using data from  `casia2015_en`, TED talks, NLTK's Brown corpus,

# %% [markdown]
# Data directory:

# %%
#my personal computer
path = "C:/Users/chuck189/Desktop/Cal Poly Summer Research 2017/data"

#math lounge computer
#path = "/Users/csmuser/Desktop/Cal Poly Summer Research 2017/data"

# %% [markdown]
# This function generates *n*-grams when n = 3.

# %%
def trigram(list_, temp = {}, freqs = {}):
    '''
    Takes a list of strings (which are sentences) and a dictionary with phrase frequencies
    Returns a trigram and updated phrase frequencies.
    '''
    
    for sent in list_:
        
        sent = sent.split()
        
        for i in range(0, len(sent) - 2):
            ot = sent[i] + " " + sent[i + 1]
            tt = sent[i + 1] + " " + sent[i + 2]
            if ot in temp:
                if tt in temp[ot]:
                    temp[ot][tt] += 1
                else:
                    temp[ot].update({tt : 1})
            else:
                temp.update({ot : {tt : 1}})
    
    for i in list(temp):
        num = 0
        for j in list(temp[i]):
            num += temp[i][j]
            if temp[i][j] in freqs:
                freqs[i] += num
            else:
                freqs[i] = num

    
    return temp, freqs

# %% [markdown]
# This functions generates *n*-grams when n = 4.

# %%
def fourgram(list_, temp = {}, freqs = {}):
    '''
    Takes a list of strings (which are sentences) and a dictionary with phrase frequencies
    Returns a trigram and updated phrase frequencies.
    '''
    
    for sent in list_:
        
        sent = sent.split()
        
        for i in range(0, len(sent) - 3):
            ot = sent[i] + " " + sent[i + 1]
            tt = sent[i + 1] + " " + sent[i + 2]
            if ot in temp:
                if tt in temp[ot]:
                    temp[ot][tt] += 1
                else:
                    temp[ot].update({tt : 1})
            else:
                temp.update({ot : {tt : 1}})
    
    for i in list(temp):
        num = 0
        for j in list(temp[i]):
            num += temp[i][j]
            if temp[i][j] in freqs:
                freqs[i] += num
            else:
                freqs[i] = num

    
    return temp, freqs

# %% [markdown]
# - check for two and three capitalized letters ending with a period
# - send everything to lowercase

# %%
one = ["i like dog", "i like cats", "i like to go running"]
two = ["我喜欢狗", "我喜欢猫", "我喜欢跑步"]
#lol = []
#lol.append(nltk.AlignedSent(nltk.word_tokenize("i like dog"), [x for x in "我喜欢狗"]))
#lol.append(nltk.AlignedSent(nltk.word_tokenize("i like dog"), [x for x in "我喜欢狗"]))
#lol.append(nltk.AlignedSent(nltk.word_tokenize("i like cats"), [x for x in "我喜欢猫"]))
#lol.append(nltk.AlignedSent(nltk.word_tokenize("i like to go running"), [x for x in "我喜欢跑步"]))
#temp = nltk.translate.IBMModel2(lol, 10)
f, b, left, right = ibm2_align(3, 5, one, two)
# Out:
# ([AlignedSent(['i', 'like', 'dog'], ['我', '喜', '欢', '狗'], Alignment([(0, 2), (1, 2), (2, 3)])),
#   AlignedSent(['i', 'like', 'cats'], ['我', '喜', '欢', '猫'], Alignment([(0, 2), (1, 2), (2, 3)])),
#   AlignedSent(['i', 'like', 'to', 'go', 'running'], ['我', '喜', '欢', '跑', '步'], Alignment([(0, 2), (1, 2), (2, 4), (3, 4), (4, 4)]))],
#  [AlignedSent(['我', '喜', '欢', '狗'], ['i', 'like', 'dog'], Alignment([(0, 1), (1, 1), (2, 1), (3, 2)])),
#   AlignedSent(['我', '喜', '欢', '猫'], ['i', 'like', 'cats'], Alignment([(0, 1), (1, 1), (2, 1), (3, 2)])),
#   AlignedSent(['我', '喜', '欢', '跑', '步'], ['i', 'like', 'to', 'go', 'running'], Alignment([(0, 1), (1, 1), (2, 1), (3, 4), (4, 4)]))],
#  <nltk.translate.ibm2.IBMModel2 at 0x10f951fd0>,
#  <nltk.translate.ibm2.IBMModel2 at 0x107b9fa20>)

# %%
nltk.pos_tag("The store will be visited by him today".split(" "))
# Out:
# [('The', 'DT'),
#  ('store', 'NN'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('visited', 'VBN'),
#  ('by', 'IN'),
#  ('him', 'PRP'),
#  ('today', 'NN')]

# %% [markdown]
# ### CASIA 2015

# %%
import nltk, time

# %%
os.chdir(path + "/casia2015")
files = glob.glob("*.txt")

engtemp = open(files[1], "r", encoding = "utf-8").read().split("\n")
chtemp = open(files[0], "r", encoding = "utf-8").read().split("\n")

# %%
for i in chtemp:
    print(nltk.word_tokenize(i), len(nltk.word_tokenize(i)))
    time.sleep(0.2)
# Out:
# ['表演的明星是X女孩团队——由一对具有天才技艺的艳舞女孩们组成，其中有些人受过专业的训练。'] 1
# ['表演的压轴戏是闹剧版《天鹅湖》，男女小人们身着粉红色的芭蕾舞裙扮演小天鹅。'] 1
# ['表演和后期制作之间的屏障被清除了，这对演员来说一样大有裨益。'] 1
# ['（表演或背诵时）通过暗示下面忘记或记地不准的东西来帮助某人。'] 1
# ['表演基本上很精彩', '--', '我只对她的技巧稍有意见。'] 3
# ['表演结束后，我们看到一对对车灯沿主路一路排回镇上，然后散开来各回各家。'] 1
# ['表演结束后，移走了背景墙，随后全体演员即兴邀请观众上台齐跳并排舞。'] 1
# ['表演结束后用宣纸轻铺水面，可将水面上的画进行拓印保存。'] 1
# ['表演结束后，众人期待已久的园游会终于正式开锣，美味可口的素食佳肴让大家一饱口福。'] 1
# ['表演节目丰富精采，交换礼物的欢乐时刻一到，则形成另一波高潮。'] 1
# ['表演仅仅是造就一个近乎觉察不出来的「直线的地质的移位」。'] 1
# ['表演开始十五分钟后，一帮足球运动员开始集体向着舞台上的女演员发出嘘声。'] 1
# ['表演开始时，舞台上会有一张床，一面镜子，一张椅子以及一位穿着内衣的美女。在你觉察到前，一位性感的女孩会突然变成三位。'] 1
# ['表演开始时，艺人坐在地毯上轻击盅子，徐缓起舞；'] 1
# ['表演', '“', '猫女', '”', '——在一个笼子里穿着带有一根长尾巴和猫耳的豹纹女内衣。'] 5
# ['表演前，她紧张得浑身颤抖不已。'] 1
# ['表演是他们的嫡传技艺，150多年来他们家族一直都是演员。'] 1
# ['表演算得上是一门残忍的职业，你偏离正统美越远，就越艰难。'] 1
# ['表演我软木塞哪一呼吸和我将表演你一瓶醋。'] 1
# ['表演：悉尼歌剧院首席男高音丁毅先生悉尼歌剧院首席女高音'] 1
# ['表演秀以及开园时间有可能因故不经预告而取消或中止，敬请留意。'] 1
# ['表演一个不限分析国内受损的期望往往带来了个人工作的公司。'] 1
# ['“', '表演', '”', '一结束，他马上给那名黑人', '“', '歹徒', '”', '发工钱，然后两个人还握手拥抱。'] 8
# ['表演艺术家MarniKotak（持玩偶者）在布鲁克林的', '“', '显微镜', '”', '画廊生下一婴作为她艺术作品的一部分。'] 5
# ['表演艺术来源于生活而高于生活，生活是艺术创作的来源，取之不尽用之不竭的源泉。'] 1
# ['表演在安慰疗法中也很重要。安慰性注射虽然比安慰药丸有效果，但是却没有虚假手术来得见效。'] 1
# ['“', '表演在本质上给了他们一个正当的理由去学习如何表达自己。', '”', '阿伦森说。'] 4
# ['表演者把信封靠近他的脑袋，然后先给出答案，再打开信封，读问题。'] 1
# ['表演者包括歌手马尼洛和富兰克林；歌手们星期五将向观众献上一场彩排。'] 1
# ['表演者会带来他自己的吸引力，他自己的感性，他自己的作者。'] 1
# ['表演者没有大炮火药了，于是Clifford吹气把她发射出去了。'] 1
# ['表演者拿一个小簸箕在上面炒，过一会，爆米花就出来了。'] 1
# ['表演者热情地向中国贵宾赠送斯特森骑士帽。'] 1
# ['表演者在冰上的那种潇洒的风格为她赢得了许多朋友和一块金牌。'] 1
# ['表演者在开幕典礼庆祝活动溅水的首届青年奥运会星期六2010年8月14日在新加坡举行。'] 1
# ['表演者，指演员或者其他表演文学、艺术作品的人。'] 1
# ['表演中用打击乐伴奏，但狮舞的动作不受音乐节奏的限制，音乐只起烘托气氛的作用。'] 1
# ['表一：对人体肠道的通透性，作为替代标记使用极地糖尿execretionGIPET我的时间。'] 1
# ['表已经成为有身份或有品味——抑或是身份或品味低下——的新标志。'] 1
# ['表意的主观性和抽象性导致小说偏向表现', '“', '形而上的现实', '”', '。'] 5
# ['表英尺组表页脚始终显示在其他所有行和行组，和之前的底部字幕。'] 1
# ['表有8毫米厚的明确钢化玻璃与抛光边缘和沙丘抨击标志的顶端小组。'] 1
# ['表有结构简单、口径大、重量轻、操作方便等优点。'] 1
# ['表彰他在电路，系统和信号处理，尤其是数字滤波方面的贡献。'] 1
# ['表征的结果显示PAS分子筛具有更多的适合蜡分子异构化反应的孔径分布。'] 1
# ['表征的途径，其中一项是作家揭示了这样一个人物身份证的个性。'] 1
# ['表征影像学表现上皮样血管瘤，我们审查了现有文献关于这一主题的。'] 1
# ['表值对象可以是表、视图、函数、同义词或本地表。'] 1
# ['表中的大多数术语在本书最后所附的', '“', '名词汇编', '”', '中均有说明。'] 5
# ['表中的第一列包含任务，后面两列指明任务是否在其原始平台上进行操作。'] 1
# ['表中光照度数据为上午和下午两次观测值的平均值。'] 1
# ['表中基因的一列相对于表达数据发生了调换，导致两项不相对应。'] 1
# ['表中继续述说着两个甚至更多世纪的全食，然而持续时间逐渐减少。'] 1
# ['表中所列电参数为参考值，实际电参数会因使用条件的不同而变化。'] 1
# ['表中也显示了每个版本的小计以及顾客的总费用。'] 1
# ['裱糊纸板：用多张较薄纸板裱贴而成的纸板。有别于均质纸板。'] 1
# ['憋了几个月，等啊等，等待市场推出一款你钟爱的平板电脑。'] 1
# ['憋死我了！你也不说，我也不说，咱俩总得有一个来挑明吧！算了，我不下地狱谁下地狱。我说了', '“', '我爱你', '”', '！'] 5
# ['瘪版是堵住雕镂或蚀刻制成的，制成的版镀铬后会补充硬度，以提矮耐印度。'] 1
# ['瘪印版滚筒不合为有轴版滚筒和无轴版滚筒。'] 1
# ['瘪印机洋牵引辊与初版辊相邻凡是撤有周速同步机构。'] 1
# ['瘪印在制卡和会员卡制作金属油墨时不入格得当。柔印在上光方面也有其独到之处。'] 1
# ['瘪制卡和会员卡制作又不合为雕镂不不凸版与拍照印版两栽。'] 1
# ['“', '别啊，', '”', '他喊道，冷笑着，', '“', '我们可以把这脏东西当奴隶卖了呀，正好可以换一碗酒钱呢。', '”'] 7
# ['别按你自己的想象认为他们需要什么；做些用户研究去确切地发现他们所需。'] 1
# ['别把关心你的人扔在角落，否则会让你更受伤。'] 1
# ['别把火炬受干扰当成那整个城市或国家不可饶恕的罪过。'] 1
# ['别把莓果掉出来，因为正如大家所知，最快装满桶子的第一只熊就可以赢得比赛喔！'] 1
# ['别把你的车子停在我的房子外边，你想想人家回怎么说！'] 1
# ['别把数学想象为硬梆梆的、死绞蛮缠的、令人讨厌的、有悖于常识的东西，它只不过是赋予常识以灵性的东西。'] 1
# ['别把所有的积蓄花在整修住所，存下出游的金额。'] 1
# ['别把他算进去。你还不了解他吗。他的决心持续不了三分钟。'] 1
# ['别把它当作不切实际、或是必须经过选民公投通过的事情。'] 1
# ['别把它丢失在你的爆米花里，ICM公司的老板认为，互联网能够降低新的电影拍摄者的进入门槛。'] 1
# ['“', '别把我的心搅乱了，我亲爱的保罗，', '”', '他的妹妹说道，', '“', '因为这会毁了我。'] 6
# ['别把我框死在一个岗位上！除了接电话，我还可以做许多其他事情！'] 1
# ['别把我们两个人算在一块儿，哈丽特。拿我的演奏同她的相比，就如同一盏灯同太阳相比。'] 1
# ['别把我弄糊涂了，力量举需要很多的技术，我刚才说的意思是举重是更热门的竞技运动。'] 1
# ['别把香蕉船算我那份里，我想我还是想点份三克巧克力华夫饼蛋卷冰激凌吧。'] 1
# ['别把雪柜放置在煮食炉和发热源头旁，也避免放在有阳光直接照射的窗户。'] 1
# ['别把一个人想的有多高尚，也别把一个人想的有多龌龊'] 1
# ['别把衣服扔在椅子上，把它们挂起来。'] 1
# ['别把油漆胡乱刷得这么厚，他们要求外表光滑美观。'] 1
# ['别把这头猪说成是受害者，这个可怜的女人才是受害者！那些帮助她的人都做得很好，但是没必要把它拍下了！'] 1
# ['别把这些都当成是你自己的事情：即使你是那个拿着高薪，深感不安，并且一次又一次地触及他们失望底线的家伙。'] 1
# ['别把自己弄得像个太监一样，连自己的理想都要去遗忘，这样你真的会开心？'] 1
# ['别霸占着你不用的东西！既然你下午有课，就把网球拍让我用。'] 1
# ['别拌嘴了，女士们。就让我们也偶尔在舒适的床上享受一个平静的夜晚吧。'] 1
# ['别抱怨你假期花钱太多，你倒是玩得痛快。鱼与熊掌不可兼得嘛。'] 1
# ['别被教条捆住了，否则你就只是生活在别人思考的结果里。'] 1
# ['别被名字给弄混了，它出售的是时髦的围裙、手袋、钱包以及非常传统式样的垫桌布。'] 1
# ['别被秋分日昼夜长短相等的概念愚弄了。'] 1
# ['别被他谦虚的态度骗了，其实他是个很骄傲的人。'] 1
# ['别被这个狡猾的忍者所愚弄！这其实是一个优盘。'] 1
# ['别逼着他们告诉你他们的心事。那将惹怒他们，可能另他们感觉更糟。'] 1
# ['别别，没但是。只要你客观点看待这个情况，这份工作就该归我。'] 1
# ['“', '别，别着急放下灯笼，看来，还有一个要出来！', '”', '，医生不由得惊叫起来。'] 4
# ['别不承认你内心最深处的事情，爱她胜过爱你自己，没有她你的生活毫无意义。'] 1
# ['别不假思索的就怪罪于母亲：一个爱哭的、得腹绞痛的宝宝也同样会是由父亲的情绪而影响形成的，荷兰研究人员的报告说。'] 1
# ['别操心化妆了这样可以让你的皮肤透透气', '--', '但得确保先抹上滋润霜。'] 3
# ['别缠我了，要不我就把你关进橱柜里去了！'] 1
# ['别抄杰克逊的观点了，他那一套现实主义已经用够了，再也没有什么意思。'] 1
# ['别嘲笑我了。我是认真的。我以前从来没有被要求写这种报告，我只写研究报告。'] 1
# ['“', '别吵！你们这些蠢孩子！', '”', '当她们去敲门的时候，他这样说。'] 4
# ['别臭美了，我又不是专为你做的，我每个周末都这样吃。'] 1
# ['别处，在靠近塞纳河处，甚至在离河还相当远的地方，比如在贝尔维尔、在大道和吕尼埃通道上。'] 1
# ['别吹牛了，人们说，真是搞笑。心智正常的人不会将英国君主制的庄严和对自由的威胁混淆。'] 1
# ['别从你的乐队里拿些第三单簧或者第二低音声部的谱来做考试材料。'] 1
# ['别错过机会', '--', '我向你保证我的投资方法可以使你的收入在一年内翻番。'] 3
# ['别错过了上帝赐给你们彼此享受那甜美沟通的福气。'] 1
# ['别错误的认为你能通过私交，表现人性化的一面，就能让你的恶霸老板熄火。'] 1
# ['别打断谈话，这不礼貌，并表示出你认为你要说的比他们说的要更重要。'] 1
# ['别打搅我妹妹。要是我再看到你靠近她，我就要狠狠地揍你一顿了。'] 1
# ['别打她家里电话，要不然她会滔滔不绝地说几个小时。'] 1
# ['别耽搁，别疏忽，因为我将不会再走一回了。'] 1
# ['别担心啊，至少还有我陪你嘛，我们玩一会网路游戏好吗？'] 1
# ['别担心。把那个冰桶给我，然后把这个拿到隔壁去。'] 1
# ['别担心董事长对接受出价如何反应，他正斗志旺盛呢。'] 1
# ['“', '别担心，夫人。', '”', '布莱克先生说，', '“', '你应该减肥，如果你按我说得去做你有可能穿上你的外套了。', '”'] 7
# ['别担心，服用Liquid-Plumr-Cardio后，你的舌头只会绿一两个小时。'] 1
# ['别担心', '--', '规则跟规则不一样（有的规则比其他规则重要，容易疏忽等）。'] 3
# ['别担心化妆了，这样可以让你的皮肤透透气——但是皮肤上涂抹上滋润霜。'] 1
# ['别担心会被水母螫到，这些水母没有天敌，所以牠们的螫刺是无害的。'] 1
# ['别担心！假如你噎到的话，我会替你做谦烈治拯救法的！'] 1
# ['别担心，叫做无尾熊完全无损于他是一位电脑专家啦', '!'] 2
# ['别担心，警察不会因为你说了几句出格的话就来抓你的，真理在你一边，你不会有事的。'] 1
# ['别担心老板，就我的白内障看来，你只是看上去像个坏蛋。'] 1
# ['别担心了。今年我和你一起去，帮你挑些清淡的。我一直都想去见识一下年货市场。'] 1
# ['别担心没进校队的事，你还有机会的。'] 1
# ['别担心你的钢琴独奏会。船到桥头自然直。'] 1
# ['别担心你的梦想不太实际，只要你觉得可能实现，就是个好梦想。'] 1
# ['别担心你写下来的东西没有（或者欠缺）理性，因为头脑风暴活动结束后，你可以选择保留还是抛弃哪些概念。'] 1
# ['别担心。你只要围上头巾，穿上衣服，你就看上去很有女性味了。'] 1
# ['别担心其它小组的反对意见，你正在做对的事，逆境出人才。'] 1
# ['别担心.让我们先用灰色眼影笔在你的眼睫毛外侧画上眼线.然后用手指头把眼线涂开.下一步.刷上一层淡蓝色的眼影在眉毛下.来增加一点立体感', '.'] 2
# ['别担心，如果你在闻海地咖啡时把这种苹果香味和新割青草的味道搞混的话是没有人会怪你的。'] 1
# ['“', '别担心，', '”', '她笑着，一面看看他的脚。', '“', '你的聪明才智挽救了今天的婚礼。', '”'] 7
# ['“', '别担心，太太，', '”', '士兵们对她说，', '“', '我们不是冲孩子开战。', '”'] 7
# ['别担心！天气预报员说，在这个周末之前，会有一阵子的冷天气。'] 1
# ['别担心，为了照顾你，这份高中毕业就能读懂？沟眯荒？哥们儿。'] 1
# ['别担心。我把地图从杂物柜里拿出来看一下……嗯，我们在哪里？'] 1
# ['别担心，我的木头朋友们！你们对闪电已经有很好的防护了。'] 1
# ['“', '别担心，我会帮助你的！', '”', '小熊说。他把小老鼠放进衣服口袋里又继续往前跑去。'] 4
# ['别担心，我会找到像你一样的人。我希望你过很好……'] 1
# ['别担心，我今天下午就去找人来看一下，同时，我让他们把您要的文件重新发到其他传真机上。'] 1
# ['别担心，我们帮你对不同的设计领域进行了调查，找出哪里的工作幸福指数最高。'] 1
# ['别担心，我们知道，即使是一个高尔夫球俱乐部也可能拥有这样的名字，所以不要太在意，这仅仅是一个名字而已。'] 1
# ['别担心，一点点的磨损是免不了的。'] 1
# ['别担心伊朗，伊朗会给任何来犯者好好上一课。你会看到伊朗和中国将领导世界。'] 1
# ['别担心，由我来承担她的怒火，孩子。不过这些人有很重要的事要告诉我女儿。'] 1
# ['别担心。在几天内会有太多的去做…然后你就会想要回这些懒惰的日子。'] 1
# ['别担心，这不会是世界末日，至少需要相当长一段时间，但世界却会变得不同。'] 1
# ['别担心。这是对人的耐力和智力的检验，对多数人而言，尝试一次就已经够勇敢的了。'] 1
# ['别担心，只要你礼貌的寻求签名或是照片的话，其实是没有问题的，但是不要', '“', 'gawkatthem', '”', '（盯着他们看）就行。'] 5
# ['别担心装傻的样子很拙劣，即使每个人都看出你在装傻，可他们依旧拿你没办法。'] 1
# ['“', '别挡道。', '”', '他说，朝哈利胸口就是一拳。'] 4
# ['“', '别捣乱', '”', '的说法对孩子们并不适用，因为他们时刻准备着捣乱，想方设法达到自己的目的。'] 4
# ['别的，本文还将分析', '“', '恻隐', '”', '和', '“', '骑士精神', '”', '的实质和浪漫色彩在小说中的表现。'] 9
# ['别的不多说，铃木一郎通过拍摄时尚杂志照片和在公众场合亮相为自己打造品牌。'] 1
# ['别的不说，个性外向的郎朗似乎还没被自己的名声冲昏头。'] 1
# ['别的不说了，最后所有同事都在MUJI购了2件以上的产品。'] 1
# ['别的', '“', '登陆者', '”', '要不是力不从心就是疲于应付。'] 5
# ['别的地方实在是太别扭，太闷气了，可是木筏上的情况却不是那样。'] 1
# ['别的地方也有很多抗议者，他们正在从大本营被清场后经历的动荡和困惑中恢复。'] 1
# ['别的公司很难与他们竞争是无可争辩的事实。'] 1
# ['别的俱乐部怎么样呢？你最近在推特上质疑曼城的赞助协议…'] 1
# ['别的邻居们有的执教足球队，探视病人，有的驱车访问那些羁居于家的人，辅导那些辍学学生，教成年人读书。'] 1
# ['别的男孩都叫汤米娘娘腔的男孩因为没有母亲在旁他就不肯出来玩。'] 1
# ['别的男人可能已经被她所吸引，忽然之间有了保护她的冲动，而爱德华兹却开始感觉到占有的欲望。'] 1
# ['别的鸟儿或走兽谁都没吭声儿，不过渡渡鸟还等着提问题呢，因此爱丽丝问：', '“', '什么是考克斯赛跑？', '”'] 4
# ['别的鸟儿们看见它并不曾被我伤害，也飞下来啄着谷粒，所以在一个短短的时间内，在我的四周，完全是一大群乌鸦。'] 1
# ['别的，欠债运营风险也是企业停止资金运作地一个主要障碍。'] 1
# ['别的祛痘产品我不知道，不过我觉得茚象泉的祛痘产品挺好的啊，你不知道吗？'] 1
# ['别的人还罢了，如月郡主却是等不及人回话，', '“', '呼', '”', '一声就闯进房里的。'] 5
# ['别的，人们关于文体的承受水平也是因言语的差别而异。'] 1
# ['别的人遗弃了它，虐待它，而现在它有了朋友，它对我的感谢是不言而喻的。'] 1
# ['别的神祗气恼万分，但不敢拯救赫拉，尽管她哭喊得十分凄惨。'] 1
# ['别的事都能束之高阁也，然后自我解嘲地微笑，睡去吧。'] 1
# ['别的网站允许用户交换货物和服务，或者是物物交换。在这种古老的交易形式过程中，没有金钱转手。'] 1
# ['别的许多人处在他的境地一定会成为父母的累赘。'] 1
# ['别的研究人员系统地对酵母菌的6，600种基因进行了诱变，并观察这些变异酵母菌在不同条件下的进展状况。'] 1
# ['别的一个人也许也病了，病得危在旦夕，其苦难可能躲在他的膏肓里，好像矿层中的金子，对他毫无用处；'] 1
# ['别的一些人也传了这个，只要没关系的话就会让你知道的。还有，大赞这片。'] 1
# ['别的一种广吃香的常青植物是寄生树，树上生有白的颜色的小浆果，树叶摸上去象动物熟皮。'] 1
# ['别的渔夫捕鱼比他多，收益比他高，最终鱼还是要被捕光。'] 1
# ['别的指向型包括', '“', '超心型', '”', '（超指向），假如你想缩紧声场可能会用得着。'] 5
# ['“', '别蹬了！', '”', '西鲁非低头用爪子挠了挠眼睛，脑袋上的薇薇安随着他的动作不断尖叫。'] 4
# ['别等到那一天，我们只能靠着回忆，才能坚持下去。'] 1
# ['“', '别，等等，我现在想要。等我洗洗。', '”'] 3
# ['别喋喋不休，向我诉说：生命只是梦罔，因为，沉睡的灵魂死了，一切都是假象。'] 1
# ['“', '别盯着我看，', '”', '黛西回嘴说，', '“', '我整个下午都在动员你上纽约去。', '”'] 7
# ['“', '别丢下我！', '”', '她歇斯底里地哭喊着。'] 4
# ['别动我的电脑，我不想丢失我存过的任何文件。'] 1
# ['“', '别动！', '”', '伊芙说，', '“', '我去拎一桶水来。', '”', '她急急忙忙朝管家的餐具室跑去，心里砰砰直跳，既害怕，又高兴。'] 8
# ['“', '别逗了，', '”', '他不果断说。', '“', '你知道这很危险。', '”'] 7
# ['别对弗雷耍花招。要是他认为你是在和他胡闹，他会狠狠揍你一顿的。'] 1
# ['别对生活太认真，否则你将永远不能摆脱它活着。'] 1
# ['别对他的所作所为太苛刻，他毕竟还是个孩子。'] 1
# ['别对他的所作所为太苛求，他毕竟还是个孩子。'] 1
# ['别对他太严厉。他毕竟只是个孩子。'] 1
# ['别对现实生活过于苛求，常存感激的心情！'] 1
# ['别饿着自己研究表明使自己处于饥饿状态的人会以错误的方式减少体重。'] 1
# ['别尔哥罗德州州长称，这一节日与俄罗斯文化传统不符，同样被禁止的还有万圣节。'] 1
# ['别尔嘉耶夫则从末世论的角度讨论基督教世界必定是一个恩典的历史，人类历史需要一个救世主。'] 1
# ['《别尔金小说集》一直被分体研究，视为多部小说的沙状集合。'] 1
# ['“', '别发疯', '”', '，我们愤怒地说：', '“', '我们有足够的果盘。', '”'] 7
# ['别发火，亲爱的。我去检查过那车了，情况并不像你想象的那么严重。而且，他们的保险公司会负担修理费的。'] 1
# ['别发火。我会打电话给他们，把事情搞定。'] 1
# ['别发牢骚了，尽快开始做你的工作。'] 1
# ['别犯傻了。你还是要看医生的。我来帮你预约。只有傻子才怕见牙医呢！'] 1
# ['“', '别放弃，', '”', '他说，', '“', '你是个很棒的作家。', '”', '他读过我的几篇小说，以便告诉我哪些地方的科学部分被我弄错了。'] 8
# ['别放弃。我相信如果你坚持埋头苦干，你就会得到你想要的结果。'] 1
# ['“', '别放在那儿，', '”', '男孩说，', '“', '那马厩今晚会失火。', '”'] 7
# ['别费心了，我们不可能赶上的，干脆别尝试了，还浪费我们的钱，加重纳税人负担。'] 1
# ['别敷衍我了你，是，我误解了你对爱的，理解。'] 1
# ['别搞错了，这不是狼的侥幸。这是狼应得的，他们以他们的表现挣来了26年来第一次战胜安菲尔德的辉煌战绩。'] 1
# ['别搞得像你事先知道这事会发生一样。你这完全是事后诸葛亮。'] 1
# ['别告诉别人，但我在股票市场赚了一大笔。我现在很有钱呀，老弟！'] 1
# ['别告诉她我们正在为她准备的生日晚会，我们可以给她一个惊喜。'] 1
# ['别告诉同事，其实我正在找新工作。'] 1
# ['别告诉我——就这样走出去而我却再也看不到它了。'] 1
# ['别告诉我硫磺石，我知道我闻到了什么，不可能是硫磺石。'] 1
# ['别告诉我你不可救药的迷恋，发展成了无意义的嫉妒。'] 1
# ['别格咬紧牙关，举起铁锅；但他不敢扔出去，怕打不中。'] 1
# ['别给人家寄一张五十美元的支票，同时却暗示自己拥有游艇。'] 1
# ['别给我介绍不必要的注册步骤或者是其他会减慢我支付的无用信息。'] 1
# ['别跟旅店的职员混得太熟，否则你只能参加一些当地的活动。'] 1
# ['别跟他们说话，凯西说。你没看到他们笑的就像扫帚吗。'] 1
# ['别跟他说是我讲的，因为他对此极其敏感，而且每次有人提起他那懦弱的婴儿般的眼睛就会流下大量胆小的眼泪。'] 1
# ['别跟我吹有个魅力十足的女人在Facebook上加你好友，想徒劳得招我嫉恨。'] 1
# ['别跟我回嘴，食人妖。你知道现在这里谁是老大，难道你不曾想过为何索尔会选择我担任大酋长，而不是你呢？'] 1
# ['别跟我谈生活', '”', '）、还有Vogon的诗篇、过于自我的自动门、以及舰载电脑Eddie。'] 3
# ['别跟我提机器人。不论怎样我看到的那些眼睛不是机器的。它是什么有血有肉的东西。'] 1
# ['别跟我玩儿这套，我知道你一直在骗我。直说吧，别藏着了。'] 1
# ['别鼓动他。他父母亲不准他参加探险队。'] 1
# ['别挂念着孩子们，他们已经长大，自己会照顾自己了。'] 1
# ['别拐弯抹角的了，直接告诉我你认为我的工作有什么不对的。'] 1
# ['别拐弯抹角了：这看起来极像是第二次大萧条的前兆。'] 1
# ['别怪他打碎那个花瓶，他毕竟是小孩子嘛。'] 1
# ['别怪他，他是真的不知道如何找到理智和情感的平衡支点。'] 1
# ['别管丁太太那些残酷的警告，宽宏大量些，想法去看看他吧。'] 1
# ['别管航道曲折蜿蜒，让生命之舟穿过激流险滩，驶向理想的彼岸。'] 1
# ['别管是在人世还是去阴间，她的习惯是在所有场合都不轻举妄动。'] 1
# ['别管他了，来吧，在到达码头前我们侠盗飞车任务把这件事情搞定。快走。'] 1
# ['别管他说什么，他总是信口胡说。'] 1
# ['“', '别惯坏了我的姑娘', '”', '妈妈说', '“', '别和她们搭讪了除非你真的有意', '”'] 7
# ['别光是把名字写在你的东西上。任何标有', '“', '西蒙的牛奶，别动', '”', '的东西马上就会被一扫而光。'] 5
# ['别国的人用更烈性的东西来增强体力，但英国人的体质却只需要茶。'] 1
# ['“', '别，哈姆！', '”', '我叫道，试图拉回他，', '“', '不用试着去救那可怜的水手！你自己会没命的！', '”'] 7
# ['别害怕不敢砍价——如果你不是在学校假期期间租房时更应砍价。'] 1
# ['“', '别害怕，', '”', '莫吉安娜说，', '“', '你看到的这个男人既不能对你也不能对任何人造成任何伤害了。'] 6
# ['别害怕去尝试仿佛超过能力所及的事情。敢于冒巨大的风险。不要畏缩不前，走出去，大胆尝试。'] 1
# ['别害怕生活，也要勇敢地像海鸥一样，在暴风雨的海面快乐地高叫，穿透乌云。'] 1
# ['别害怕完全地告诉别人你想什么，但是要礼貌的进行。说出心里话。'] 1
# ['别害怕，我不会伤害你的。我爪子里扎进了一根刺，你看，它扎得很深，我拔不出来。'] 1
# ['别和焚书者一起去。你难道不认为你是在通过抹杀思想存在的证据来抹杀思想吗？'] 1
# ['别和敏感的人开玩笑。那有可能会伤害他们。'] 1
# ['别和他交朋友，他只是一个傻瓜。'] 1
# ['别和我说什么照护夜凰的话，是不是家里发生什么事了？'] 1
# ['别和我玩，白痴，我才不和你交易呢，你这个骗子。'] 1
# ['别和这种机构呆在一块，如果他们值得你加入，他们就准备好有效发挥你的才能。'] 1
# ['别和自己过不去，一切都会过去。别和往事过不去，它已经过去。'] 1
# ['别胡扯啦！你总不会认为我会相信你的瞎话吧？'] 1
# ['别花时间跑回家然后买个回城卷轴，买只鸡然后运个治疗药膏过来，而此刻你正窝在塔下！'] 1
# ['别慌，看看爱情专家怎么说：鲜花：最传统也是最经典的情人节礼物。'] 1
# ['“', '别慌张，他一回来我就让他打电话给你', '”', '这位教练的妻子告诉她', '“', '你的号码是多少？', '”'] 7
# ['别灰心，换个角度看。荾怂淙缓芄？但他终究还是个男人。'] 1
# ['别灰心，你还有很多机会改善你和他们的关系的。'] 1
# ['别激动，来，坐下，有我，请放心。请具体说下你的情况好吗？'] 1
# ['别急，你到底会想起来的。也许我能帮你跑跑腿什么的。'] 1
# ['别急，请先回答我一个问题：这件事不会发生在哪里？'] 1
# ['别急，这里仍有一些揭开未知邮件发送者身份的方法与在线服务。'] 1
# ['别急着把你的周英里数增长百分比提高到比10', '%', '还多。'] 3
# ['别急着把这篇日志又当成一篇投机取巧的技巧帖，想想前面的路该怎么走。'] 1
# ['别急着做宣传，大多数时候，有些事会事与愿违的，那么它并不能在人们的脑海里留下很深的印象。'] 1
# ['别假惺惺地说不愿意他走。我很清楚，你讨厌他，希望他快走。'] 1
# ['别假惺惺地为他的不幸而难过了，我知道你一直讨厌他，看到他倒霉，心里可高兴哩！'] 1
# ['别假装惊讶了吧：你知道他们存在着，并组成了老大党（GrandOldParty，共和党的别称）核心的一大部分。'] 1
# ['别假装你什么都不知道。这古钢琴坏了，就是你搞坏的！'] 1
# ['别见怪我说了些什么请别见怪如今你不会见怪，不会了，是吧。'] 1
# ['“', '别讲了，给我纹吧，', '”', '我充满信念的说。几个月后，我跟西雅图男友分手了。'] 4
# ['别交哪些在一起让你舒舒服服的朋友。交那些让你不得不长进的朋友。', '--', '沃森。'] 3
# ['别介意，但这似乎，这样做好像太蠢了。'] 1
# ['“', '别介意海辛斯·巴凯特喜欢餐巾胜过餐巾纸，阶级观念比这还要严重得多', '”', '…《保住面子》。'] 4
# ['别介意海辛斯·巴凯特喜欢餐巾胜过餐巾纸，阶级观念比这还要严重得多，而且需要大声说出来。'] 1
# ['别介意他的情妇：他和他的妻子甚至去哪里度假都想不到一块去。'] 1
# ['别介意，他只是个爱发牢骚的西班牙老头'] 1
# ['别介意我：不知所措的游客看着狮子大快朵颐'] 1
# ['别紧张，只要有注意均衡饮食及多做运动，便可锻鍊出强健的体魄。'] 1
# ['别惊讶，这是我生命最后一天的最后时刻的话语。'] 1
# ['别居又称分居，它产生于欧洲中世纪基督教的教会法，至今仍存在。'] 1
# ['别具一格的建筑，浓郁的异国风情，古典与现代交相辉映，传统与西洋融为一体。'] 1
# ['别觉得我骂得难听，这比起你做的已经算是微不足道的了。'] 1
# ['别觉得牺牲很委屈，应当庆幸你还有东西可以牺牲，你要知道，围城外有多少人想进来。'] 1
# ['“', '别开玩笑了，', '”', '我对布吕丹丝说，', '“', '玛格丽特到底需要多少钱？', '”'] 7
# ['“', '别砍下我的头颅！', '”', '凯伦哀求道，', '“', '因为那样的话我就无法赎罪，但是砍掉我那穿红舞鞋的脚吧', '”'] 7
# ['别看本店小，专门供应各季适令商品，决不令您失望。'] 1
# ['别看哈努曼（印度神话中的猴神）蛇仅有一英尺长，一身漂亮的鲜绿色，这种蛇的毒性非常大，常常可以致命。'] 1
# ['别看那些人有着体面的社会地位和耀眼的头衔，暗地里却干着见不得人的罪恶勾当。'] 1
# ['别看杀人蜂看起来和普通蜜蜂没什么两样，但是其腹部却蕴藏着巨大危险，致命的毒液就在其中。'] 1
# ['别看他胖胖的，说话很幽默，教我们唱歌的方法又比较容易让我们接受。'] 1
# ['别看他四处流浪已有六个月之久，他似乎在暗示，他其实不是个流浪汉，上帝可以作证！'] 1
# ['别看他这么高，我任何一个女儿都能像打翻一根烂树枝似的把他揍倒在地。'] 1
# ['别看她是个杀人不眨眼的杀手，但在感情方面，还是0呢。'] 1
# ['别看它不大，我们人体需臾不可贫乏的氧气，必要及时排挤的二氧化碳都是靠它来运送的。'] 1
# ['别看它个儿小，它从来不估计自己的力量，只知道一个劲儿地往前冲。'] 1
# ['别看它看上去庄重仁慈端庄，其实却是一次反天主教宣传的产物。'] 1
# ['别看着我我们争吵的时候不要看我要看路'] 1
# ['别渴着如果你一天没有摄取足够的水，你就可能感觉头晕，头痛，还可能有些迷糊。'] 1
# ['别克充电式SUV将采用通用在研发雪佛兰Volt中使用过的某些技术。'] 1
# ['别克的营销团队将', '“', '美国大学篮球联赛', '”', '（NCAA）作为广告阵地，并创作了一段大学篮球明星的', '“', '精彩镜头集锦', '”', '。', '片中，明星们倾情参与了各种旨在帮助贫困人群的慈善活动。'] 10
# ['别克还努力实现车内的静音效果，这是别克数年来引以为荣的一大优点。'] 1
# ['别克凯越正是为这样一批热爱生活、务实进取，并不断追求超越的社会中坚打造的。'] 1
# ['别克砰的一声撞上铁轨停住了，这家伙踢开车门撒腿就跑。'] 1
# ['别克商标中形似', '“', '三利剑', '”', '的图案为共图形商标，被安装在汽车散热器格栅上。'] 5
# ['别克是个饱经风霜的高个子，他身着红色的狩猎服和卡其布的裤子，我去五金货架时从他身边经过，向他点了点头。'] 1
# ['别克在湿漉漉的碎石路上，怎么说呢，简直是在飞，像个喝醉了的火箭。'] 1
# ['别客气，', "''", '鹳说，', "''", '过几天请到我家来和我一起吃饭吧。', "''"] 6
# ['别客气！我看看能不能弄几份三明治。'] 1
# ['别客气，我们很爱你的笑容，我也很爱你的一双手，卡尔再说：这要多谢我的太太。'] 1
# ['别哭了孩子，别哭孩子，你的灵魂还没远走，让我为你唱一首歌吧！你想听吗。'] 1
# ['别哭了，赫德森太太.子弹真要出膛眼泪也挡不住.不然世界可真是个温柔乡啊'] 1
# ['“', '别哭了，', '”', '她说，', '“', '你知道水对你伤害很大。', '”'] 7
# ['别哭了。我会慢慢收获你的悲伤。我有时间去发现让你悲泣的原由。'] 1
# ['别哭，你是我们的英雄，我知道金牌对于你来说很重要，其实胜利与否真的无所谓。'] 1
# ['别哭泣，别叹息，别呻吟；悲伤唤不回流逝的时光。'] 1
# ['别哭泣，别叹息，别呻吟；悲伤唤不回流逝的时光。（爱尔兰剧作家弗莱沏。J。）'] 1
# ['别哭泣，别叹息，别呻吟；悲伤唤不回流逝的时光。', '--', '-约翰.弗莱彻，英国剧作家。'] 3
# ['别哭泣，别叹息，别呻吟。悲伤唤不回消逝的时光。'] 1
# ['别哭泣，别叹息，别呻吟；悲伤也唤不回流逝的时光。'] 1
# ['别哭泣，也别叹息，别失意，悲伤换不回失去的时光。'] 1
# ['别拉斯汽车液压系统常见故障及处理'] 1
# ['“', '别来这一手啦，布洛德，', '”', '卢克开始这么说，他准备要着手好好进行一番真刀真枪的科学辩论。'] 4
# ['别赖在沙发上了，做事变得高效一点吧，那才是应该过的生活。'] 1
# ['别浪费水，否则多年以后地球上就没有水可供我们使用了。'] 1
# ['别浪费我的时间来告诉我堕胎是错误的，不如告诉我有甚么更好的方法，及你们如何推广这些方法。'] 1
# ['别老穿这件条纹T恤，你看上去像大黄蜂。'] 1
# ['别老惦念着孩子们，他们已经长大，自己会照顾自己了。'] 1
# ['别老盯着我工作。挺烦人的，而且我也无法集中注意力。'] 1
# ['别了，母校，我们航行再远，总与您遥遥相望！'] 1
# ['《别了，武器》一书虽然在细节描写方面刻意求实，而且有一个悲剧性的结局，但它仍然是一部理想主义的著作。'] 1
# ['别离的泪水，为记忆的长河增添新的浪花；别离的祝福，为再—次相聚拉开了序幕。'] 1
# ['别离我太远，也别和我太近，这个距离便好。淡淡的感觉在我视线之内驻扎，在我心的一角静泊。'] 1
# ['别理解错了，我可受不了周围堆满混乱一团的杂物。'] 1
# ['别林斯基：《别林斯基选集》第1卷，满涛译。上海：上海译文出版社，1979年。'] 1
# ['《别林斯基选集》第2卷，满涛译。上海：上海译文出版社，1979年。'] 1
# ['别留下黑色羽毛作为你的灵魂谎言的象征！'] 1
# ['别留下我一个人！尼维尔马上爬起来，我不想一个人呆在这里。刚才吸血鬼巴伦已经来过两次了。'] 1
# ['别骂自己的孩子是小兔崽子，因为从遗传学的角度来讲，这对家长是不利的。'] 1
# ['别忙着在明天早晨8点打电话给一家华尔街银行去咨询业务。'] 1
# ['别冒傻气了，你爸爸刚14岁就辍了学，这使他后悔了一辈子。'] 1
# ['别名或用户定义的类型所属的架构名。'] 1
# ['别名「机会大地」（LandofOpportunity）的阿肯色于1836年添加联邦，成为美国第25州。'] 1
# ['别名可以是以句点分隔并且中间没有空格字符的组合。'] 1
# ['别名是一种简单的机制，允许您为给定的序列提供展开形式。'] 1
# ['别名数据类型或用户定义类型所属架构的名称。'] 1
# ['别名「鹈鹕之州」（PelicanState）的路易斯安那坐落在南方腹地，它拥有多采多姿的历史，是为纪念路易十四（KingLouisXIV）而得名。'] 1
# ['别名往往是一个缩短了的表名，用于在联接中引用表的特定列。'] 1
# ['别名「阳光之州」（SunshineState）的佛罗里达以其宜人、和煦的天气及美丽的海滩闻名于世。'] 1
# ['别名，以便更易于将标识符限定到命名空间或类型。'] 1
# ['别名允许访问可能被代码中的实体隐藏的根命名空间。'] 1
# ['别拿话儿搪塞我们，我们只是想知道你到底是同意还是不同意。'] 1
# ['别拿我们开心了，问问你们自己的兄弟姐妹或是子女，不是更直接吗？。'] 1
# ['“', '别那么草率嘛', '”', '！他说到。', '“', '你至少看一下我给你示范一遍。', '”'] 7
# ['别那么嫉妒好不好，在我面前他可从没说过你的坏话。'] 1
# ['“', '别那么叫我！我不是你妈。你只是一个脏老头。', '”'] 3
# ['别那么紧张。你说的都是对的，不会招致任何批评。'] 1
# ['别那么敏感，只是随口问问，我发现你在看伴郎。'] 1
# ['别那么软弱。知道吗？你应该看看史密斯医生。她很棒的。'] 1
# ['别那么生你母亲的气了，毕竟，她只是想帮助你而已。'] 1
# ['“', '别，', '”', '那女仆说，', '“', '丁太太，对这个漂亮的小姑娘别这么凶吧。'] 6
# ['别那样看着我，', '”', '——海德薇大大的琥珀色眼睛里充满了责备——', '“', '又不是我的错。'] 5
# ['别那样看着我，你知道我从不吹嘘'] 1
# ['别那样说啦！这全是命运带来的偶然！'] 1
# ['别那样，这是抽签抽到的，可不是我主动争取的。'] 1
# ['“', '别难过，', '”', 'Finklestein弥留之际说，', '“', '我已经过了八十年好日子。', '”'] 7
# ['别难过皮特：《钢铁侠》主角小罗伯特唐尼也没拿到那个角色。'] 1
# ['别难过，作者只不过比你早几年、多几次惊慌而已。'] 1
# ['“', '别闹了，', '”', '凌霄回身看她，', '“', '李小涵，在你眼里最贵的衣服是什么牌子的？', '”'] 7
# ['别闹笑话…详细的你可以百度网页搜下蔓妮韵瘦身贴官网看看。'] 1
# ['别怕丢人，那是一种成功的尝试，不要笑话那些上台丢人的人。'] 1
# ['别怕，接下来的几分钟，我会帮你解除魔咒，助你摆脱这种不体面的境地。'] 1
# ['别怕。您只会觉得一点小小的刺痛。我现在给你消毒手指。好了，做完了，疼吗？'] 1
# ['别怕伤害我的感情，直说吧，医生，我也许则得了癌症了？'] 1
# ['别怕缩短文章。你应该把这段删去，把那段缩短一些。'] 1
# ['“', '别碰帽子，', '”', '她的客人说。她转过身去，看见他已抬起头，正看着自己。'] 4
# ['“', '别碰我！', '”', '嘉莉说着挪开身子，但是仍用手帕捂着眼睛。'] 4
# ['“', '别骗我。', '”', '桃金娘喘着气说，眼泪滔滔不绝地滚下面颊，皮皮鬼在她身后快活地咯咯直笑。'] 4
# ['别嘌呤醇、抑制尿酸的合成', '--', '它可以用于治疗代谢综合征及相关的疾病吗？'] 3
# ['别期望你迟到而其他人顶上，因为有一些工作要等着你来处理完，别人才能进行。'] 1
# ['别杞人忧天了，你要学会看开一点。'] 1
# ['别气馁，毕竟，你在这个领域是个新手。'] 1
# ['别气馁，你得到的通常是马上就可以打开未知出路的钥匙。'] 1
# ['别请乔伊来参加这次聚会。他这人对人太冷淡，太不友好。他来了会使其他所有人都扫兴的。'] 1
# ['别去拆房子，要检视每块砖，并且换掉那些看来残破而不再能支撑那结构物的。'] 1
# ['别去打听别人想要保守秘密的事。'] 1
# ['别去惊动它，孩时的那份记忆太完美，无论今后的任何一种可能的相见都不能给它续添上貂尾。'] 1
# ['别去问值还是不值，生命的价值从来不是用交换体现。'] 1
# ['别去用勺子盛托盘上的饭，盛碗里的饭。'] 1
# ['“', '别嚷嚷！嗓门儿不用这么大，', '”', '马儿回答道，', '“', '我原来住的地方，几乎所有的动物都说话。', '”'] 7
# ['别让别人告诉你不能做什么，你有梦想，你就得保护它。'] 1
# ['别让电视广告引诱你购买自己实际不需要的东西', '.'] 2
# ['别让干扰信号把你弄糊涂了。重复，别让敌人的干扰信号把你弄晕了。'] 1
# ['别让孩子尝试控制你的决定，例如，你选择谁保母。'] 1
# ['别让孩子们养成晚睡的习惯。'] 1
# ['别让花花世界迷惑了双眼，更别让夺走你内心宁静的那种美妙感受。'] 1
# ['别让那声音把你吓着了，那不过是风声。别让那声音把你吓着了，那不过是风声。'] 1
# ['别让那些地面上的垃圾们再让太空中的垃圾问题恶化了。'] 1
# ['别让那些伤害你的人驾驭你的精神生活，做回你自己。'] 1
# ['别让你的孩子把头伸出火车窗外-太危险了。'] 1
# ['别让情绪干扰你的成功EQ差的人，很容易被情绪打败，只有完全与情绪分开来，这样才会战胜自己，才不会踏上失败的路程。'] 1
# ['别让日复一日的压力和生活琐碎纠缠着你，试试用明星们的方式来放松吧。'] 1
# ['别让时间冲淡友情的酒，别让距离拉开梦中相握的手。'] 1
# ['别让他们离得太近了，不然我们就不能一鼓作气夺路冲杀了！'] 1
# ['别让他迷惑你，因为他是个有魅力的人'] 1
# ['别让他人的批评妨碍你或减损你的自信，捍卫自己，批评者最后可能是你的好友。'] 1
# ['别让他人熄灭你的激情！激情可以引导你的生活变得圆满充实。享受你做的事吧。'] 1
# ['别让我觉得我很渺小，这只会令我更加愚蠢地去逞强。'] 1
# ['别让我们所争得的自由再落到外国侵略者和国内封建主手里。'] 1
# ['别让我们整个团体都处于险境，你应该试着跟他沟通。'] 1
# ['别让我难堪了，行不行，特德。把挡风玻璃抹一下。'] 1
# ['别让我失望，年轻的女士。我不会总是这么纵容你的。'] 1
# ['别让我推迟，别让我忽视，因为我不会从这里再次经过了。', '’', '这就是我的生活。'] 3
# ['别让我想起那个尴尬的日子，我可是出尽了丑。'] 1
# ['别让我原谅你.你会是一个骗子，会是一个骗子。'] 1
# ['别让我在人生的战场上寻找盟友，让我拥有自己强大的力量。'] 1
# ['别让我这么难受，别拖延了。来啊！开枪吧。我说的不是你。'] 1
# ['《别让我走》可能在技巧上有些科幻，因为故事场景设定在未来，但实际上整个故事并没有科幻色彩。'] 1
# ['别让现在的经济衰退欺骗了你，拥有大学学位的人更可能获得经济上的保障。'] 1
# ['别让愚昧无知的自大造成你们民族的殒落，', '$', 'PLAYER0。赶快献上我们想要的一切，要不然就等着毁灭吧！'] 3
# ['别让这些东西整天放置在外令人知道家中无人，容易成为盗贼的目标。'] 1
# ['别人把钱或东西给错了你的时候，包括给与你远远超出应得的报酬，一定要拒绝。'] 1
# ['别人不服，说既然不呻吟，你怎么知道他们的嗓子没伤？'] 1
# ['别人不敢读，但我们却敢读出来，这是我们的优势，我们要大力宣扬出来。'] 1
# ['别人不行，等他忏悔了以后，没有再要弄原子弹才可以。'] 1
# ['别人不领情，那是他的错；但如果我不给予，那就是我的错了。'] 1
# ['别人不同意他时，他很容易大发脾气'] 1
# ['别人不应当看见象您这样一个体面的年轻人跟着我这样一个女人。'] 1
# ['别人错了没有必须时时纠正，注意纠正可能会使双方陷入尴尬境地从而引得彼此不舒服。'] 1
# ['别人的洋娃娃：如果你曾收到一个洋娃娃礼物', ',', '请写它的意义和你的评论。'] 3
# ['别人钓鱼都用有香味的鱼饵诱骗鱼儿上钩，但是太公从不挂鱼饵，也不把鱼竿沉到水下。'] 1
# ['别人都从传送带上拿到了行李，但是我的好像不在那里。'] 1
# ['别人都说我很疯狂，真的，我只个疯子，一个为减肥而费心费力的女生。'] 1
# ['别人都说我看起来不错，但是我知道，这是汽油又泄露了。'] 1
# ['别人都说在大学很难找到真正的友谊，特别是女生之间。'] 1
# ['别人都说，只有赢得这个总冠军才能留得住菲尔。你会这样觉得吗？'] 1
# ['别人都一定会高举快乐的火炬进入新的一年，充满活力面对新年，前途一片光明。'] 1
# ['别人都在工作和努力，你怎么能满不在乎，不怕给人瞧不起呢？'] 1
# ['别人对你的改变反应如何？你是否收到了口头或非口头的反应？给以具体说明。'] 1
# ['别人对你工作的干扰与你自己无数次地打断自己相比，微不足道。'] 1
# ['别人对他说，伊朗未能阻止对巴格达逊尼派的', '“', '异教徒清洗', '”', '，伊朗还迫害其国内属于逊尼派的少数派群体。'] 5
# ['别人对自己的生活，该关心的一定要关心，不该关心的绝对不要关心，更不能横加干涉。'] 1
# ['别人非但不会接受他的批评及规劝，还会反过来指责他，攻击他。'] 1
# ['别人告诉你进屋不用脱鞋你会觉得怪怪的。'] 1
# ['别人告诉我不要走近查尔斯，他染上了流行性腮腺炎。更详细。'] 1
# ['别人告诉我，我的腿明显有点瘸，有几天我拒绝承认，但现在我清楚地感觉到我的身体往右边晃动更大了，而当我向前跨步时，右脚也弯曲得更厉害了。'] 1
# ['别人还以为我怕了他，今后怎么掌管锦衣卫？'] 1
# ['别人会将它们褶盖在椅子上或者将他们扔在地板上，留着之后收拾。', '这便成了主要的家庭杂务。'] 2
# ['别人会将它们褶盖在椅子上或者将他们扔在地板上，留着之后收拾。这便成了主要的家庭杂务。'] 1
# ['别人会试图猜测它到底值多少钱，这挺可怕的。'] 1
# ['别人会怎么看呢？一位哈佛大学的法律教授娶了一个刚参加工作就被开除的律师。'] 1
# ['别人会抓住你犯下的错误不放，所以第一次就做好很重要。'] 1
# ['别人或许会告诉你不行，但你想要的就要去得到它。'] 1
# ['别人家里鸡零狗碎的事你都知道的这么全，真是个包打听！'] 1
# ['别人惊讶地说，这么危重的病情不呻吟，一定是他们的声带烧糊了。'] 1
# ['别人纠正他，他就说要跟女主人扳手腕，证明自己的厉害。'] 1
# ['别人看球是为了享受，但是，在球场上，我们必须为自己努力奋斗。'] 1
# ['别人可能会理解这个错误，所以怎样平息自己的最严厉指责呢？'] 1
# ['别人可能会为你的表现感到些许不适，因此记得要和往常一样关心他人，正常社交。'] 1
# ['别人可能认为我在此事上花费太多的精力，但，请等一下，这一简单工作不应被忽视。'] 1
# ['别人可能说他的话是叛国言论，但思嘉听来却是真实的，合乎情理的。'] 1
# ['别人可能一片混乱的时候，你能洞悉形势，产生令人吃惊的见识。'] 1
# ['别人可以违背因果，别人可以害我们，打我们，毁谤我们。可是我们不能因此而憎恨别人，为什。'] 1
# ['别人恐惧时，我们贪婪；别人贪婪时，我们恐惧。'] 1
# ['别人没有义务先弄明白你是否偷汉再决定是否管你叫破鞋。'] 1
# ['别人，那麽你就是在浪费你的旅程。相反的，你应该学会享受旅程。把它当作一场一次快乐的，不断学。'] 1
# ['别人去游泳时，我儿子说他也要去，扯下了暴雨时一直挂在绳上的游泳裤并把它拧干。'] 1
# ['别人认为是拉圾的，其中往往却有黄金，而历史将会因没有它而为之减色。'] 1
# ['别人认为这是不可忍受的生活条件，而我则视其为一项理财投资。'] 1
# ['别人杀的人，却让我背了黑锅。'] 1
# ['别人试图说服你按他们的方式做事，这可能会激怒你。'] 1
# ['别人说话时，你插入某些不必要的细节。', '“', '这种反驳别人的人，经常用另一种方式重述同一件事。', '”'] 4
# ['别人说几句关于我们的闲话，我们根本就不必理会，它就像围绕在老教堂的尘塔周围呱呱叫的乌鸦一样。'] 1
# ['别人说你做不成这件事的时候，偏偏你把这件事给做成了。'] 1
# ['别人所厌恶的一切，什么低贱的伙伴啊，简陋的房间啊，污浊的空气啊，令人作呕的朋友啊，对你却很有吸引力。'] 1
# ['别人贪婪（歇斯底里）的时候，你就要开始卖了——如果你需要找一个卖的理由的话，这就是理由。'] 1
# ['别人同你讲话时出心不在焉是没礼貌的。'] 1
# ['别人同意，他必须等待他价质的证明。'] 1
# ['别人想分享他们财富的要求变得非常烦人、无休无止，以致于有钱人常常决定必须把自己隔离起来。'] 1
# ['别人向他要财务报告时，那位会计员不该生气的，没有人指责他的诚实。'] 1
# ['别人写信时也不要近看。'] 1
# ['别人辛苦修行数十年，居然被一个小辈在刹那之间追了上去。'] 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-393-0b9d327e7707> in <module>()
#       1 for i in chtemp:
#       2     print(nltk.word_tokenize(i), len(nltk.word_tokenize(i)))
# ----> 3     time.sleep(0.2)
#
# KeyboardInterrupt:

# %%
nltk.word_tokenize("DON'T 'DON \"T' ICM's boss thinks ")
# Out:
# ['DO', "N'T", "'DON", '``', 'T', "'", 'ICM', "'s", 'boss', 'thinks']

# %%
nltk.word_tokenize("Well now you can sleep with your head against one in this 1940s Bristol B-170 Freighter plane.")
# Out:
# ['Well',
#  'now',
#  'you',
#  'can',
#  'sleep',
#  'with',
#  'your',
#  'head',
#  'against',
#  'one',
#  'in',
#  'this',
#  '1940s',
#  'Bristol',
#  'B-170',
#  'Freighter',
#  'plane',
#  '.']

# %%
def ibm_align(numsent, iterations, engtemp, chtemp):
    forwards, backwards = [], []
    for i in range(numsent):
        forwards.append(nltk.AlignedSent(nltk.word_tokenize(engtemp[i].lower()), [x for x in chtemp[i]]))
        backwards.append(nltk.AlignedSent([x for x in chtemp[i]], nltk.word_tokenize(engtemp[i].lower())))
    ibm2f = nltk.translate.IBMModel2(forwards, iterations)
    ibm2b = nltk.translate.IBMModel2(backwards, iterations)
    return forwards, backwards, ibm2f, ibm2b

# %%
forwards, backwards, ibm2f, ibm2b = ibm_align(100, 5, engtemp, chtemp)

# %%
sent = 2

# %%
def t(a):
    return [(x[1], x[0]) for x in list(a.alignment)]

# %%
set(list(forwards[sent].alignment)).intersection(t(backwards[sent]))
# Out:
# {(7, 2), (9, 18), (10, 14), (12, 28), (16, 29)}

# %%
translation_table = ibm2.translation_table
alignment_table = ibm2.alignment_table

os.chdir(path)
os.system("mkdir data_structures")

import json

with open(path + "/data_structures/translation_table.json", "w") as f:
    json.dump(translation_table, f)
    
with open(path + "/data_structures/alignment_table.json", "w") as f:
    json.dump(alignment_table, f)

# %%
def get_max_probs(d):
    l = {}
    for i, j in d.items():
        if j > 1e-12:
            l.update({i:j})
    return l

# %%
def max_prob(d):
    return max(d, key = d.get)

# %%
max_prob(get_max_probs(ibm2.translation_table["after"]))
# Out:
# '毕'

# %%
get_max_probs(ibm2.translation_table["show"])
# Out:
# {'布': 4.654869454497104e-08,
#  '径': 4.392909528415727e-12,
#  '演': 0.14201526890009336,
#  '瓶': 0.0002452198467060133,
#  '示': 0.280925476124776,
#  '舞': 0.572160506868442,
#  '表': 3.2865584560703185e-09,
#  '软': 2.8700119581480847e-06,
#  '饥': 0.032572484561202576,
#  '饿': 0.19999991164810252}

# %%
bitext[0].alignment
# Out:
# [(6, 39),
#  (8, 23),
#  (14, 13),
#  (20, 43),
#  (11, 23),
#  (13, 30),
#  (9, 37),
#  (18, 23),
#  (5, 25),
#  (0, 40),
#  (1, 24),
#  (7, 14),
#  (16, 23),
#  (3, 40),
#  (10, 23),
#  (17, 4),
#  (4, 6),
#  (19, 23),
#  (12, 23),
#  (15, 37),
#  (2, 4)]

# %%
#json.load(open(path + "/data_structures/translation_table.json", "r"))

# %%
nltk.translate.IBMModel2(bitext, 10, ibm2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-e25ec1552f5d> in <module>()
# ----> 1 nltk.translate.IBMModel2(bitext, 10, ibm2)
#
# /Users/csmuser/anaconda/lib/python3.6/site-packages/nltk/translate/ibm2.py in __init__(self, sentence_aligned_corpus, iterations, probability_tables)
#     131         else:
#     132             # Set user-defined probabilities
# --> 133             self.translation_table = probability_tables['translation_table']
#     134             self.alignment_table = probability_tables['alignment_table']
#     135
#
# TypeError: 'IBMModel2' object is not subscriptable

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-de8df8265c35> in <module>()
#       5
#       6 with open(path + "/data_structures/translation_table.json", "w") as f:
# ----> 7     json.dump(ibm2, f)
#
# /Users/csmuser/anaconda/lib/python3.6/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# /Users/csmuser/anaconda/lib/python3.6/json/encoder.py in _iterencode(o, _current_indent_level)
#     435                     raise ValueError("Circular reference detected")
#     436                 markers[markerid] = o
# --> 437             o = _default(o)
#     438             yield from _iterencode(o, _current_indent_level)
#     439             if markers is not None:
#
# /Users/csmuser/anaconda/lib/python3.6/json/encoder.py in default(self, o)
#     178         """
#     179         raise TypeError("Object of type '%s' is not JSON serializable" %
# --> 180                         o.__class__.__name__)
#     181
#     182     def encode(self, o):
#
# TypeError: Object of type 'IBMModel2' is not JSON serializable

# %%
os.chdir(path + "/casia2015")
files = glob.glob("*.txt")

c2015entemp = process_eng(open(files[1], "r", encoding = "utf-8").read().split("\n"), conts, nopunct, exclude, e)
#c2015en = eng_sentence_split(c2015entemp)

# %%
c2015en = eng_sentence_split(c2015entemp, 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-451a2fdf3269> in <module>()
# ----> 1 c2015en = eng_sentence_split(c2015entemp, 3)
#
# NameError: name 'eng_sentence_split' is not defined

# %% [markdown]
# *n*-gram for `casia2015_en`:

# %%
c2015engram, freqs = trigram(c2015en, {}, {})

# %%
#c2015engram

# %%
c2015engram["It's gon'"]
# Out:
# {"gon' say": 1}

# %% [markdown]
# ### NTLK Brown

# %% [markdown]
# *n*-gram for NLTK Brown corpus:

# %%
def process_NLTK_Brown(conts, nopunct, exclude, e):
    from nltk.corpus import brown
    temp = " ".join([x for x in brown.words(categories = brown.categories())])
    listform = eng_sentence_split(temp)
    return process_eng(listform, conts, nopunct, exclude, e)

# %%
browntemp = process_NLTK_Brown(conts, nopunct, exclude, e)

# %%
browngram, freqs = trigram(browntemp, c2015engram, freqs)

# %%
c2015cntemp = open(files[0], "r", encoding = "utf-8").read().split("\n")

# %%
for i in range(100):
    print(lol[i], i)
# Out:
# 表演的明星是X女孩团队——由一对具有天才技艺的艳舞女孩们组成，其中有些人受过专业的训练。 0
# 表演的压轴戏是闹剧版《天鹅湖》，男女小人们身着粉红色的芭蕾舞裙扮演小天鹅。 1
# 表演和后期制作之间的屏障被清除了，这对演员来说一样大有裨益。 2
# （表演或背诵时）通过暗示下面忘记或记地不准的东西来帮助某人。 3
# 表演基本上很精彩--我只对她的技巧稍有意见。 4
# 表演结束后，我们看到一对对车灯沿主路一路排回镇上，然后散开来各回各家。 5
# 表演结束后，移走了背景墙，随后全体演员即兴邀请观众上台齐跳并排舞。 6
# 表演结束后用宣纸轻铺水面，可将水面上的画进行拓印保存。 7
# 表演结束后，众人期待已久的园游会终于正式开锣，美味可口的素食佳肴让大家一饱口福。 8
# 表演节目丰富精采，交换礼物的欢乐时刻一到，则形成另一波高潮。 9
# 表演仅仅是造就一个近乎觉察不出来的「直线的地质的移位」。 10
# 表演开始十五分钟后，一帮足球运动员开始集体向着舞台上的女演员发出嘘声。 11
# 表演开始时，舞台上会有一张床，一面镜子，一张椅子以及一位穿着内衣的美女。在你觉察到前，一位性感的女孩会突然变成三位。 12
# 表演开始时，艺人坐在地毯上轻击盅子，徐缓起舞； 13
# 表演“猫女”——在一个笼子里穿着带有一根长尾巴和猫耳的豹纹女内衣。 14
# 表演前，她紧张得浑身颤抖不已。 15
# 表演是他们的嫡传技艺，150多年来他们家族一直都是演员。 16
# 表演算得上是一门残忍的职业，你偏离正统美越远，就越艰难。 17
# 表演我软木塞哪一呼吸和我将表演你一瓶醋。 18
# 表演：悉尼歌剧院首席男高音丁毅先生悉尼歌剧院首席女高音 19
# 表演秀以及开园时间有可能因故不经预告而取消或中止，敬请留意。 20
# 表演一个不限分析国内受损的期望往往带来了个人工作的公司。 21
# “表演”一结束，他马上给那名黑人“歹徒”发工钱，然后两个人还握手拥抱。 22
# 表演艺术家MarniKotak（持玩偶者）在布鲁克林的“显微镜”画廊生下一婴作为她艺术作品的一部分。 23
# 表演艺术来源于生活而高于生活，生活是艺术创作的来源，取之不尽用之不竭的源泉。 24
# 表演在安慰疗法中也很重要。安慰性注射虽然比安慰药丸有效果，但是却没有虚假手术来得见效。 25
# “表演在本质上给了他们一个正当的理由去学习如何表达自己。”阿伦森说。 26
# 表演者把信封靠近他的脑袋，然后先给出答案，再打开信封，读问题。 27
# 表演者包括歌手马尼洛和富兰克林；歌手们星期五将向观众献上一场彩排。 28
# 表演者会带来他自己的吸引力，他自己的感性，他自己的作者。 29
# 表演者没有大炮火药了，于是Clifford吹气把她发射出去了。 30
# 表演者拿一个小簸箕在上面炒，过一会，爆米花就出来了。 31
# 表演者热情地向中国贵宾赠送斯特森骑士帽。 32
# 表演者在冰上的那种潇洒的风格为她赢得了许多朋友和一块金牌。 33
# 表演者在开幕典礼庆祝活动溅水的首届青年奥运会星期六2010年8月14日在新加坡举行。 34
# 表演者，指演员或者其他表演文学、艺术作品的人。 35
# 表演中用打击乐伴奏，但狮舞的动作不受音乐节奏的限制，音乐只起烘托气氛的作用。 36
# 表一：对人体肠道的通透性，作为替代标记使用极地糖尿execretionGIPET我的时间。 37
# 表已经成为有身份或有品味——抑或是身份或品味低下——的新标志。 38
# 表意的主观性和抽象性导致小说偏向表现“形而上的现实”。 39
# 表英尺组表页脚始终显示在其他所有行和行组，和之前的底部字幕。 40
# 表有8毫米厚的明确钢化玻璃与抛光边缘和沙丘抨击标志的顶端小组。 41
# 表有结构简单、口径大、重量轻、操作方便等优点。 42
# 表彰他在电路，系统和信号处理，尤其是数字滤波方面的贡献。 43
# 表征的结果显示PAS分子筛具有更多的适合蜡分子异构化反应的孔径分布。 44
# 表征的途径，其中一项是作家揭示了这样一个人物身份证的个性。 45
# 表征影像学表现上皮样血管瘤，我们审查了现有文献关于这一主题的。 46
# 表值对象可以是表、视图、函数、同义词或本地表。 47
# 表中的大多数术语在本书最后所附的“名词汇编”中均有说明。 48
# 表中的第一列包含任务，后面两列指明任务是否在其原始平台上进行操作。 49
# 表中光照度数据为上午和下午两次观测值的平均值。 50
# 表中基因的一列相对于表达数据发生了调换，导致两项不相对应。 51
# 表中继续述说着两个甚至更多世纪的全食，然而持续时间逐渐减少。 52
# 表中所列电参数为参考值，实际电参数会因使用条件的不同而变化。 53
# 表中也显示了每个版本的小计以及顾客的总费用。 54
# 裱糊纸板：用多张较薄纸板裱贴而成的纸板。有别于均质纸板。 55
# 憋了几个月，等啊等，等待市场推出一款你钟爱的平板电脑。 56
# 憋死我了！你也不说，我也不说，咱俩总得有一个来挑明吧！算了，我不下地狱谁下地狱。我说了“我爱你”！ 57
# 瘪版是堵住雕镂或蚀刻制成的，制成的版镀铬后会补充硬度，以提矮耐印度。 58
# 瘪印版滚筒不合为有轴版滚筒和无轴版滚筒。 59
# 瘪印机洋牵引辊与初版辊相邻凡是撤有周速同步机构。 60
# 瘪印在制卡和会员卡制作金属油墨时不入格得当。柔印在上光方面也有其独到之处。 61
# 瘪制卡和会员卡制作又不合为雕镂不不凸版与拍照印版两栽。 62
# “别啊，”他喊道，冷笑着，“我们可以把这脏东西当奴隶卖了呀，正好可以换一碗酒钱呢。” 63
# 别按你自己的想象认为他们需要什么；做些用户研究去确切地发现他们所需。 64
# 别把关心你的人扔在角落，否则会让你更受伤。 65
# 别把火炬受干扰当成那整个城市或国家不可饶恕的罪过。 66
# 别把莓果掉出来，因为正如大家所知，最快装满桶子的第一只熊就可以赢得比赛喔！ 67
# 别把你的车子停在我的房子外边，你想想人家回怎么说！ 68
# 别把数学想象为硬梆梆的、死绞蛮缠的、令人讨厌的、有悖于常识的东西，它只不过是赋予常识以灵性的东西。 69
# 别把所有的积蓄花在整修住所，存下出游的金额。 70
# 别把他算进去。你还不了解他吗。他的决心持续不了三分钟。 71
# 别把它当作不切实际、或是必须经过选民公投通过的事情。 72
# 别把它丢失在你的爆米花里，ICM公司的老板认为，互联网能够降低新的电影拍摄者的进入门槛。 73
# “别把我的心搅乱了，我亲爱的保罗，”他的妹妹说道，“因为这会毁了我。 74
# 别把我框死在一个岗位上！除了接电话，我还可以做许多其他事情！ 75
# 别把我们两个人算在一块儿，哈丽特。拿我的演奏同她的相比，就如同一盏灯同太阳相比。 76
# 别把我弄糊涂了，力量举需要很多的技术，我刚才说的意思是举重是更热门的竞技运动。 77
# 别把香蕉船算我那份里，我想我还是想点份三克巧克力华夫饼蛋卷冰激凌吧。 78
# 别把雪柜放置在煮食炉和发热源头旁，也避免放在有阳光直接照射的窗户。 79
# 别把一个人想的有多高尚，也别把一个人想的有多龌龊 80
# 别把衣服扔在椅子上，把它们挂起来。 81
# 别把油漆胡乱刷得这么厚，他们要求外表光滑美观。 82
# 别把这头猪说成是受害者，这个可怜的女人才是受害者！那些帮助她的人都做得很好，但是没必要把它拍下了！ 83
# 别把这些都当成是你自己的事情：即使你是那个拿着高薪，深感不安，并且一次又一次地触及他们失望底线的家伙。 84
# 别把自己弄得像个太监一样，连自己的理想都要去遗忘，这样你真的会开心？ 85
# 别霸占着你不用的东西！既然你下午有课，就把网球拍让我用。 86
# 别拌嘴了，女士们。就让我们也偶尔在舒适的床上享受一个平静的夜晚吧。 87
# 别抱怨你假期花钱太多，你倒是玩得痛快。鱼与熊掌不可兼得嘛。 88
# 别被教条捆住了，否则你就只是生活在别人思考的结果里。 89
# 别被名字给弄混了，它出售的是时髦的围裙、手袋、钱包以及非常传统式样的垫桌布。 90
# 别被秋分日昼夜长短相等的概念愚弄了。 91
# 别被他谦虚的态度骗了，其实他是个很骄傲的人。 92
# 别被这个狡猾的忍者所愚弄！这其实是一个优盘。 93
# 别逼着他们告诉你他们的心事。那将惹怒他们，可能另他们感觉更糟。 94
# 别别，没但是。只要你客观点看待这个情况，这份工作就该归我。 95
# “别，别着急放下灯笼，看来，还有一个要出来！”，医生不由得惊叫起来。 96
# 别不承认你内心最深处的事情，爱她胜过爱你自己，没有她你的生活毫无意义。 97
# 别不假思索的就怪罪于母亲：一个爱哭的、得腹绞痛的宝宝也同样会是由父亲的情绪而影响形成的，荷兰研究人员的报告说。 98
# 别操心化妆了这样可以让你的皮肤透透气--但得确保先抹上滋润霜。 99
